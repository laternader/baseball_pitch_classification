# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Read in the Seasonal Data

# %%
mlb2020 = pd.read_csv('data/2020mlb.csv')
mlb2020.shape
# Out:
# (279660, 90)

# %%
mlb2019 = pd.read_csv('data/2019mlb.csv')
mlb2019.shape
# Out:
# (743572, 90)

# %%
mlb2018 = pd.read_csv('data/2018mlb.csv')
mlb2018.shape
# Out:
# (731207, 90)

# %%
mlb2017 = pd.read_csv('data/2017mlb.csv')
mlb2017.shape
# Out:
# (732476, 90)

# %% [markdown]
# # Look at previews

# %%
mlb2020.head()
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         FF  2020-10-27           96.7           1.58           5.99
# 1      1         FF  2020-10-27           94.1           2.91           5.45
# 2      2         FF  2020-10-27           94.9           1.77           6.02
# 3      3         FF  2020-10-27           94.4           1.66           5.93
# 4      4         CU  2020-10-27           81.4           1.46           6.06
#
#    player_name    batter   pitcher     events      description  spin_dir  \
# 0  Julio Urias  642715.0  628711.0  strikeout    called_strike       NaN
# 1  Julio Urias  642715.0  628711.0        NaN    called_strike       NaN
# 2  Julio Urias  642715.0  628711.0        NaN  swinging_strike       NaN
# 3  Julio Urias  670712.0  628711.0  strikeout    called_strike       NaN
# 4  Julio Urias  670712.0  628711.0        NaN             ball       NaN
#
# ...

# %%
mlb2019.head()
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         SL  2019-10-30           87.9          -2.65           5.50
# 1      1         FF  2019-10-30           95.9          -2.77           5.52
# 2      2         FF  2019-10-30           96.5          -2.68           5.42
# 3      3         FF  2019-10-30           96.0          -2.65           5.55
# 4      4         SL  2019-10-30           86.7          -2.73           5.59
#
#      player_name    batter   pitcher     events      description  spin_dir  \
# 0  Daniel Hudson  488726.0  543339.0  strikeout  swinging_strike       NaN
# 1  Daniel Hudson  488726.0  543339.0        NaN             foul       NaN
# 2  Daniel Hudson  488726.0  543339.0        NaN             ball       NaN
# 3  Daniel Hudson  488726.0  543339.0        NaN             foul       NaN
# 4  Daniel Hudson  488726.0  543339.0        NaN             ball       NaN
#
# ...

# %%
mlb2018.head()
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         SL  2018-10-28           84.0           3.05           5.26
# 1      1         FF  2018-10-28           95.3           3.17           5.50
# 2      2         FF  2018-10-28           96.4           3.07           5.54
# 3      3         CH  2018-10-28           86.6           3.10           4.98
# 4      4         SL  2018-10-28           78.5           3.31           5.16
#
#   player_name    batter   pitcher     events      description  spin_dir  \
# 0  Chris Sale  592518.0  519242.0  strikeout  swinging_strike       NaN
# 1  Chris Sale  592518.0  519242.0        NaN             ball       NaN
# 2  Chris Sale  592518.0  519242.0        NaN             foul       NaN
# 3  Chris Sale  592518.0  519242.0        NaN  swinging_strike       NaN
# 4  Chris Sale  571771.0  519242.0  strikeout  swinging_strike       NaN
#
# ...

# %%
mlb2017.head()
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         FF  2017-11-01           96.6          -1.85           5.93
# 1      1         FF  2017-11-01           95.0          -1.99           5.86
# 2      2         FF  2017-11-01           96.1          -2.06           5.92
# 3      3         FF  2017-11-01           96.7          -1.92           5.87
# 4      4         FF  2017-11-01           96.0          -1.89           5.84
#
#       player_name    batter   pitcher     events      description  spin_dir  \
# 0  Charlie Morton  608369.0  450203.0  field_out    hit_into_play       NaN
# 1  Charlie Morton  621035.0  450203.0  field_out    hit_into_play       NaN
# 2  Charlie Morton  621035.0  450203.0        NaN  swinging_strike       NaN
# 3  Charlie Morton  621035.0  450203.0        NaN             ball       NaN
# 4  Charlie Morton  621035.0  450203.0        NaN             foul       NaN
#
# ...

# %%
mlb2017['events'].unique()
# Out:
# array(['field_out', nan, 'strikeout', 'walk', 'single', 'force_out',
#        'hit_by_pitch', 'double_play', 'home_run', 'double', 'field_error',
#        'sac_fly', 'grounded_into_double_play', 'triple',
#        'fielders_choice_out', 'caught_stealing_2b', 'sac_bunt',
#        'interf_def', 'pickoff_1b', 'strikeout_double_play',
#        'fielders_choice', 'pickoff_caught_stealing_2b',
#        'caught_stealing_3b', 'pickoff_2b', 'other_out',
#        'sac_fly_double_play', 'caught_stealing_home', 'triple_play',
#        'pickoff_caught_stealing_3b', 'batter_interference', 'run',
#        'pickoff_caught_stealing_home'], dtype=object)

# %%
mlb2017['description'].unique()
# Out:
# array(['hit_into_play', 'swinging_strike', 'ball', 'foul',
#        'called_strike', 'foul_tip', 'hit_into_play_score',
#        'hit_into_play_no_out', 'blocked_ball', 'swinging_strike_blocked',
#        'hit_by_pitch', 'missed_bunt', 'foul_bunt', 'pitchout'],
#       dtype=object)

# %%
mlb2017[mlb2017['description']=='swinging_strike'].sample(5)
# Out:
#         index pitch_type   game_date  release_speed  release_pos_x  \
# 618442  25792         FF  2017-05-02           93.3          -1.06
# 452347   2089         CU  2017-06-12           88.5          -2.05
# 440596  16121         CH  2017-06-15           84.8          -0.26
# 706999  16978         FF  2017-04-09           91.4           1.69
# 34743    9787         CH  2017-09-26           83.2           2.58
#
#         release_pos_z    player_name    batter   pitcher     events  \
# 618442           6.36  Ervin Santana  476704.0  429722.0  strikeout
# 452347           5.39     Alex Meyer  592450.0  543542.0        NaN
# 440596           6.66  Michael Wacha  543768.0  608379.0        NaN
# 706999           5.84  Jose Quintana  592696.0  500779.0        NaN
# 34743            6.38    Cole Hamels  543807.0  430935.0        NaN
#
#             description  spin_dir  spin_rate_deprecated  \
# 618442  swinging_strike       NaN                   NaN
# ...

# %%
mlb2017.iloc[618442][0:20]
# Out:
# index                                                                  25792
# pitch_type                                                                FF
# game_date                                                         2017-05-02
# release_speed                                                           93.3
# release_pos_x                                                          -1.06
# release_pos_z                                                           6.36
# player_name                                                    Ervin Santana
# batter                                                                476704
# pitcher                                                               429722
# events                                                             strikeout
# description                                                  swinging_strike
# spin_dir                                                                 NaN
# ...

# %% [markdown]
# # Cleaning

# %% [markdown]
# Extract the batters name since we don't have it.
