# %%
mlb2020['description'].unique()
# Out:
# array(['called_strike', 'swinging_strike', 'ball', 'foul',
#        'hit_into_play', 'blocked_ball', 'hit_into_play_score',
#        'swinging_strike_blocked', 'hit_into_play_no_out', 'foul_bunt',
#        'foul_tip', 'hit_by_pitch', 'missed_bunt', 'pitchout',
#        'bunt_foul_tip'], dtype=object)

# %%
mlb2020[(mlb2020['bb_type']=='fly_ball') & (mlb2020['strike_attempt']=='out')] # Make an EDA
# Out:
#         index pitch_type  game_date  release_speed  release_pos_x  \
# 9           9         FF 2020-10-27           95.2           1.72
# 77         77         FF 2020-10-27           94.3          -0.71
# 119       119         CH 2020-10-27           89.9           2.13
# 239       239         FF 2020-10-27           96.2          -0.53
# 263         4         FC 2020-10-25           94.3          -2.86
# ...       ...        ...        ...            ...            ...
# 279564  19973         FF 2020-07-23           96.3          -2.14
# 279569  19984         SL 2020-07-23           89.7          -1.90
# 279599  20043         FF 2020-07-23           96.9          -1.91
# 279603  20052         FF 2020-07-23           97.3          -1.94
# 279633  20111         FF 2020-07-23           96.4          -1.94
#
#         release_pos_z   pitcher_name    batter   pitcher     events  \
# 9                6.09    Julio Urias  622534.0  628711.0  field_out
# 77               6.46  Nick Anderson  457759.0  623433.0  field_out
# 119              6.45    Blake Snell  669257.0  605483.0  field_out
# 239              6.34  Tony Gonsolin  622534.0  664062.0  field_out
# 263              6.39  Blake Treinen  621563.0  595014.0  field_out
# ...               ...            ...       ...       ...        ...
# 279564           5.40    Gerrit Cole  594809.0  543037.0  field_out
# 279569           5.57    Gerrit Cole  607208.0  543037.0  field_out
# 279599           5.53    Gerrit Cole  452678.0  543037.0  field_out
# 279603           5.38    Gerrit Cole  435559.0  543037.0  field_out
# 279633           5.56    Gerrit Cole  607208.0  543037.0  field_out
#
#           description  zone  \
# 9       hit_into_play   6.0
# 77      hit_into_play   1.0
# 119     hit_into_play   6.0
# 239     hit_into_play   2.0
# 263     hit_into_play   3.0
# ...               ...   ...
# 279564  hit_into_play   5.0
# 279569  hit_into_play   8.0
# 279599  hit_into_play   1.0
# 279603  hit_into_play   6.0
# 279633  hit_into_play  13.0
#
#                                                       des game_type stand  \
# 9       Manuel Margot flies out to right fielder Mooki...         W     R
# 77      Justin Turner flies out sharply to left fielde...         W     R
# 119     Will Smith flies out to right fielder Manuel M...         W     R
# 239     Manuel Margot flies out to right fielder Mooki...         W     R
# 263     Joey Wendle flies out to center fielder Cody B...         W     L
# ...                                                   ...       ...   ...
# 279564  Adam Eaton flies out sharply to right fielder ...         R     L
# 279569  Trea Turner flies out to right fielder Aaron J...         R     R
# 279599  Asdrubal Cabrera flies out to left fielder Bre...         R     L
# 279603  Kurt Suzuki flies out to right fielder Aaron J...         R     R
# 279633  Trea Turner flies out to center fielder Aaron ...         R     R
#
#        p_throws home_team away_team type  hit_location   bb_type  balls  \
# 9             L       LAD        TB    X           9.0  fly_ball    1.0
# 77            R       LAD        TB    X           7.0  fly_ball    2.0
# 119           L       LAD        TB    X           9.0  fly_ball    1.0
# 239           R       LAD        TB    X           9.0  fly_ball    2.0
# 263           R        TB       LAD    X           8.0  fly_ball    0.0
# ...         ...       ...       ...  ...           ...       ...    ...
# 279564        R       WSH       NYY    X           9.0  fly_ball    1.0
# 279569        R       WSH       NYY    X           9.0  fly_ball    1.0
# 279599        R       WSH       NYY    X           7.0  fly_ball    2.0
# 279603        R       WSH       NYY    X           9.0  fly_ball    2.0
# 279633        R       WSH       NYY    X           8.0  fly_ball    3.0
#
#         strikes  game_year  pfx_x  pfx_z  plate_x  plate_z  on_3b     on_2b  \
# 9           2.0     2020.0    0.4    1.5     0.40     2.56    NaN       NaN
# 77          1.0     2020.0   -0.3    1.2    -0.50     3.33    NaN       NaN
# 119         1.0     2020.0    0.9    0.8     0.41     2.13    NaN       NaN
# 239         2.0     2020.0   -0.8    1.6    -0.03     2.85    NaN  640457.0
# 263         1.0     2020.0    0.2    0.6     0.33     2.85    NaN       NaN
# ...         ...        ...    ...    ...      ...      ...    ...       ...
# 279564      2.0     2020.0   -0.9    1.3     0.14     2.46    NaN       NaN
# 279569      2.0     2020.0    0.4    0.3     0.13     1.59    NaN       NaN
# 279599      1.0     2020.0   -1.1    1.3    -0.37     3.46    NaN       NaN
# 279603      0.0     2020.0   -1.0    1.6     0.42     2.33    NaN       NaN
# 279633      1.0     2020.0   -1.1    1.4    -0.07     1.26    NaN       NaN
#
#            on_1b  outs_when_up  inning inning_topbot    hc_x    hc_y  \
# 9            NaN           0.0     9.0           Top  191.34   99.03
# 77      608369.0           1.0     6.0           Bot   57.09   58.10
# 119          NaN           0.0     5.0           Bot  169.84   92.21
# 239     664040.0           1.0     1.0           Top  162.88  102.52
# 263     622534.0           1.0     9.0           Bot  135.95   72.41
# ...          ...           ...     ...           ...     ...     ...
# 279564       NaN           2.0     3.0           Bot  127.07  182.71
# 279569       NaN           1.0     3.0           Bot  199.64  124.90
# 279599  519346.0           1.0     2.0           Bot   82.14   65.45
# 279603  519346.0           0.0     2.0           Bot  207.47  100.47
# 279633       NaN           0.0     1.0           Bot  161.09   77.50
#
#          Catcher       vx0         vy0       vz0         ax         ay  \
# 9       605131.0 -4.306764 -138.539023 -6.867868   6.166594  30.824839
# 77      572287.0  1.251048 -137.341253 -5.206023  -4.296378  29.941916
# 119     572287.0 -6.266070 -130.702046 -6.519853  11.843886  27.616449
# 239     605131.0  3.007189 -139.968878 -7.224611 -10.612648  33.546888
# 263     605131.0  7.737255 -137.201580 -4.919650   1.117310  29.123174
# ...          ...       ...         ...       ...        ...        ...
# 279564  596142.0  8.132363 -140.052278 -5.275349 -13.691072  29.691544
# 279569  596142.0  4.243760 -130.644752 -4.720634   3.620447  23.060521
# 279599  596142.0  6.773670 -140.969449 -2.936449 -16.779139  30.025899
# 279603  596142.0  8.662956 -141.481030 -6.323744 -15.324475  29.843747
# 279633  596142.0  7.612632 -140.053500 -9.062853 -16.589153  29.861348
#
#                az  sz_top  sz_bot  hit_distance_sc  launch_speed  \
# 9      -11.731952    3.25    1.53            284.0          83.4
# 77     -15.701940    3.41    1.57            370.0         100.8
# 119    -21.545474    3.21    1.50            276.0          84.1
# 239     -9.694762    3.25    1.53            248.0          93.4
# 263    -23.091144    3.05    1.46            303.0          83.5
# ...           ...     ...     ...              ...           ...
# 279564 -13.739515    3.29    1.49            364.0         101.3
# 279569 -27.463063    3.47    1.59            248.0          77.1
# 279599 -14.735646    3.37    1.53            333.0          97.5
# 279603  -9.711639    3.34    1.52            302.0          87.3
# 279633 -12.052281    3.47    1.59            301.0          85.0
#
#         launch_angle  effective_speed  release_spin_rate  release_extension  \
# 9               44.0             94.0             2450.0                5.6
# 77              38.0             94.4             2172.0                6.3
# 119             43.0             90.9             1827.0                6.9
# 239             53.0             95.3             2471.0                5.9
# 263             38.0             93.6             2470.0                5.8
# ...              ...              ...                ...                ...
# 279564          41.0             97.1             2307.0                6.6
# 279569          39.0             90.8             2525.0                6.6
# 279599          45.0             97.6             2484.0                6.6
# 279603          34.0             98.1             2521.0                6.6
# 279633          37.0             97.3             2548.0                6.7
#
#          game_pk  FirstBasemen  SecondBasemen  ThirdBasemen  ShortStop  \
# 9       635886.0      571970.0       571771.0      621458.0   608369.0
# 77      635886.0      596847.0       664040.0      621563.0   642715.0
# 119     635886.0      596847.0       664040.0      621563.0   642715.0
# 239     635886.0      571970.0       621035.0      457759.0   608369.0
# 263     635887.0      571970.0       571771.0      457759.0   608369.0
# ...          ...           ...            ...           ...        ...
# 279564  630851.0      572228.0       642180.0      570482.0   650402.0
# 279569  630851.0      572228.0       642180.0      570482.0   650402.0
# 279599  630851.0      572228.0       642180.0      570482.0   650402.0
# 279603  630851.0      572228.0       642180.0      570482.0   650402.0
# 279633  630851.0      572228.0       642180.0      570482.0   650402.0
#
#         LeftField  CenterField  RightField  release_pos_y  \
# 9        621035.0     641355.0    605141.0          54.92
# 77       668227.0     595281.0    622534.0          54.21
# 119      668227.0     595281.0    622534.0          53.57
# 239      572041.0     641355.0    605141.0          54.57
# 263      621035.0     641355.0    605141.0          54.68
# ...           ...          ...         ...            ...
# 279564   458731.0     543305.0    592450.0          53.89
# 279569   458731.0     543305.0    592450.0          53.93
# 279599   458731.0     543305.0    592450.0          53.93
# 279603   458731.0     543305.0    592450.0          53.87
# 279633   458731.0     543305.0    592450.0          53.76
#
#         estimated_ba_using_speedangle  estimated_woba_using_speedangle  \
# 9                               0.029                            0.040
# 77                              0.257                            0.448
# 119                             0.014                            0.015
# 239                             0.014                            0.017
# 263                             0.007                            0.007
# ...                               ...                              ...
# 279564                          0.136                            0.224
# 279569                          0.057                            0.051
# 279599                          0.021                            0.031
# 279603                          0.007                            0.006
# 279633                          0.007                            0.006
#
#         woba_value  woba_denom  babip_value  iso_value  launch_speed_angle  \
# 9              0.0         1.0          0.0        0.0                 3.0
# 77             0.0         1.0          0.0        0.0                 5.0
# 119            0.0         1.0          0.0        0.0                 3.0
# 239            0.0         1.0          0.0        0.0                 3.0
# 263            0.0         1.0          0.0        0.0                 3.0
# ...            ...         ...          ...        ...                 ...
# 279564         0.0         1.0          0.0        0.0                 3.0
# 279569         0.0         1.0          0.0        0.0                 3.0
# 279599         0.0         1.0          0.0        0.0                 3.0
# 279603         0.0         1.0          0.0        0.0                 3.0
# 279633         0.0         1.0          0.0        0.0                 3.0
#
#         at_bat_number  pitch_number       pitch_name  home_score  away_score  \
# 9                63.0           4.0  4-Seam Fastball         3.0         1.0
# 77               45.0           4.0  4-Seam Fastball         2.0         1.0
# 119              35.0           3.0         Changeup         0.0         1.0
# 239               5.0           6.0  4-Seam Fastball         0.0         1.0
# 263              71.0           2.0           Cutter         2.0         4.0
# ...               ...           ...              ...         ...         ...
# 279564           24.0           5.0  4-Seam Fastball         1.0         3.0
# 279569           23.0           4.0           Slider         1.0         3.0
# 279599           15.0           4.0  4-Seam Fastball         1.0         2.0
# 279603           14.0           3.0  4-Seam Fastball         1.0         2.0
# 279633            6.0           5.0  4-Seam Fastball         0.0         2.0
#
#         bat_score  fld_score  post_away_score  post_home_score  \
# 9             1.0        3.0              1.0              3.0
# 77            2.0        1.0              1.0              2.0
# 119           0.0        1.0              1.0              0.0
# 239           1.0        0.0              1.0              0.0
# 263           2.0        4.0              4.0              2.0
# ...           ...        ...              ...              ...
# 279564        1.0        3.0              3.0              1.0
# 279569        1.0        3.0              3.0              1.0
# 279599        1.0        2.0              2.0              1.0
# 279603        1.0        2.0              2.0              1.0
# 279633        0.0        2.0              2.0              0.0
#
#         post_bat_score  post_fld_score if_fielding_alignment  \
# 9                  1.0             3.0              Standard
# 77                 2.0             1.0         Infield shift
# 119                0.0             1.0         Infield shift
# 239                1.0             0.0              Standard
# 263                2.0             4.0              Standard
# ...                ...             ...                   ...
# 279564             1.0             3.0              Standard
# 279569             1.0             3.0              Standard
# 279599             1.0             2.0         Infield shift
# 279603             1.0             2.0         Infield shift
# 279633             0.0             2.0              Standard
#
#        of_fielding_alignment       batter_name count strike_attempt
# 9                   Standard     Manuel Margot   1-2            out
# 77                  Standard     Justin Turner   2-1            out
# 119                 Standard        Will Smith   1-1            out
# 239                 Standard     Manuel Margot   2-2            out
# 263                 Standard       Joey Wendle   0-1            out
# ...                      ...               ...   ...            ...
# 279564              Standard        Adam Eaton   1-2            out
# 279569              Standard       Trea Turner   1-2            out
# 279599              Standard  Asdrubal Cabrera   2-1            out
# 279603              Standard       Kurt Suzuki   2-0            out
# 279633              Standard       Trea Turner   3-1            out
#
# [7406 rows x 83 columns]

# %%
mlb2020['zone'].unique() # Zone location of the ball when it crosses the plate from the catcher's perspective.
# Out:
# array([ 4.,  1.,  2., 13., 11.,  5., 12.,  6.,  8.,  3., 14.,  9.,  7.,
#        nan])

# %%
mlb2020['bb_type'].unique() # Fielder out, batted ball type
# Out:
# array([nan, 'fly_ball', 'ground_ball', 'line_drive', 'popup'],
#       dtype=object)

# %%
mlb2020['hit_location'].unique() # Infielder/Outfielder did the ball get hit to
# Out:
# array([ 2., nan,  9.,  4.,  5.,  8.,  7.,  3.,  6.,  1.])

# %%
# Look at the plays surrounding the 4-2 counts
mlb2020.iloc[36750:36760] # 8682, 36750, 36751-2

# Error by Umpire at pitch 8682-8689 ATLvsMIA, Pablo Lopez vs Adam Duvall, result: flyout (playoffgame)
# https://sports.yahoo.com/mishap-count-costs-braves-baserunner-025838865.html

# Might have to drop index 36753, no explanation
# Apparently, 51-52 were fouled off, but considered balls
# @53, there is NaNs
# After watching the actual game footage, it was Umpire error game was a blow out
# https://www.mlb.com/video/search?q=Player+%3D+%5B%22Brock+Holt%22%5D+AND+BatterName+%3D+%5B%22Mickey+Moniak%22%5D+Order+By+Timestamp+DESC
# Decide what to do with that whole at bat, pitcher was a position player
# Out:
#        index pitch_type  game_date  release_speed  release_pos_x  \
# 36750  13210         CH 2020-09-23           84.4          -0.99
# 36751  13226         CH 2020-09-23           83.3          -1.02
# 36752  13238         CU 2020-09-23           80.1          -1.15
# 36753  13255        NaN 2020-09-23            NaN            NaN
# 36754  13269         CH 2020-09-23           81.7          -0.99
# 36755  13271         CU 2020-09-23           58.0          -1.65
# 36756  13292         CU 2020-09-23           80.5          -1.00
# 36757  13309         CU 2020-09-23           70.1          -0.91
# 36758  13322        NaN 2020-09-23            NaN            NaN
# 36759  13339         CU 2020-09-23           38.1          -0.94
#
#        release_pos_z pitcher_name    batter   pitcher       events  \
# 36750           6.18   Brock Holt  666160.0  571788.0       single
# 36751           6.23   Brock Holt  666160.0  571788.0          NaN
# 36752           6.17   Brock Holt  666160.0  571788.0          NaN
# 36753            NaN   Brock Holt  666160.0  571788.0          NaN
# 36754           6.26   Brock Holt  666160.0  571788.0          NaN
# 36755           5.94   Brock Holt  666160.0  571788.0          NaN
# 36756           6.22   Brock Holt  666160.0  571788.0          NaN
# 36757           6.58   Brock Holt  666160.0  571788.0          NaN
# 36758            NaN   Brock Holt  666160.0  571788.0          NaN
# 36759           6.92   Brock Holt  664068.0  571788.0  field_error
#
#                 description  zone  \
# 36750  hit_into_play_no_out   1.0
# 36751                  foul   4.0
# 36752                  foul   5.0
# 36753                  ball   NaN
# 36754                  ball  11.0
# 36755                  ball  11.0
# 36756                  foul   8.0
# 36757       swinging_strike  12.0
# 36758                  ball   NaN
# 36759  hit_into_play_no_out   5.0
#
#                                                      des game_type stand  \
# 36750  Mickey Moniak singles on a sharp ground ball t...         R     L
# 36751                                                NaN         R     L
# 36752                                                NaN         R     L
# 36753                                                NaN         R     L
# 36754                                                NaN         R     L
# 36755                                                NaN         R     L
# 36756                                                NaN         R     L
# 36757                                                NaN         R     L
# 36758                                                NaN         R     L
# 36759  Scott Kingery reaches on a fielding error by s...         R     R
#
#       p_throws home_team away_team type  hit_location      bb_type  balls  \
# 36750        R       WSH       PHI    X           9.0  ground_ball    4.0
# 36751        R       WSH       PHI    S           NaN          NaN    4.0
# 36752        R       WSH       PHI    S           NaN          NaN    4.0
# 36753        R       WSH       PHI    B           NaN          NaN    3.0
# 36754        R       WSH       PHI    B           NaN          NaN    2.0
# 36755        R       WSH       PHI    B           NaN          NaN    1.0
# 36756        R       WSH       PHI    S           NaN          NaN    1.0
# 36757        R       WSH       PHI    S           NaN          NaN    1.0
# 36758        R       WSH       PHI    B           NaN          NaN    0.0
# 36759        R       WSH       PHI    X           6.0  ground_ball    0.0
#
#        strikes  game_year  pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  \
# 36750      2.0     2020.0   -0.6    1.7    -0.37     3.32    NaN    NaN
# 36751      2.0     2020.0   -0.7    1.8    -0.39     2.55    NaN    NaN
# 36752      2.0     2020.0   -0.6    1.8     0.16     2.37    NaN    NaN
# 36753      2.0     2020.0    NaN    NaN      NaN      NaN    NaN    NaN
# 36754      2.0     2020.0   -0.6    1.8    -1.05     3.28    NaN    NaN
# 36755      2.0     2020.0    0.5   -0.3    -1.85     2.69    NaN    NaN
# 36756      1.0     2020.0   -0.5    1.7    -0.17     2.12    NaN    NaN
# 36757      0.0     2020.0   -0.6    1.7     0.16     3.87    NaN    NaN
# 36758      0.0     2020.0    NaN    NaN      NaN      NaN    NaN    NaN
# 36759      0.0     2020.0   -0.3    1.4     0.14     2.24    NaN    NaN
#
#           on_1b  outs_when_up  inning inning_topbot    hc_x    hc_y   Catcher  \
# 36750  664068.0           2.0     9.0           Top  166.58  112.92  543228.0
# 36751  664068.0           2.0     9.0           Top     NaN     NaN  543228.0
# 36752  664068.0           2.0     9.0           Top     NaN     NaN  543228.0
# 36753  664068.0           2.0     9.0           Top     NaN     NaN  543228.0
# 36754  664068.0           2.0     9.0           Top     NaN     NaN  543228.0
# 36755  664068.0           2.0     9.0           Top     NaN     NaN  543228.0
# 36756  664068.0           2.0     9.0           Top     NaN     NaN  543228.0
# 36757  664068.0           2.0     9.0           Top     NaN     NaN  543228.0
# 36758  664068.0           2.0     9.0           Top     NaN     NaN  543228.0
# 36759       NaN           2.0     9.0           Top  110.45  155.13  543228.0
#
#             vx0         vy0       vz0        ax         ay         az  sz_top  \
# 36750  2.528689 -122.849015 -3.541800 -6.206217  23.899668 -14.872529    3.39
# 36751  2.806865 -121.170098 -5.364831 -7.677905  23.425814 -14.033880    3.39
# 36752  3.859255 -116.599883 -5.033640 -5.819140  21.349736 -14.999680    3.39
# 36753       NaN         NaN       NaN       NaN        NaN        NaN     NaN
# 36754  0.948936 -118.960824 -3.547717 -5.567221  21.923928 -14.720264    3.38
# 36755 -1.038664  -84.297752  4.306728  2.757080  10.472126 -34.575267    3.39
# 36756  2.813704 -117.132051 -5.604724 -5.513865  21.273592 -15.485972    3.39
# 36757  3.007371 -102.101501 -0.407086 -4.839696  16.550979 -20.463384    3.47
# 36758       NaN         NaN       NaN       NaN        NaN        NaN     NaN
# 36759  1.304384  -54.554375  8.020162 -0.675826   5.514760 -30.465872    3.21
#
#        sz_bot  hit_distance_sc  launch_speed  launch_angle  effective_speed  \
# 36750    1.61            131.0         105.8           7.0             83.1
# 36751    1.61              NaN           NaN           NaN             81.8
# 36752    1.61            149.0          77.9          72.0             78.9
# 36753     NaN              NaN           NaN           NaN              NaN
# 36754    1.50              NaN           NaN           NaN             80.2
# 36755    1.61              NaN           NaN           NaN             56.7
# 36756    1.61            185.0          75.8          59.0             79.0
# 36757    1.56              NaN           NaN           NaN             68.3
# 36758     NaN              NaN           NaN           NaN              NaN
# 36759    1.65             52.0          87.5           1.0             35.9
#
#        release_spin_rate  release_extension   game_pk  FirstBasemen  \
# 36750             2057.0                5.3  630892.0      452678.0
# 36751             2175.0                5.3  630892.0      452678.0
# 36752             2103.0                5.4  630892.0      452678.0
# 36753                NaN                NaN  630892.0      452678.0
# 36754             2140.0                5.1  630892.0      452678.0
# 36755             1718.0                4.8  630892.0      452678.0
# 36756             2050.0                5.2  630892.0      452678.0
# 36757             1809.0                4.8  630892.0      452678.0
# 36758                NaN                NaN  630892.0      452678.0
# 36759              829.0                4.1  630892.0      452678.0
#
#        SecondBasemen  ThirdBasemen  ShortStop  LeftField  CenterField  \
# 36750       543281.0      669738.0   671277.0   664057.0     572191.0
# 36751       543281.0      669738.0   671277.0   664057.0     572191.0
# 36752       543281.0      669738.0   671277.0   664057.0     572191.0
# 36753       543281.0      669738.0   671277.0   664057.0     572191.0
# 36754       543281.0      669738.0   671277.0   664057.0     572191.0
# 36755       543281.0      669738.0   671277.0   664057.0     572191.0
# 36756       543281.0      669738.0   671277.0   664057.0     572191.0
# 36757       543281.0      669738.0   671277.0   664057.0     572191.0
# 36758       543281.0      669738.0   671277.0   664057.0     572191.0
# 36759       543281.0      669738.0   671277.0   664057.0     572191.0
#
#        RightField  release_pos_y  estimated_ba_using_speedangle  \
# 36750    665742.0          55.16                          0.643
# 36751    665742.0          55.24                            NaN
# 36752    665742.0          55.15                            NaN
# 36753    665742.0            NaN                            NaN
# 36754    665742.0          55.37                            NaN
# 36755    665742.0          55.65                            NaN
# 36756    665742.0          55.32                            NaN
# 36757    665742.0          55.73                            NaN
# 36758    665742.0            NaN                            NaN
# 36759    665742.0          56.37                          0.300
#
#        estimated_woba_using_speedangle  woba_value  woba_denom  babip_value  \
# 36750                            0.579         0.9         1.0          1.0
# 36751                              NaN         NaN         NaN          NaN
# 36752                              NaN         NaN         NaN          NaN
# 36753                              NaN         NaN         NaN          NaN
# 36754                              NaN         NaN         NaN          NaN
# 36755                              NaN         NaN         NaN          NaN
# 36756                              NaN         NaN         NaN          NaN
# 36757                              NaN         NaN         NaN          NaN
# 36758                              NaN         NaN         NaN          NaN
# 36759                            0.270         0.9         1.0          0.0
#
#        iso_value  launch_speed_angle  at_bat_number  pitch_number pitch_name  \
# 36750        0.0                 4.0           74.0           9.0   Changeup
# 36751        NaN                 NaN           74.0           8.0   Changeup
# 36752        NaN                 NaN           74.0           7.0  Curveball
# 36753        NaN                 NaN           74.0           6.0        NaN
# 36754        NaN                 NaN           74.0           5.0   Changeup
# 36755        NaN                 NaN           74.0           4.0  Curveball
# 36756        NaN                 NaN           74.0           3.0  Curveball
# 36757        NaN                 NaN           74.0           2.0  Curveball
# 36758        NaN                 NaN           74.0           1.0        NaN
# 36759        0.0                 2.0           73.0           1.0  Curveball
#
#        home_score  away_score  bat_score  fld_score  post_away_score  \
# 36750         1.0        12.0       12.0        1.0             12.0
# 36751         1.0        12.0       12.0        1.0             12.0
# 36752         1.0        12.0       12.0        1.0             12.0
# 36753         1.0        12.0       12.0        1.0             12.0
# 36754         1.0        12.0       12.0        1.0             12.0
# 36755         1.0        12.0       12.0        1.0             12.0
# 36756         1.0        12.0       12.0        1.0             12.0
# 36757         1.0        12.0       12.0        1.0             12.0
# 36758         1.0        12.0       12.0        1.0             12.0
# 36759         1.0        12.0       12.0        1.0             12.0
#
#        post_home_score  post_bat_score  post_fld_score if_fielding_alignment  \
# 36750              1.0            12.0             1.0         Infield shift
# 36751              1.0            12.0             1.0         Infield shift
# 36752              1.0            12.0             1.0         Infield shift
# 36753              1.0            12.0             1.0                   NaN
# 36754              1.0            12.0             1.0         Infield shift
# 36755              1.0            12.0             1.0         Infield shift
# 36756              1.0            12.0             1.0         Infield shift
# 36757              1.0            12.0             1.0         Infield shift
# 36758              1.0            12.0             1.0         Infield shift
# 36759              1.0            12.0             1.0              Standard
#
#       of_fielding_alignment    batter_name count strike_attempt
# 36750             Strategic  Mickey Moniak   4-2             ob
# 36751             Strategic  Mickey Moniak   4-2         strike
# 36752             Strategic  Mickey Moniak   4-2         strike
# 36753                   NaN  Mickey Moniak   3-2           ball
# 36754             Strategic  Mickey Moniak   2-2           ball
# 36755             Strategic  Mickey Moniak   1-2           ball
# 36756             Strategic  Mickey Moniak   1-1         strike
# 36757             Strategic  Mickey Moniak   1-0         strike
# 36758             Strategic  Mickey Moniak   0-0           ball
# 36759             Strategic  Scott Kingery   0-0             ob

# %%
# Type of Game. E = Exhibition, S = Spring Training, R = Regular Season, F = Wild Card, D = Divisional Series, L = League Championship Series, W = World Series
mlb2020['game_type'].unique()
# Out:
# array(['W', 'L', 'D', 'F', 'R'], dtype=object)

# %% [markdown]
# ---
# # Functions
#
# The functions below will help in grabbing the stats we want from certain players.
#
# #### Get Pitcher Name Stats
#
# ```python
# def pitcher_stats(name ,df):
#     '''
#     name: name of pitcher as a string
#     df: dataframe of the season you want to check
#     '''
#     try:
#         return df[df['pitcher_name']==name]
#     except:
#         return 'Did not play this season or you misspelled his name.'
# ```
#
# #### Get Batter Stats
#
# ```python
# def batter_stats(name ,df):
#     '''
#     name: name of batter as a string
#     df: dataframe of the season you want to check
#     '''
#     try:
#         return df[df['batter_name']==name]
#     except:
#         return 'Did not play this season or you misspelled his name.'
# ```

# %%
# Example of grabbing pitcher stats
julio_urias = pitcher_stats('Julio Urias', mlb2020)

yu_darvish = pitcher_stats('Yu Darvish', mlb2020)

# Example of grabbing batter stats
justin_turner = batter_stats('Justin Turner', mlb2020)

joey_gallo = batter_stats('Joey Gallo', mlb2020)

freddy = batter_stats('Freddie Freeman', mlb2020)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-5ccfc61d8418> in <module>
#       1 # Example of grabbing pitcher stats
# ----> 2 julio_urias = pitcher_stats('Julio Urias', mlb2020)
#       3
#       4 yu_darvish = pitcher_stats('Yu Darvish', mlb2020)
#       5
#
# NameError: name 'pitcher_stats' is not defined

# %%
# Find out how a homer is scored
# events == 'home_run'
mookie = batter_stats('Mookie Betts', mlb2020)

# %%
julio_urias.sample(10)
# Out:
#         index pitch_type  game_date  release_speed  release_pos_x  \
# 248733   9599         CH 2020-08-01           84.5           1.63
# 127754   6264         CU 2020-09-01           78.7           1.38
# 814       555         FF 2020-10-24           95.2           1.68
# 268350  10361         FF 2020-07-26           95.9           1.52
# 225040  12530         CH 2020-08-07           84.2           1.80
# 106036  11320         FF 2020-09-06           93.0           1.53
# 14064    2562         FF 2020-09-30           94.4           1.60
# 248554   7624         FF 2020-08-01           94.7           1.25
# 4409      452         FF 2020-10-14           95.1           1.60
# 1762      308         FF 2020-10-18           95.0           1.79
#
#         release_pos_z pitcher_name    batter   pitcher     events  \
# 248733           6.02  Julio Urias  545121.0  628711.0        NaN
# 127754           6.11  Julio Urias  608348.0  628711.0        NaN
# 814              6.13  Julio Urias  622534.0  628711.0  strikeout
# 268350           6.14  Julio Urias  527038.0  628711.0        NaN
# 225040           5.87  Julio Urias  596103.0  628711.0        NaN
# 106036           6.04  Julio Urias  461314.0  628711.0        NaN
# 14064            6.01  Julio Urias  641924.0  628711.0  strikeout
# 248554           6.13  Julio Urias  572233.0  628711.0        NaN
# 4409             6.09  Julio Urias  622666.0  628711.0        NaN
# 1762             5.97  Julio Urias  645277.0  628711.0        NaN
#
#             description  zone                                       des  \
# 248733             ball  14.0                                       NaN
# 127754    called_strike   5.0                                       NaN
# 814     swinging_strike   6.0     Manuel Margot strikes out swinging.
# 268350  swinging_strike   4.0                                       NaN
# 225040             foul  14.0                                       NaN
# 106036             foul   9.0                                       NaN
# 14064   swinging_strike   1.0  Jacob Nottingham strikes out swinging.
# 248554             ball   4.0                                       NaN
# 4409               foul   5.0                                       NaN
# 1762               foul   5.0                                       NaN
#
#        game_type stand p_throws home_team away_team type  hit_location  \
# 248733         R     R        L       ARI       LAD    B           NaN
# 127754         R     R        L       LAD       ARI    S           NaN
# 814            W     R        L        TB       LAD    S           2.0
# 268350         R     R        L       LAD        SF    S           NaN
# 225040         R     R        L       LAD        SF    S           NaN
# 106036         R     R        L       LAD       COL    S           NaN
# 14064          F     R        L       LAD       MIL    S           2.0
# 248554         R     R        L       ARI       LAD    B           NaN
# 4409           L     R        L       ATL       LAD    S           NaN
# 1762           L     R        L       LAD       ATL    S           NaN
#
#        bb_type  balls  strikes  game_year  pfx_x  pfx_z  plate_x  plate_z  \
# 248733     NaN    1.0      0.0     2020.0    1.5    0.6     1.28     1.04
# 127754     NaN    0.0      0.0     2020.0   -1.8   -0.2     0.11     2.29
# 814        NaN    1.0      2.0     2020.0    0.4    1.4     0.52     2.68
# 268350     NaN    1.0      1.0     2020.0    0.4    1.5    -0.62     2.70
# 225040     NaN    1.0      2.0     2020.0    1.1    0.4     1.35     2.12
# 106036     NaN    0.0      0.0     2020.0    0.4    1.6     0.44     1.81
# 14064      NaN    0.0      2.0     2020.0    0.4    1.4    -0.66     3.08
# 248554     NaN    0.0      0.0     2020.0    0.2    1.7    -0.67     2.25
# 4409       NaN    3.0      2.0     2020.0    0.4    1.7    -0.20     2.57
# 1762       NaN    2.0      1.0     2020.0    0.2    1.5     0.19     2.43
#
#         on_3b     on_2b     on_1b  outs_when_up  inning inning_topbot  hc_x  \
# 248733    NaN       NaN       NaN           1.0     1.0           Bot   NaN
# 127754    NaN       NaN       NaN           1.0     5.0           Top   NaN
# 814       NaN       NaN       NaN           0.0     2.0           Bot   NaN
# 268350    NaN  643289.0  573262.0           0.0     3.0           Top   NaN
# 225040    NaN       NaN       NaN           0.0     1.0           Top   NaN
# 106036    NaN       NaN       NaN           1.0     4.0           Top   NaN
# 14064     NaN       NaN       NaN           1.0     7.0           Top   NaN
# 248554    NaN       NaN       NaN           2.0     6.0           Bot   NaN
# 4409      NaN       NaN       NaN           2.0     2.0           Bot   NaN
# 1762      NaN       NaN       NaN           0.0     9.0           Top   NaN
#
#         hc_y   Catcher       vx0         vy0       vz0         ax         ay  \
# 248733   NaN  669257.0 -3.709604 -122.826406 -6.324772  15.535001  26.126769
# 127754   NaN  669257.0  0.517680 -114.660385 -1.124552 -15.647237  22.460211
# 814      NaN  669257.0 -3.856057 -138.571252 -6.542046   5.881535  30.963736
# 268350   NaN  669257.0 -6.594654 -139.423410 -6.844423   7.308891  32.038307
# 225040   NaN  669257.0 -3.292470 -122.659750 -3.223409  12.165704  22.348094
# 106036   NaN  669257.0 -3.674183 -135.218839 -8.591251   5.957163  27.690518
# 14064    NaN  669257.0 -6.775679 -137.295378 -5.006261   6.844588  29.641631
# 248554   NaN  669257.0 -5.331974 -137.543257 -8.145142   3.375654  32.537694
# 4409     NaN  669257.0 -5.542055 -138.278418 -7.291456   6.345034  31.922389
# 1762     NaN  669257.0 -4.673177 -138.353185 -6.930400   3.987723  26.486498
#
#                az  sz_top  sz_bot  hit_distance_sc  launch_speed  \
# 248733 -24.986765    3.36    1.69              NaN           NaN
# 127754 -33.606471    3.09    1.59              NaN           NaN
# 814    -12.479980    3.24    1.52              NaN           NaN
# 268350 -11.073499    3.24    1.56              NaN           NaN
# 225040 -27.438998    3.40    1.65              NaN           NaN
# 106036 -10.292037    3.61    1.82            236.0          73.0
# 14064  -13.657578    3.41    1.62              NaN           NaN
# 248554  -8.898269    3.40    1.65              NaN           NaN
# 4409    -8.975528    3.60    1.76              NaN           NaN
# 1762   -11.952457    3.18    1.51              NaN           NaN
#
#         launch_angle  effective_speed  release_spin_rate  release_extension  \
# 248733           NaN             83.6             1951.0                5.9
# 127754           NaN             77.7             2830.0                5.6
# 814              NaN             94.0             2477.0                5.5
# 268350           NaN             94.9             2494.0                5.8
# 225040           NaN             84.0             1664.0                5.9
# 106036          37.0             92.2             2562.0                5.7
# 14064            NaN             93.7             2445.0                5.9
# 248554           NaN             93.5             2570.0                5.8
# 4409             NaN             94.1             2469.0                5.8
# 1762             NaN             94.7             2466.0                5.8
#
#          game_pk  FirstBasemen  SecondBasemen  ThirdBasemen  ShortStop  \
# 248733  630100.0      607461.0       571970.0      621458.0   608369.0
# 127754  631355.0      571970.0       666158.0      621458.0   608369.0
# 814     635897.0      571970.0       571771.0      457759.0   608369.0
# 268350  631384.0      571970.0       571771.0      457759.0   608369.0
# 225040  631358.0      571970.0       621035.0      621458.0   608369.0
# 106036  631344.0      641355.0       666158.0      571970.0   608369.0
# 14064   635893.0      571970.0       621035.0      457759.0   608369.0
# 248554  630100.0      607461.0       571970.0      621458.0   621035.0
# 4409    635880.0      571970.0       621035.0      621458.0   608369.0
# 1762    635888.0      571970.0       571771.0      457759.0   608369.0
#
#         LeftField  CenterField  RightField  release_pos_y  \
# 248733   592626.0     572041.0    605141.0          54.57
# 127754   571771.0     621035.0    605141.0          54.89
# 814      621035.0     572041.0    605141.0          54.96
# 268350   621035.0     641355.0    605141.0          54.67
# 225040   592626.0     641355.0    605141.0          54.61
# 106036   572041.0     621035.0    571771.0          54.76
# 14064    572041.0     641355.0    605141.0          54.64
# 248554   592626.0     572041.0    605141.0          54.67
# 4409     592626.0     641355.0    605141.0          54.66
# 1762     621035.0     641355.0    605141.0          54.73
#
#         estimated_ba_using_speedangle  estimated_woba_using_speedangle  \
# 248733                            NaN                              NaN
# 127754                            NaN                              NaN
# 814                               NaN                              NaN
# 268350                            NaN                              NaN
# 225040                            NaN                              NaN
# 106036                            NaN                              NaN
# 14064                             NaN                              NaN
# 248554                            NaN                              NaN
# 4409                              NaN                              NaN
# 1762                              NaN                              NaN
#
#         woba_value  woba_denom  babip_value  iso_value  launch_speed_angle  \
# 248733         NaN         NaN          NaN        NaN                 NaN
# 127754         NaN         NaN          NaN        NaN                 NaN
# 814            0.0         1.0          0.0        0.0                 NaN
# 268350         NaN         NaN          NaN        NaN                 NaN
# 225040         NaN         NaN          NaN        NaN                 NaN
# 106036         NaN         NaN          NaN        NaN                 NaN
# 14064          0.0         1.0          0.0        0.0                 NaN
# 248554         NaN         NaN          NaN        NaN                 NaN
# 4409           NaN         NaN          NaN        NaN                 NaN
# 1762           NaN         NaN          NaN        NaN                 NaN
#
#         at_bat_number  pitch_number       pitch_name  home_score  away_score  \
# 248733            6.0           2.0         Changeup         0.0         0.0
# 127754           39.0           1.0        Curveball         2.0         1.0
# 814              13.0           5.0  4-Seam Fastball         0.0         1.0
# 268350           19.0           3.0  4-Seam Fastball         0.0         0.0
# 225040            1.0           4.0         Changeup         0.0         0.0
# 106036           28.0           1.0  4-Seam Fastball         2.0         2.0
# 14064            54.0           3.0  4-Seam Fastball         3.0         2.0
# 248554           54.0           1.0  4-Seam Fastball         2.0         8.0
# 4409             26.0          11.0  4-Seam Fastball         0.0        12.0
# 1762             70.0           4.0  4-Seam Fastball         4.0         3.0
#
#         bat_score  fld_score  post_away_score  post_home_score  \
# 248733        0.0        0.0              0.0              0.0
# 127754        1.0        2.0              1.0              2.0
# 814           0.0        1.0              1.0              0.0
# 268350        0.0        0.0              0.0              0.0
# 225040        0.0        0.0              0.0              0.0
# 106036        2.0        2.0              2.0              2.0
# 14064         2.0        3.0              2.0              3.0
# 248554        2.0        8.0              8.0              2.0
# 4409          0.0       12.0             12.0              0.0
# 1762          3.0        4.0              3.0              4.0
#
#         post_bat_score  post_fld_score if_fielding_alignment  \
# 248733             0.0             0.0         Infield shift
# 127754             1.0             2.0         Infield shift
# 814                0.0             1.0              Standard
# 268350             0.0             0.0              Standard
# 225040             0.0             0.0              Standard
# 106036             2.0             2.0         Infield shift
# 14064              2.0             3.0              Standard
# 248554             2.0             8.0         Infield shift
# 4409               0.0            12.0              Standard
# 1762               3.0             4.0             Strategic
#
#        of_fielding_alignment       batter_name count strike_attempt
# 248733              Standard   Ildemaro Vargas   1-0           ball
# 127754              Standard      Carson Kelly   0-0         strike
# 814                 Standard     Manuel Margot   1-2         strike
# 268350              Standard     Wilmer Flores   1-1         strike
# 225040              Standard     Austin Slater   1-2         strike
# 106036              Standard         Matt Kemp   0-0         strike
# 14064               Standard  Jacob Nottingham   0-2         strike
# 248554              Standard  Christian Walker   0-0           ball
# 4409                Standard     Johan Camargo   3-2         strike
# 1762                Standard      Ozzie Albies   2-1         strike

# %%
julio_urias['strike_attempt'].value_counts(normalize=True)
# Out:
# strike    0.496779
# ball      0.332528
# out       0.122383
# ob        0.048309
# Name: strike_attempt, dtype: float64

# %%
julio_urias['description'].value_counts(normalize=True)
# Out:
# ball                       0.318841
# foul                       0.194847
# called_strike              0.159420
# swinging_strike            0.123994
# hit_into_play              0.122383
# hit_into_play_no_out       0.033011
# hit_into_play_score        0.015298
# blocked_ball               0.013688
# foul_tip                   0.012882
# swinging_strike_blocked    0.005636
# Name: description, dtype: float64

# %%
joey_gallo['strike_attempt'].value_counts(normalize=True)
# Out:
# strike    0.474737
# ball      0.401053
# out       0.080000
# ob        0.044211
# Name: strike_attempt, dtype: float64

# %%
freddy['strike_attempt'].value_counts(normalize=True)
# Out:
# strike    0.414018
# ball      0.408313
# out       0.103504
# ob        0.074165
# Name: strike_attempt, dtype: float64

# %%
justin_turner['strike_attempt'].value_counts(normalize=True)
# Out:
# strike    0.429150
# ball      0.384615
# out       0.110324
# ob        0.075911
# Name: strike_attempt, dtype: float64
