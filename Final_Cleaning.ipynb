# %% [markdown]
# Any and all data was scraped from the Baseball savant website [here](https://baseballsavant.mlb.com/) using the `pybaseball` library.

# %% [markdown]
# # Imports

# %%
import pybaseball as pb
import project_baseball as project

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# Import Data
mlb2020 = pd.read_csv('data/2020mlb.csv')
mlb2020.shape
# Out:
# (279660, 90)

# %% [markdown]
# For a full explanation of what the data dictionary is, go [here](https://baseballsavant.mlb.com/csv-docs).

# %% [markdown]
# # Cleaning
#
# ---
# The cleaning will be shown on the `mlb2020` dataset but will be applied on past data as well.

# %% [markdown]
# This function will rename the fielders columns from the `project_baseball.py` file.
#
# ```python
# def renaming_fielders(mlb):
#     mlb.rename(columns={'player_name':'Pitcher_name'}, inplace=True) # Rename pitcher
#     mlb.rename(columns={'fielder_2':'Catcher'}, inplace=True) # rename Catcher
#     # Rename other fielders
#     mlb.rename(columns={'fielder_3':'FirstBasemen',
#                         'fielder_4':'SecondBasemen',
#                         'fielder_5':'ThirdBasemen',
#                         'fielder_6':'ShortStop',
#                         'fielder_7':'LeftField',
#                         'fielder_8':'CenterField',
#                         'fielder_9':'RightField'}, inplace=True)
#     mlb.rename(columns={'batter':'batter_id',
#                        'pitcher':'pitcher_id'})
#     return mlb
# ```

# %%
project.renaming_fielders(mlb2020)
# Out:
#         index pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FF  2020-10-27           96.7           1.58
# 1           1         FF  2020-10-27           94.1           2.91
# 2           2         FF  2020-10-27           94.9           1.77
# 3           3         FF  2020-10-27           94.4           1.66
# 4           4         CU  2020-10-27           81.4           1.46
# ...       ...        ...         ...            ...            ...
# 279655  20155         FF  2020-07-23           96.1          -3.28
# 279656  20157         CU  2020-07-23           79.7          -3.36
# 279657  20159         FF  2020-07-23           96.7          -3.21
# 279658  20162         FF  2020-07-23           96.1          -3.38
# 279659  20163         FF  2020-07-23           95.3          -3.28
#
#         release_pos_z  Pitcher_name  batter_id  pitcher_id     events  \
# 0                5.99   Julio Urias   642715.0    628711.0  strikeout
# 1                5.45   Julio Urias   642715.0    628711.0        NaN
# 2                6.02   Julio Urias   642715.0    628711.0        NaN
# 3                5.93   Julio Urias   670712.0    628711.0  strikeout
# 4                6.06   Julio Urias   670712.0    628711.0        NaN
# ...               ...           ...        ...         ...        ...
# 279655           5.13  Max Scherzer   543305.0    453286.0  field_out
# 279656           5.48  Max Scherzer   543305.0    453286.0        NaN
# 279657           5.33  Max Scherzer   543305.0    453286.0        NaN
# 279658           5.33  Max Scherzer   543305.0    453286.0        NaN
# 279659           5.47  Max Scherzer   543305.0    453286.0        NaN
#
#             description  spin_dir  spin_rate_deprecated  \
# 0         called_strike       NaN                   NaN
# 1         called_strike       NaN                   NaN
# 2       swinging_strike       NaN                   NaN
# 3         called_strike       NaN                   NaN
# 4                  ball       NaN                   NaN
# ...                 ...       ...                   ...
# 279655    hit_into_play       NaN                   NaN
# 279656    called_strike       NaN                   NaN
# 279657    called_strike       NaN                   NaN
# 279658             ball       NaN                   NaN
# 279659             ball       NaN                   NaN
#
#         break_angle_deprecated  break_length_deprecated  zone  \
# 0                          NaN                      NaN   4.0
# 1                          NaN                      NaN   1.0
# 2                          NaN                      NaN   2.0
# 3                          NaN                      NaN   4.0
# 4                          NaN                      NaN  13.0
# ...                        ...                      ...   ...
# 279655                     NaN                      NaN   5.0
# 279656                     NaN                      NaN   7.0
# 279657                     NaN                      NaN   9.0
# 279658                     NaN                      NaN  11.0
# 279659                     NaN                      NaN  11.0
#
#                                                       des game_type stand  \
# 0                   Willy Adames called out on strikes.           W     R
# 1                                                     NaN         W     R
# 2                                                     NaN         W     R
# 3                  Mike Brosseau called out on strikes.           W     R
# 4                                                     NaN         W     R
# ...                                                   ...       ...   ...
# 279655  Aaron Hicks grounds out sharply, second basema...         R     L
# 279656                                                NaN         R     L
# 279657                                                NaN         R     L
# 279658                                                NaN         R     L
# 279659                                                NaN         R     L
#
#        p_throws home_team away_team type  hit_location      bb_type  balls  \
# 0             L       LAD        TB    S           2.0          NaN    0.0
# 1             L       LAD        TB    S           NaN          NaN    0.0
# 2             L       LAD        TB    S           NaN          NaN    0.0
# 3             L       LAD        TB    S           2.0          NaN    3.0
# 4             L       LAD        TB    B           NaN          NaN    2.0
# ...         ...       ...       ...  ...           ...          ...    ...
# 279655        R       WSH       NYY    X           4.0  ground_ball    2.0
# 279656        R       WSH       NYY    S           NaN          NaN    2.0
# 279657        R       WSH       NYY    S           NaN          NaN    2.0
# 279658        R       WSH       NYY    B           NaN          NaN    1.0
# 279659        R       WSH       NYY    B           NaN          NaN    0.0
#
#         strikes  game_year  pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  \
# 0           2.0     2020.0    0.2    1.6    -0.53     2.29    NaN    NaN
# 1           1.0     2020.0    0.8    1.3    -0.55     3.03    NaN    NaN
# 2           0.0     2020.0    0.2    1.5    -0.04     3.32    NaN    NaN
# 3           2.0     2020.0    0.3    1.5    -0.37     2.15    NaN    NaN
# 4           2.0     2020.0   -1.7   -0.2    -0.14     0.96    NaN    NaN
# ...         ...        ...    ...    ...      ...      ...    ...    ...
# 279655      2.0     2020.0   -0.8    1.2    -0.19     2.41    NaN    NaN
# 279656      1.0     2020.0    0.9   -0.8    -0.41     1.85    NaN    NaN
# 279657      0.0     2020.0   -0.8    1.3     0.48     2.07    NaN    NaN
# 279658      0.0     2020.0   -0.8    1.4    -1.17     2.75    NaN    NaN
# 279659      0.0     2020.0   -0.9    1.2    -1.16     3.06    NaN    NaN
#
#         on_1b  outs_when_up  inning inning_topbot    hc_x    hc_y  \
# 0         NaN           2.0     9.0           Top     NaN     NaN
# 1         NaN           2.0     9.0           Top     NaN     NaN
# 2         NaN           2.0     9.0           Top     NaN     NaN
# 3         NaN           1.0     9.0           Top     NaN     NaN
# 4         NaN           1.0     9.0           Top     NaN     NaN
# ...       ...           ...     ...           ...     ...     ...
# 279655    NaN           0.0     1.0           Top  163.49  140.27
# 279656    NaN           0.0     1.0           Top     NaN     NaN
# 279657    NaN           0.0     1.0           Top     NaN     NaN
# 279658    NaN           0.0     1.0           Top     NaN     NaN
# 279659    NaN           0.0     1.0           Top     NaN     NaN
#
#         tfs_deprecated  tfs_zulu_deprecated   Catcher  umpire  sv_id  \
# 0                  NaN                  NaN  605131.0     NaN    NaN
# 1                  NaN                  NaN  605131.0     NaN    NaN
# 2                  NaN                  NaN  605131.0     NaN    NaN
# 3                  NaN                  NaN  605131.0     NaN    NaN
# 4                  NaN                  NaN  605131.0     NaN    NaN
# ...                ...                  ...       ...     ...    ...
# 279655             NaN                  NaN  435559.0     NaN    NaN
# 279656             NaN                  NaN  435559.0     NaN    NaN
# 279657             NaN                  NaN  435559.0     NaN    NaN
# 279658             NaN                  NaN  435559.0     NaN    NaN
# 279659             NaN                  NaN  435559.0     NaN    NaN
#
#               vx0         vy0       vz0         ax         ay         az  \
# 0       -5.950264 -140.490456 -7.897391   3.772000  32.321911  -8.981441
# 1      -10.560246 -136.599519 -3.429867  11.723598  29.183810 -15.237217
# 2       -5.199252 -138.098234 -4.637970   4.158758  30.838499 -12.535677
# 3       -5.843595 -137.294295 -7.414897   4.754147  30.016237 -11.778755
# 4       -0.383207 -118.447810 -4.454166 -15.553576  24.451936 -32.892744
# ...           ...         ...       ...        ...        ...        ...
# 279655   9.899700 -139.626080 -4.473902 -12.016982  30.128689 -14.962333
# 279656   4.691537 -116.064292  0.319935   7.680712  22.130450 -39.867212
# 279657  11.547336 -140.289508 -5.998194 -12.798480  30.880442 -14.099707
# 279658   7.600636 -139.767747 -4.483222 -11.964765  30.151437 -12.476899
# 279659   7.498831 -138.723511 -3.506988 -12.699151  28.237021 -15.689358
#
#         sz_top  sz_bot  hit_distance_sc  launch_speed  launch_angle  \
# 0         3.50    1.69              NaN           NaN           NaN
# 1         3.50    1.69              NaN           NaN           NaN
# 2         3.50    1.69              NaN           NaN           NaN
# 3         3.34    1.53              NaN           NaN           NaN
# 4         3.34    1.53              NaN           NaN           NaN
# ...        ...     ...              ...           ...           ...
# 279655    3.41    1.56             91.0         106.7           4.0
# 279656    3.51    1.65              NaN           NaN           NaN
# 279657    3.33    1.65              NaN           NaN           NaN
# 279658    3.58    1.75              NaN           NaN           NaN
# 279659    3.85    1.84              NaN           NaN           NaN
#
#         effective_speed  release_spin_rate  release_extension   game_pk  \
# 0                  95.4             2615.0                5.7  635886.0
# 1                  93.4             2470.0                5.9  635886.0
# 2                  94.0             2397.0                5.7  635886.0
# 3                  93.7             2508.0                5.9  635886.0
# 4                  80.2             3031.0                5.7  635886.0
# ...                 ...                ...                ...       ...
# 279655             96.3             2450.0                6.4  630851.0
# 279656             79.6             2846.0                6.2  630851.0
# 279657             96.4             2421.0                6.2  630851.0
# 279658             95.9             2477.0                6.1  630851.0
# 279659             95.7             2484.0                6.3  630851.0
#
#         pitcher.1  fielder_2.1  FirstBasemen  SecondBasemen  ThirdBasemen  \
# 0        628711.0     605131.0      571970.0       571771.0      621458.0
# 1        628711.0     605131.0      571970.0       571771.0      621458.0
# 2        628711.0     605131.0      571970.0       571771.0      621458.0
# 3        628711.0     605131.0      571970.0       571771.0      621458.0
# 4        628711.0     605131.0      571970.0       571771.0      621458.0
# ...           ...          ...           ...            ...           ...
# 279655   453286.0     435559.0      519346.0       516770.0      452678.0
# 279656   453286.0     435559.0      519346.0       516770.0      452678.0
# 279657   453286.0     435559.0      519346.0       516770.0      452678.0
# 279658   453286.0     435559.0      519346.0       516770.0      452678.0
# 279659   453286.0     435559.0      519346.0       516770.0      452678.0
#
#         ShortStop  LeftField  CenterField  RightField  release_pos_y  \
# 0        608369.0   621035.0     641355.0    605141.0          54.82
# 1        608369.0   621035.0     641355.0    605141.0          54.59
# 2        608369.0   621035.0     641355.0    605141.0          54.76
# 3        608369.0   621035.0     641355.0    605141.0          54.60
# 4        608369.0   621035.0     641355.0    605141.0          54.84
# ...           ...        ...          ...         ...            ...
# 279655   607208.0   664057.0     645302.0    594809.0          54.09
# 279656   607208.0   664057.0     645302.0    594809.0          54.28
# 279657   607208.0   664057.0     645302.0    594809.0          54.29
# 279658   607208.0   664057.0     645302.0    594809.0          54.38
# 279659   607208.0   664057.0     645302.0    594809.0          54.21
#
#         estimated_ba_using_speedangle  estimated_woba_using_speedangle  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
# ...                               ...                              ...
# 279655                          0.657                            0.591
# 279656                            NaN                              NaN
# 279657                            NaN                              NaN
# 279658                            NaN                              NaN
# 279659                            NaN                              NaN
#
#         woba_value  woba_denom  babip_value  iso_value  launch_speed_angle  \
# 0              0.0         1.0          0.0        0.0                 NaN
# 1              NaN         NaN          NaN        NaN                 NaN
# 2              NaN         NaN          NaN        NaN                 NaN
# 3              0.0         1.0          0.0        0.0                 NaN
# 4              NaN         NaN          NaN        NaN                 NaN
# ...            ...         ...          ...        ...                 ...
# 279655         0.0         1.0          0.0        0.0                 4.0
# 279656         NaN         NaN          NaN        NaN                 NaN
# 279657         NaN         NaN          NaN        NaN                 NaN
# 279658         NaN         NaN          NaN        NaN                 NaN
# 279659         NaN         NaN          NaN        NaN                 NaN
#
#         at_bat_number  pitch_number       pitch_name  home_score  away_score  \
# 0                65.0           3.0  4-Seam Fastball         3.0         1.0
# 1                65.0           2.0  4-Seam Fastball         3.0         1.0
# 2                65.0           1.0  4-Seam Fastball         3.0         1.0
# 3                64.0           6.0  4-Seam Fastball         3.0         1.0
# 4                64.0           5.0        Curveball         3.0         1.0
# ...               ...           ...              ...         ...         ...
# 279655            1.0           5.0  4-Seam Fastball         0.0         0.0
# 279656            1.0           4.0        Curveball         0.0         0.0
# 279657            1.0           3.0  4-Seam Fastball         0.0         0.0
# 279658            1.0           2.0  4-Seam Fastball         0.0         0.0
# 279659            1.0           1.0  4-Seam Fastball         0.0         0.0
#
#         bat_score  fld_score  post_away_score  post_home_score  \
# 0             1.0        3.0              1.0              3.0
# 1             1.0        3.0              1.0              3.0
# 2             1.0        3.0              1.0              3.0
# 3             1.0        3.0              1.0              3.0
# 4             1.0        3.0              1.0              3.0
# ...           ...        ...              ...              ...
# 279655        0.0        0.0              0.0              0.0
# 279656        0.0        0.0              0.0              0.0
# 279657        0.0        0.0              0.0              0.0
# 279658        0.0        0.0              0.0              0.0
# 279659        0.0        0.0              0.0              0.0
#
#         post_bat_score  post_fld_score if_fielding_alignment  \
# 0                  1.0             3.0              Standard
# 1                  1.0             3.0              Standard
# 2                  1.0             3.0              Standard
# 3                  1.0             3.0              Standard
# 4                  1.0             3.0              Standard
# ...                ...             ...                   ...
# 279655             0.0             0.0         Infield shift
# 279656             0.0             0.0         Infield shift
# 279657             0.0             0.0         Infield shift
# 279658             0.0             0.0         Infield shift
# 279659             0.0             0.0         Infield shift
#
#        of_fielding_alignment
# 0                   Standard
# 1                   Standard
# 2                   Standard
# 3                   Standard
# 4                   Standard
# ...                      ...
# 279655              Standard
# 279656              Standard
# 279657              Standard
# 279658              Standard
# 279659              Standard
#
# [279660 rows x 90 columns]

# %%
# Drop what we don't need

mlb2020.drop(columns=['spin_dir', 'spin_rate_deprecated',
       'break_angle_deprecated', 'break_length_deprecated','tfs_deprecated', 'tfs_zulu_deprecated',
       'umpire', 'sv_id', 'pitcher.1', 'fielder_2.1'], inplace=True)

# %%
# Make datetime
mlb2020['game_date']=pd.to_datetime(mlb2020['game_date'])

# %%
mlb2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279660 entries, 0 to 279659
# Data columns (total 80 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   index                            279660 non-null  int64
#  1   pitch_type                       279089 non-null  object
#  2   game_date                        279660 non-null  datetime64[ns]
#  3   release_speed                    279652 non-null  float64
#  4   release_pos_x                    279652 non-null  float64
#  5   release_pos_z                    279652 non-null  float64
#  6   Pitcher_name                     279660 non-null  object
#  7   batter_id                        279660 non-null  float64
#  8   pitcher_id                       279660 non-null  float64
#  9   events                           70437 non-null   object
#  10  description                      279660 non-null  object
#  11  zone                             279652 non-null  float64
#  12  des                              70436 non-null   object
#  13  game_type                        279660 non-null  object
#  14  stand                            279660 non-null  object
#  15  p_throws                         279660 non-null  object
#  16  home_team                        279660 non-null  object
#  17  away_team                        279660 non-null  object
#  18  type                             279660 non-null  object
#  19  hit_location                     60548 non-null   float64
#  20  bb_type                          46517 non-null   object
#  21  balls                            279660 non-null  float64
#  22  strikes                          279660 non-null  float64
#  23  game_year                        279660 non-null  float64
#  24  pfx_x                            279652 non-null  float64
#  25  pfx_z                            279652 non-null  float64
#  26  plate_x                          279652 non-null  float64
#  27  plate_z                          279652 non-null  float64
#  28  on_3b                            26882 non-null   float64
#  29  on_2b                            53084 non-null   float64
#  30  on_1b                            88406 non-null   float64
#  31  outs_when_up                     279660 non-null  float64
#  32  inning                           279660 non-null  float64
#  33  inning_topbot                    279660 non-null  object
#  34  hc_x                             46468 non-null   float64
#  35  hc_y                             46468 non-null   float64
#  36  Catcher                          279660 non-null  float64
#  37  vx0                              279652 non-null  float64
#  38  vy0                              279652 non-null  float64
#  39  vz0                              279652 non-null  float64
#  40  ax                               279652 non-null  float64
#  41  ay                               279652 non-null  float64
#  42  az                               279652 non-null  float64
#  43  sz_top                           279652 non-null  float64
#  44  sz_bot                           279652 non-null  float64
#  45  hit_distance_sc                  83781 non-null   float64
#  46  launch_speed                     82568 non-null   float64
#  47  launch_angle                     82568 non-null   float64
#  48  effective_speed                  279652 non-null  float64
#  49  release_spin_rate                279306 non-null  float64
#  50  release_extension                279065 non-null  float64
#  51  game_pk                          279660 non-null  float64
#  52  FirstBasemen                     279660 non-null  float64
#  53  SecondBasemen                    279660 non-null  float64
#  54  ThirdBasemen                     279660 non-null  float64
#  55  ShortStop                        279660 non-null  float64
#  56  LeftField                        279660 non-null  float64
#  57  CenterField                      279660 non-null  float64
#  58  RightField                       279660 non-null  float64
#  59  release_pos_y                    279652 non-null  float64
#  60  estimated_ba_using_speedangle    46210 non-null   float64
#  61  estimated_woba_using_speedangle  46210 non-null   float64
#  62  woba_value                       70437 non-null   float64
#  63  woba_denom                       70130 non-null   float64
#  64  babip_value                      70437 non-null   float64
#  65  iso_value                        70437 non-null   float64
#  66  launch_speed_angle               46210 non-null   float64
#  67  at_bat_number                    279660 non-null  float64
#  68  pitch_number                     279660 non-null  float64
#  69  pitch_name                       279089 non-null  object
#  70  home_score                       279660 non-null  float64
#  71  away_score                       279660 non-null  float64
#  72  bat_score                        279660 non-null  float64
#  73  fld_score                        279660 non-null  float64
#  74  post_away_score                  279660 non-null  float64
#  75  post_home_score                  279660 non-null  float64
#  76  post_bat_score                   279660 non-null  float64
#  77  post_fld_score                   279660 non-null  float64
#  78  if_fielding_alignment            279135 non-null  object
#  79  of_fielding_alignment            279135 non-null  object
# dtypes: datetime64[ns](1), float64(62), int64(1), object(16)
# memory usage: 170.7+ MB

# %%
mlb2020.columns
# Out:
# Index(['index', 'pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'Pitcher_name', 'batter_id', 'pitcher_id', 'events',
#        'description', 'zone', 'des', 'game_type', 'stand', 'p_throws',
#        'home_team', 'away_team', 'type', 'hit_location', 'bb_type', 'balls',
#        'strikes', 'game_year', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'on_3b',
#        'on_2b', 'on_1b', 'outs_when_up', 'inning', 'inning_topbot', 'hc_x',
#        'hc_y', 'Catcher', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top',
#        'sz_bot', 'hit_distance_sc', 'launch_speed', 'launch_angle',
#        'effective_speed', 'release_spin_rate', 'release_extension', 'game_pk',
#        'FirstBasemen', 'SecondBasemen', 'ThirdBasemen', 'ShortStop',
#        'LeftField', 'CenterField', 'RightField', 'release_pos_y',
#        'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
#        'woba_value', 'woba_denom', 'babip_value', 'iso_value',
#        'launch_speed_angle', 'at_bat_number', 'pitch_number', 'pitch_name',
#        'home_score', 'away_score', 'bat_score', 'fld_score', 'post_away_score',
#        'post_home_score', 'post_bat_score', 'post_fld_score',
#        'if_fielding_alignment', 'of_fielding_alignment'],
#       dtype='object')

# %%
mlb2020[mlb2020['pitch_type']=='FO']['pitch_name']
# Out:
# 249966    Forkball
# 250000    Forkball
# 252757    Forkball
# Name: pitch_name, dtype: object

# %%
# Rename CS to CU for Curveball
mlb2020['pitch_type']=mlb2020['pitch_type'].map({'CS':'CU',
                           'FF':'FF',
                           'CU':'CU',
                           'CH':'CH',
                           'SI':'SI',
                           'SL':'SL',
                           'FC':'FC',
                           'KC':'KC',
                           'FS':'FS',
                           'KN':'KN',
                           'FO':'FO'})

# %% [markdown]
# # Dealing with Nulls
#
# ---
# I will drop any nulls in the release_speed as it will most likely drop the same nulls in release position, zone, movement, velocity, and acceleration columns.

# %%
# re run to check every so often
pd.DataFrame(mlb2020.isnull().sum()).T
# Out:
#    index  pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         571          0              8              8              8
#
#    Pitcher_name  batter_id  pitcher_id  events  description  zone     des  \
# 0             0          0           0  209223            0     8  209224
#
#    game_type  stand  p_throws  home_team  away_team  type  hit_location  \
# 0          0      0         0          0          0     0        219112
#
#    bb_type  balls  strikes  game_year  pfx_x  pfx_z  plate_x  plate_z   on_3b  \
# 0   233143      0        0          0      8      8        8        8  252778
#
#     on_2b   on_1b  outs_when_up  inning  inning_topbot    hc_x    hc_y  \
# 0  226576  191254             0       0              0  233192  233192
#
#    Catcher  vx0  vy0  vz0  ax  ay  az  sz_top  sz_bot  hit_distance_sc  \
# 0        0    8    8    8   8   8   8       8       8           195879
#
#    launch_speed  launch_angle  effective_speed  release_spin_rate  \
# 0        197092        197092                8                354
#
#    release_extension  game_pk  FirstBasemen  SecondBasemen  ThirdBasemen  \
# 0                595        0             0              0             0
#
#    ShortStop  LeftField  CenterField  RightField  release_pos_y  \
# 0          0          0            0           0              8
#
#    estimated_ba_using_speedangle  estimated_woba_using_speedangle  woba_value  \
# 0                         233450                           233450      209223
#
#    woba_denom  babip_value  iso_value  launch_speed_angle  at_bat_number  \
# 0      209530       209223     209223              233450              0
#
#    pitch_number  pitch_name  home_score  away_score  bat_score  fld_score  \
# 0             0         571           0           0          0          0
#
#    post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0                0                0               0               0
#
#    if_fielding_alignment  of_fielding_alignment
# 0                    525                    525

# %%
# mlb2020 = mlb2020[mlb2020['release_speed'].notnull()].copy() # dropped 8 nulls

# %% [markdown]
# For `pitch_type`, I will replace them with "U". And `pitch_name` is "Unknown"

# %%
mlb2020['pitch_type'].fillna('U', inplace=True)
mlb2020['pitch_name'].fillna('Unknown', inplace=True)

# %% [markdown]
# For fielding alignments, I will also fill with "Unknown". Although they may or may not be vital for our model, I will still apply them.

# %%
mlb2020['if_fielding_alignment'].fillna('Unknown', inplace=True)
mlb2020['of_fielding_alignment'].fillna('Unknown', inplace=True)

# %% [markdown]
# The other NaNs are based on the batter/runners causing hits, steals, or sacrifice flys. Those will remain and may not play a role.

# %% [markdown]
# # Feature Engineering
#
# ---
# ## Strike Attempt
#
# This will show whether or not a pitch result in a strike or other event.

# %%
# Gives a pitch and determines what happens at that particular at-bat

# Good for creating a model to determine if a ball is a strike or not
mlb2020['strike_attempt']=mlb2020['description'].map(
{'called_strike':'strike',
 'swinging_strike':'strike',
 'ball':'ball',
 'foul':'strike', # False in out_via_description
 'hit_into_play':'out',
 'blocked_ball':'ball',
 'hit_into_play_score':'ob',
 'swinging_strike_blocked':'strike',
 'hit_into_play_no_out':'ob',
 'foul_bunt':'strike',
 'foul_tip':'strike',
 'hit_by_pitch':'ob',
 'missed_bunt':'strike',
 'pitchout':'out',
 'bunt_foul_tip':'strike'})

# %%
mlb2020['strike_attempt'].value_counts(normalize=True)
# Out:
# strike    0.463309
# ball      0.367157
# out       0.107009
# ob        0.062526
# Name: strike_attempt, dtype: float64

# %% [markdown]
# ## Create Batter Name
#
# ---
#
#
# ```python
# def batter_name(des):
#     try:
#         name = ' '.join(des.split(' ',2)[:2])
#         return name
#     except:
#         return np.nan
# mlb2020['batter_name'] = mlb2020['des'].map(batter_name)
# mlb2020['batter_name'].ffill(axis=0, inplace=True)
# mlb2020.head()
# ```

# %%
def batter_name(des):
    try:
        name = ' '.join(des.split(' ',2)[:2])
        return name
    except:
        return np.nan

mlb2020['batter_name'] = mlb2020['des'].map(batter_name)
mlb2020['batter_name'].ffill(axis=0, inplace=True)
# mlb2020.head(10)

# %% [markdown]
# Creates an easier way to access the count of a current pitch.
#
# ```python
# def the_count(df):
#
#     df['count'] = df['balls'].map(int).map(str) +"-"+ df['strikes'].map(int).map(str)
#     return df
# ```

# %%
# Convert balls and strikes into `int` then into `str` then concatenate strings to make the count
mlb2020['count'] = mlb2020['balls'].map(int).map(str) +"-"+ mlb2020['strikes'].map(int).map(str)
mlb2020['count'].unique()
# Out:
# array(['0-2', '0-1', '0-0', '3-2', '2-2', '1-2', '1-1', '1-0', '2-1',
#        '2-0', '3-1', '3-0', '4-2'], dtype=object)

# %% [markdown]
# ---
# # Select Features
#
# If I were to go with trying to figure out whether a pitch was a `strike`, `ball`, `out`, or `on-base`, I would select these features.
#
# ```python
# features = ['game_date','pitch_type','Pitcher_name', 'batter_id','pitcher_id','release_speed', 'release_pos_x', 'release_pos_z', 'stand', 'p_throws', 'balls', 'strikes',
#             'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b', 'inning', 'inning_topbot',
#             'effective_speed', 'release_spin_rate', 'release_extension','Catcher','FirstBasemen', 'SecondBasemen', 'ThirdBasemen', 'ShortStop',
#             'LeftField', 'CenterField', 'RightField', 'at_bat_number', 'pitch_number', 'pitch_name',
#             'bat_score', 'fld_score', 'post_bat_score', 'post_fld_score', 'if_fielding_alignment', 'of_fielding_alignment',
#             'count', 'strike_attempt','events','description','type','bb_type','vx0','vy0','vz0',
#             'ax','ay','az','outs_when_up']
#
# target = mlb2020['strike_attempt'] or mlb2020['pitch_name']
# ```

# %% [markdown]
# If I wanted to predict the next pitch of a sequence based on factors such as lineup or current at-bat, I would need these features, most likely.
#
# ```python
# features = <need to select>
#
# target = mlb2020['pitch_name', 'pitch_speed'] # anything after pitch name is debatable
# ```

# %%
features = ['game_date','pitch_type','Pitcher_name','pitcher_id','batter_name', 'batter_id','release_speed', 'release_pos_x', 'release_pos_z', 'stand', 'p_throws', 'balls', 'strikes',
            'pfx_x', 'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b', 'inning', 'inning_topbot',
            'effective_speed', 'release_spin_rate', 'release_extension','Catcher','FirstBasemen', 'SecondBasemen', 'ThirdBasemen', 'ShortStop',
            'LeftField', 'CenterField', 'RightField', 'at_bat_number', 'pitch_number', 'pitch_name',
            'bat_score', 'fld_score', 'post_bat_score', 'post_fld_score', 'if_fielding_alignment', 'of_fielding_alignment',
            'count', 'strike_attempt','events','description','type','bb_type','vx0','vy0','vz0',
            'ax','ay','az','outs_when_up']
mlb2020new = mlb2020[features].copy()

# %% [markdown]
# # Results

# %%
mlb2020new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279660 entries, 0 to 279659
# Data columns (total 55 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   game_date              279660 non-null  datetime64[ns]
#  1   pitch_type             279660 non-null  object
#  2   Pitcher_name           279660 non-null  object
#  3   pitcher_id             279660 non-null  float64
#  4   batter_name            279660 non-null  object
#  5   batter_id              279660 non-null  float64
#  6   release_speed          279652 non-null  float64
#  7   release_pos_x          279652 non-null  float64
#  8   release_pos_z          279652 non-null  float64
#  9   stand                  279660 non-null  object
#  10  p_throws               279660 non-null  object
#  11  balls                  279660 non-null  float64
#  12  strikes                279660 non-null  float64
#  13  pfx_x                  279652 non-null  float64
#  14  pfx_z                  279652 non-null  float64
#  15  plate_x                279652 non-null  float64
#  16  plate_z                279652 non-null  float64
#  17  on_3b                  26882 non-null   float64
#  18  on_2b                  53084 non-null   float64
#  19  on_1b                  88406 non-null   float64
#  20  inning                 279660 non-null  float64
#  21  inning_topbot          279660 non-null  object
#  22  effective_speed        279652 non-null  float64
#  23  release_spin_rate      279306 non-null  float64
#  24  release_extension      279065 non-null  float64
#  25  Catcher                279660 non-null  float64
#  26  FirstBasemen           279660 non-null  float64
#  27  SecondBasemen          279660 non-null  float64
#  28  ThirdBasemen           279660 non-null  float64
#  29  ShortStop              279660 non-null  float64
#  30  LeftField              279660 non-null  float64
#  31  CenterField            279660 non-null  float64
#  32  RightField             279660 non-null  float64
#  33  at_bat_number          279660 non-null  float64
#  34  pitch_number           279660 non-null  float64
#  35  pitch_name             279660 non-null  object
#  36  bat_score              279660 non-null  float64
#  37  fld_score              279660 non-null  float64
#  38  post_bat_score         279660 non-null  float64
#  39  post_fld_score         279660 non-null  float64
#  40  if_fielding_alignment  279660 non-null  object
#  41  of_fielding_alignment  279660 non-null  object
#  42  count                  279660 non-null  object
#  43  strike_attempt         279660 non-null  object
#  44  events                 70437 non-null   object
#  45  description            279660 non-null  object
#  46  type                   279660 non-null  object
#  47  bb_type                46517 non-null   object
#  48  vx0                    279652 non-null  float64
#  49  vy0                    279652 non-null  float64
#  50  vz0                    279652 non-null  float64
#  51  ax                     279652 non-null  float64
#  52  ay                     279652 non-null  float64
#  53  az                     279652 non-null  float64
#  54  outs_when_up           279660 non-null  float64
# dtypes: datetime64[ns](1), float64(39), object(15)
# memory usage: 117.4+ MB

# %%
mlb2020new.sample(5)
# Out:
#         game_date pitch_type     Pitcher_name  pitcher_id    batter_name  \
# 94471  2020-09-09         SL  Sean Reid-Foley    656887.0      Luke Voit
# 130898 2020-08-31         SL      Mike Mayers    594577.0  J.P. Crawford
# 51133  2020-09-19         FF       Josh Osich    592612.0  Jorge Polanco
# 30938  2020-09-24         SI    Jimmy Cordero    622772.0   Tyler Naquin
# 69562  2020-09-15         FF     Dane Dunning    641540.0    Nelson Cruz
#
#         batter_id  release_speed  release_pos_x  release_pos_z stand p_throws  \
# 94471    572228.0           84.4          -1.98           5.61     R        R
# 130898   641487.0           84.7          -2.21           5.86     L        R
# 51133    593871.0           90.1           1.52           6.57     R        L
# 30938    571980.0           97.0          -2.55           6.44     L        R
# 69562    443558.0           91.5          -1.24           6.28     R        R
#
#         balls  strikes  pfx_x  pfx_z  plate_x  plate_z  on_3b     on_2b  \
# 94471     0.0      0.0    0.6   -0.2    -0.32     2.10    NaN       NaN
# 130898    1.0      2.0    0.2   -0.1     0.61     0.51    NaN       NaN
# 51133     1.0      1.0    0.5    1.2    -0.17     3.27    NaN  596146.0
# 30938     1.0      2.0   -1.2    0.9    -1.22     4.41    NaN       NaN
# 69562     1.0      0.0   -0.3    1.2     1.26     2.38    NaN       NaN
#
#            on_1b  inning inning_topbot  effective_speed  release_spin_rate  \
# 94471   518934.0     9.0           Top             85.5             2150.0
# 130898       NaN     7.0           Top             83.8             2129.0
# 51133        NaN     7.0           Top             89.5             2213.0
# 30938   647304.0     7.0           Bot             98.3             2095.0
# 69562        NaN     2.0           Top             91.4             2218.0
#
#         release_extension   Catcher  FirstBasemen  SecondBasemen  \
# 94471                 6.8  543376.0      666971.0       624415.0
# 130898                5.7  621532.0      665120.0       650859.0
# 51133                 5.9  575929.0      519203.0       663538.0
# 30938                 6.9  518735.0      547989.0       570560.0
# 69562                 6.2  543510.0      547989.0       663611.0
#
#         ThirdBasemen  ShortStop  LeftField  CenterField  RightField  \
# 94471       605412.0   542340.0   605233.0     545341.0    641505.0
# 130898      543685.0   592743.0   457708.0     545361.0    666176.0
# 51133       592178.0   595879.0   656941.0     664023.0    518792.0
# 30938       660162.0   641313.0   641553.0     502481.0    608577.0
# 69562       660162.0   641313.0   650391.0     673357.0    641553.0
#
#         at_bat_number  pitch_number       pitch_name  bat_score  fld_score  \
# 94471            68.0           1.0           Slider        5.0        2.0
# 130898           48.0           4.0           Slider        2.0        1.0
# 51133            48.0           3.0  4-Seam Fastball        3.0        1.0
# 30938            52.0           4.0           Sinker        1.0        4.0
# 69562            10.0           2.0  4-Seam Fastball        0.0        1.0
#
#         post_bat_score  post_fld_score if_fielding_alignment  \
# 94471              5.0             2.0         Infield shift
# 130898             2.0             1.0             Strategic
# 51133              3.0             1.0             Strategic
# 30938              1.0             4.0              Standard
# 69562              0.0             1.0         Infield shift
#
#        of_fielding_alignment count strike_attempt     events    description  \
# 94471               Standard   0-0            out  field_out  hit_into_play
# 130898              Standard   1-2           ball        NaN           ball
# 51133               Standard   1-1         strike        NaN           foul
# 30938               Standard   1-2           ball        NaN           ball
# 69562              Strategic   1-0           ball        NaN           ball
#
#        type      bb_type       vx0         vy0       vz0         ax  \
# 94471     X  ground_ball  2.713948 -122.937856 -1.411092   5.524388
# 130898    B          NaN  6.034160 -123.238988 -5.921340   1.246628
# 51133     S          NaN -5.288136 -131.133612 -4.704346   7.328119
# 30938     B          NaN  6.316592 -141.210976 -1.884435 -17.029848
# 69562     B          NaN  6.974418 -133.093492 -6.442432  -5.312903
#
#                ay         az  outs_when_up
# 94471   22.406635 -34.456867           0.0
# 130898  24.231355 -32.038887           1.0
# 51133   27.873433 -17.878928           0.0
# 30938   30.544197 -20.536807           0.0
# 69562   27.462710 -17.286414           0.0

# %%
# Save to new csv
mlb2020new.to_csv('data/2020cleaned.csv', index=False)

# %%
check = pd.read_csv('data/cleaned2020.csv')

# %%
check.head()
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         FF  2020-10-27           96.7           1.58           5.99
# 1      1         FF  2020-10-27           94.1           2.91           5.45
# 2      2         FF  2020-10-27           94.9           1.77           6.02
# 3      3         FF  2020-10-27           94.4           1.66           5.93
# 4      4         CU  2020-10-27           81.4           1.46           6.06
#
#    player_name    batter     events      description stand p_throws  balls  \
# 0  Julio Urias  642715.0  strikeout    called_strike     R        L    0.0
# 1  Julio Urias  642715.0        NaN    called_strike     R        L    0.0
# 2  Julio Urias  642715.0        NaN  swinging_strike     R        L    0.0
# 3  Julio Urias  670712.0  strikeout    called_strike     R        L    3.0
# 4  Julio Urias  670712.0        NaN             ball     R        L    2.0
#
#    strikes type bb_type        vx0         vy0       vz0         ax  \
# 0      2.0    S     NaN  -5.950264 -140.490456 -7.897391   3.772000
# 1      1.0    S     NaN -10.560246 -136.599519 -3.429867  11.723598
# 2      0.0    S     NaN  -5.199252 -138.098234 -4.637970   4.158758
# 3      2.0    S     NaN  -5.843595 -137.294295 -7.414897   4.754147
# 4      2.0    B     NaN  -0.383207 -118.447810 -4.454166 -15.553576
#
#           ay         az  pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  \
# 0  32.321911  -8.981441    0.2    1.6    -0.53     2.29    NaN    NaN    NaN
# 1  29.183810 -15.237217    0.8    1.3    -0.55     3.03    NaN    NaN    NaN
# 2  30.838499 -12.535677    0.2    1.5    -0.04     3.32    NaN    NaN    NaN
# 3  30.016237 -11.778755    0.3    1.5    -0.37     2.15    NaN    NaN    NaN
# 4  24.451936 -32.892744   -1.7   -0.2    -0.14     0.96    NaN    NaN    NaN
#
#    outs_when_up  inning inning_topbot  effective_speed   pitcher  fielder_2  \
# 0           2.0     9.0           Top             95.4  628711.0   605131.0
# 1           2.0     9.0           Top             93.4  628711.0   605131.0
# 2           2.0     9.0           Top             94.0  628711.0   605131.0
# 3           1.0     9.0           Top             93.7  628711.0   605131.0
# 4           1.0     9.0           Top             80.2  628711.0   605131.0
#
#    fielder_3  fielder_4  fielder_5  fielder_6  fielder_7  fielder_8  \
# 0   571970.0   571771.0   621458.0   608369.0   621035.0   641355.0
# 1   571970.0   571771.0   621458.0   608369.0   621035.0   641355.0
# 2   571970.0   571771.0   621458.0   608369.0   621035.0   641355.0
# 3   571970.0   571771.0   621458.0   608369.0   621035.0   641355.0
# 4   571970.0   571771.0   621458.0   608369.0   621035.0   641355.0
#
#    fielder_9  at_bat_number  pitch_number       pitch_name  bat_score  \
# 0   605141.0           65.0           3.0  4-Seam Fastball        1.0
# 1   605141.0           65.0           2.0  4-Seam Fastball        1.0
# 2   605141.0           65.0           1.0  4-Seam Fastball        1.0
# 3   605141.0           64.0           6.0  4-Seam Fastball        1.0
# 4   605141.0           64.0           5.0        Curveball        1.0
#
#    fld_score  post_bat_score  post_fld_score if_fielding_alignment  \
# 0        3.0             1.0             3.0              Standard
# 1        3.0             1.0             3.0              Standard
# 2        3.0             1.0             3.0              Standard
# 3        3.0             1.0             3.0              Standard
# 4        3.0             1.0             3.0              Standard
#
#   of_fielding_alignment home_team away_team  first  second  third
# 0              Standard       LAD        TB      0       0      0
# 1              Standard       LAD        TB      0       0      0
# 2              Standard       LAD        TB      0       0      0
# 3              Standard       LAD        TB      0       0      0
# 4              Standard       LAD        TB      0       0      0

# %%
for col in mlb2020new.columns:
    if col not in check.columns:
        print(col)
# Out:
# Pitcher_name
# pitcher_id
# batter_name
# batter_id
# release_spin_rate
# release_extension
# Catcher
# FirstBasemen
# SecondBasemen
# ThirdBasemen
# ShortStop
# LeftField
# CenterField
# RightField
# count
# strike_attempt

# %%
check[check['type']=='X']['events'].unique()
# Out:
# array(['field_out', 'grounded_into_double_play', 'home_run', 'double',
#        'single', 'fielders_choice', 'triple', 'force_out', 'sac_bunt',
#        'sac_fly', 'fielders_choice_out', 'double_play', 'field_error',
#        'sac_fly_double_play', 'triple_play'], dtype=object)

# %%
# compare what is in original cleaned and add it into mlb2020new
for col in check.columns:
    if col not in mlb2020new.columns:
        print(col)
# Out:
# index
# player_name
# batter
# pitcher
# fielder_2
# fielder_3
# fielder_4
# fielder_5
# fielder_6
# fielder_7
# fielder_8
# fielder_9
# home_team
# away_team
# first
# second
# third

# %%
# Check the changes from the original to now
mlb2020.shape, mlb2020new.shape
# Out:
# ((279660, 83), (279660, 54))

# %% [markdown]
# After selecting the columns I want for this, I will import 2019 and before data. I want to concatenate and clean it up so I can put it in a model soon.
#
# ---
# # Import the other years and apply changes

# %%
mlb2020new.head()
# Out:
#    game_date pitch_type Pitcher_name  batter_id  pitcher_id  release_speed  \
# 0 2020-10-27         FF  Julio Urias   642715.0    628711.0           96.7
# 1 2020-10-27         FF  Julio Urias   642715.0    628711.0           94.1
# 2 2020-10-27         FF  Julio Urias   642715.0    628711.0           94.9
# 3 2020-10-27         FF  Julio Urias   670712.0    628711.0           94.4
# 4 2020-10-27         CU  Julio Urias   670712.0    628711.0           81.4
#
#    release_pos_x  release_pos_z stand p_throws  balls  strikes  pfx_x  pfx_z  \
# 0           1.58           5.99     R        L    0.0      2.0    0.2    1.6
# 1           2.91           5.45     R        L    0.0      1.0    0.8    1.3
# 2           1.77           6.02     R        L    0.0      0.0    0.2    1.5
# 3           1.66           5.93     R        L    3.0      2.0    0.3    1.5
# 4           1.46           6.06     R        L    2.0      2.0   -1.7   -0.2
#
#    plate_x  plate_z  on_3b  on_2b  on_1b  inning inning_topbot  \
# 0    -0.53     2.29    NaN    NaN    NaN     9.0           Top
# 1    -0.55     3.03    NaN    NaN    NaN     9.0           Top
# 2    -0.04     3.32    NaN    NaN    NaN     9.0           Top
# 3    -0.37     2.15    NaN    NaN    NaN     9.0           Top
# 4    -0.14     0.96    NaN    NaN    NaN     9.0           Top
#
#    effective_speed  release_spin_rate  release_extension   Catcher  \
# 0             95.4             2615.0                5.7  605131.0
# 1             93.4             2470.0                5.9  605131.0
# 2             94.0             2397.0                5.7  605131.0
# 3             93.7             2508.0                5.9  605131.0
# 4             80.2             3031.0                5.7  605131.0
#
#    FirstBasemen  SecondBasemen  ThirdBasemen  ShortStop  LeftField  \
# 0      571970.0       571771.0      621458.0   608369.0   621035.0
# 1      571970.0       571771.0      621458.0   608369.0   621035.0
# 2      571970.0       571771.0      621458.0   608369.0   621035.0
# 3      571970.0       571771.0      621458.0   608369.0   621035.0
# 4      571970.0       571771.0      621458.0   608369.0   621035.0
#
#    CenterField  RightField  at_bat_number  pitch_number       pitch_name  \
# 0     641355.0    605141.0           65.0           3.0  4-Seam Fastball
# 1     641355.0    605141.0           65.0           2.0  4-Seam Fastball
# 2     641355.0    605141.0           65.0           1.0  4-Seam Fastball
# 3     641355.0    605141.0           64.0           6.0  4-Seam Fastball
# 4     641355.0    605141.0           64.0           5.0        Curveball
#
#    bat_score  fld_score  post_bat_score  post_fld_score if_fielding_alignment  \
# 0        1.0        3.0             1.0             3.0              Standard
# 1        1.0        3.0             1.0             3.0              Standard
# 2        1.0        3.0             1.0             3.0              Standard
# 3        1.0        3.0             1.0             3.0              Standard
# 4        1.0        3.0             1.0             3.0              Standard
#
#   of_fielding_alignment count strike_attempt     events      description type  \
# 0              Standard   0-2         strike  strikeout    called_strike    S
# 1              Standard   0-1         strike        NaN    called_strike    S
# 2              Standard   0-0         strike        NaN  swinging_strike    S
# 3              Standard   3-2         strike  strikeout    called_strike    S
# 4              Standard   2-2           ball        NaN             ball    B
#
#   bb_type        vx0         vy0       vz0         ax         ay         az  \
# 0     NaN  -5.950264 -140.490456 -7.897391   3.772000  32.321911  -8.981441
# 1     NaN -10.560246 -136.599519 -3.429867  11.723598  29.183810 -15.237217
# 2     NaN  -5.199252 -138.098234 -4.637970   4.158758  30.838499 -12.535677
# 3     NaN  -5.843595 -137.294295 -7.414897   4.754147  30.016237 -11.778755
# 4     NaN  -0.383207 -118.447810 -4.454166 -15.553576  24.451936 -32.892744
#
#    outs_when_up
# 0           2.0
# 1           2.0
# 2           2.0
# 3           1.0
# 4           1.0

# %%
mlb2019 = pd.read_csv('data/2019mlb.csv')
mlb2018 = pd.read_csv('data/2018mlb.csv')
mlb2017 = pd.read_csv('data/2017mlb.csv')
mlb2016 = pd.read_csv('data/2016mlb.csv')
mlb2019.shape, mlb2018.shape, mlb2017.shape, mlb2016.shape
# Out:
# ((743572, 90), (731207, 90), (732476, 90), (726023, 90))

# %%
# Apply changes to 2016-2019 data
mlb2019 = project.cleaning(mlb2019)
mlb2019 = project.strike_attempt_column(mlb2019)
mlb2019 = project.fill_in_batters(mlb2019)
mlb2019 = project.the_count(mlb2019)
mlb2019 = mlb2019[features]
print(mlb2019.shape)
mlb2019.sample(3)
# Out:
# (743572, 55)
#         game_date pitch_type    Pitcher_name  pitcher_id    batter_name  \
# 247008 2019-08-03         FF  Yusmeiro Petit    433589.0    Tommy Edman
# 675193 2019-04-14         FF    Jacob deGrom    594798.0  Johan Camargo
# 707117 2019-04-06         SI  Ryan Yarbrough    642232.0      Joe Panik
#
#         batter_id  release_speed  release_pos_x  release_pos_z stand p_throws  \
# 247008   669242.0           89.3          -2.08           5.83     L        R
# 675193   622666.0           97.7          -1.34           5.45     L        R
# 707117   605412.0           89.8           2.50           5.53     L        L
#
#         balls  strikes  pfx_x  pfx_z  plate_x  plate_z     on_3b     on_2b  \
# 247008    0.0      0.0   -0.3    1.6    -0.65     1.55  451594.0  446308.0
# 675193    0.0      0.0   -0.5    1.3     0.00     3.20       NaN  518692.0
# 707117    1.0      2.0    1.2    1.0     0.54     2.52       NaN       NaN
#
#            on_1b  inning inning_topbot  effective_speed  release_spin_rate  \
# 247008       NaN     7.0           Top             90.5             2216.0
# 675193  660670.0     3.0           Bot             99.4             2379.0
# 707117       NaN     6.0           Bot             90.9             2103.0
#
#         release_extension   Catcher  FirstBasemen  SecondBasemen  \
# 247008                7.0  543302.0      621566.0       595777.0
# 675193                6.8  467092.0      624413.0       429664.0
# 707117                6.5  572287.0      596847.0       621002.0
#
#         ThirdBasemen  ShortStop  LeftField  CenterField  RightField  \
# 247008      656305.0   543760.0   543257.0     592192.0    572039.0
# 675193      605204.0   642708.0   643446.0     607043.0    624424.0
# 707117      650490.0   642715.0   502054.0     595281.0    640457.0
#
#         at_bat_number  pitch_number       pitch_name  bat_score  fld_score  \
# 247008           61.0           1.0  4-Seam Fastball        1.0        5.0
# 675193           28.0           1.0  4-Seam Fastball        2.0        1.0
# 707117           53.0           5.0           Sinker        6.0        4.0
#
#         post_bat_score  post_fld_score if_fielding_alignment  \
# 247008             1.0             5.0              Standard
# 675193             2.0             1.0              Standard
# 707117             6.0             4.0              Standard
#
#        of_fielding_alignment count strike_attempt     events    description  \
# 247008              Standard   0-0         strike        NaN  called_strike
# 675193              Standard   0-0         strike        NaN           foul
# 707117             Strategic   1-2            out  field_out  hit_into_play
#
#        type     bb_type       vx0         vy0       vz0         ax         ay  \
# 247008    S         NaN  4.129823 -129.921936 -8.058894  -3.818845  27.083208
# 675193    S         NaN  4.788536 -142.498929 -3.775916  -7.588269  27.780573
# 707117    X  line_drive -7.408999 -130.716393 -3.651199  15.180320  21.986541
#
#                az  outs_when_up
# 247008 -12.279762           1.0
# 675193 -13.235411           2.0
# 707117 -20.337336           1.0

# %%
mlb2018 = project.cleaning(mlb2018)
mlb2018 = project.strike_attempt_column(mlb2018)
mlb2018 = project.fill_in_batters(mlb2018)
mlb2018 = project.the_count(mlb2018)
mlb2018 = mlb2018[features]
print(mlb2018.shape)
mlb2018.sample(3)
# Out:
# (731207, 55)
#         game_date pitch_type     Pitcher_name  pitcher_id       batter_name  \
# 436520 2018-06-12         FF  Trevor Williams    592866.0  Paul Goldschmidt
# 385879 2018-06-25         SL    Kyle Crockett    641490.0    Ender Inciarte
# 107836 2018-09-06         FF     Shane Bieber    669456.0   Kendrys Morales
#
#         batter_id  release_speed  release_pos_x  release_pos_z stand p_throws  \
# 436520   502671.0           90.8          -2.36           5.19     R        R
# 385879   542255.0           77.1           2.25           4.96     L        L
# 107836   434778.0           93.7          -1.22           5.66     L        R
#
#         balls  strikes  pfx_x  pfx_z  plate_x  plate_z     on_3b     on_2b  \
# 436520    2.0      0.0   -0.5    1.0    -1.38     2.18       NaN       NaN
# 385879    0.0      0.0   -0.2    0.1    -0.36     2.51  622666.0  475247.0
# 107836    3.0      2.0   -1.1    1.4    -0.62     1.05       NaN       NaN
#
#            on_1b  inning inning_topbot  effective_speed  release_spin_rate  \
# 436520       NaN     2.0           Bot             91.3             2096.0
# 385879       NaN     6.0           Bot             77.2             1638.0
# 107836  666971.0     4.0           Bot             93.9             2284.0
#
#         release_extension   Catcher  FirstBasemen  SecondBasemen  \
# 436520                6.4  553869.0      605137.0       543281.0
# 385879                6.1  571466.0      458015.0       571697.0
# 107836                6.5  543228.0      475174.0       543401.0
#
#         ThirdBasemen  ShortStop  LeftField  CenterField  RightField  \
# 436520      592567.0   474568.0   572816.0     516782.0    570256.0
# 385879      553993.0   606299.0   608385.0     571740.0    594988.0
# 107836      608070.0   596019.0   446386.0     656185.0    466320.0
#
#         at_bat_number  pitch_number       pitch_name  bat_score  fld_score  \
# 436520           20.0           3.0  4-Seam Fastball        6.0        0.0
# 385879           55.0           1.0           Slider        3.0        3.0
# 107836           27.0           7.0  4-Seam Fastball        0.0        2.0
#
#         post_bat_score  post_fld_score if_fielding_alignment  \
# 436520             6.0             0.0              Standard
# 385879             3.0             3.0              Standard
# 107836             0.0             2.0         Infield shift
#
#        of_fielding_alignment count strike_attempt events    description type  \
# 436520              Standard   2-0           ball    NaN           ball    B
# 385879              Standard   0-0         strike    NaN  called_strike    S
# 107836              Standard   3-2           ball   walk           ball    B
#
#        bb_type       vx0         vy0       vz0         ax         ay  \
# 436520     NaN  3.638137 -132.203946 -3.879651  -7.195105  26.087741
# 385879     NaN -5.195339 -112.192872  1.576199  -0.636607  17.920354
# 107836     NaN  3.971466 -136.191804 -9.229483 -14.423408  30.107048
#
#                az  outs_when_up
# 436520 -19.452116           1.0
# 385879 -32.165188           2.0
# 107836 -13.132343           0.0

# %%
mlb2017 = project.cleaning(mlb2017)
mlb2017 = project.strike_attempt_column(mlb2017)
mlb2017 = project.fill_in_batters(mlb2017)
mlb2017 = project.the_count(mlb2017)
mlb2017 = mlb2017[features]
print(mlb2017.shape)
mlb2017.sample(3)
# Out:
# (732476, 55)
#         game_date pitch_type Pitcher_name  pitcher_id       batter_name  \
# 106654 2017-09-08         CH   Jose Urena    570632.0  Mike Foltynewicz
# 523847 2017-05-26         FF  Tim Adleman    534947.0     Aaron Altherr
# 147073 2017-08-29         FF   Mike Fiers    571666.0     Shin-Soo Choo
#
#         batter_id  release_speed  release_pos_x  release_pos_z stand p_throws  \
# 106654   592314.0           90.8          -1.62           5.95     R        R
# 523847   571437.0           90.1          -2.66           6.00     R        R
# 147073   425783.0           86.8          -0.83           6.06     L        R
#
#         balls  strikes  pfx_x  pfx_z  plate_x  plate_z  on_3b     on_2b  \
# 106654    0.0      0.0   -1.2    1.6     0.69     3.31    NaN       NaN
# 523847    0.0      1.0   -0.6    1.4    -2.37     4.17    NaN       NaN
# 147073    0.0      0.0   -0.2    0.8     1.50     1.40    NaN  596059.0
#
#            on_1b  inning inning_topbot  effective_speed  release_spin_rate  \
# 106654  607054.0     3.0           Bot             89.5             2085.0
# 523847  433217.0     1.0           Bot             90.6             1995.0
# 147073  455139.0     4.0           Top             86.7             2273.0
#
#         release_extension   Catcher  FirstBasemen  SecondBasemen  \
# 106654                5.9  592663.0      571506.0       543829.0
# 523847                6.6  519023.0      458015.0       606299.0
# 147073                6.4  594828.0      493329.0       514888.0
#
#         ThirdBasemen  ShortStop  LeftField  CenterField  RightField  \
# 106654      518618.0   500743.0   542303.0     592885.0    400085.0
# 523847      553993.0   446359.0   594807.0     571740.0    594988.0
# 147073      605204.0   608324.0   503556.0     545350.0    543807.0
#
#         at_bat_number  pitch_number       pitch_name  bat_score  fld_score  \
# 106654           24.0           1.0         Changeup        0.0        3.0
# 523847            8.0           2.0  4-Seam Fastball        0.0        2.0
# 147073           33.0           1.0  4-Seam Fastball        4.0        2.0
#
#         post_bat_score  post_fld_score if_fielding_alignment  \
# 106654             0.0             3.0             Strategic
# 523847             0.0             2.0              Standard
# 147073             4.0             2.0         Infield shift
#
#        of_fielding_alignment count strike_attempt        events   description  \
# 106654             Strategic   0-0           ball           NaN          ball
# 523847              Standard   0-1             ob  hit_by_pitch  hit_by_pitch
# 147073             Strategic   0-0           ball           NaN          ball
#
#        type bb_type       vx0         vy0       vz0         ax         ay  \
# 106654    B     NaN  8.309775 -131.523860 -3.822800 -16.102503  30.317519
# 523847    B     NaN  1.984398 -131.087232 -1.488310  -7.168195  27.598181
# 147073    B     NaN  5.928285 -125.898720 -6.512796  -3.045632  25.724312
#
#                az  outs_when_up
# 106654 -13.831970           0.0
# 523847 -16.355524           1.0
# 147073 -22.675472           1.0

# %%
mlb2016 = project.cleaning(mlb2016)
mlb2016 = project.strike_attempt_column(mlb2016)
mlb2016 = project.fill_in_batters(mlb2016)
mlb2016 = project.the_count(mlb2016)
mlb2016 = mlb2016[features]
print(mlb2016.shape)
mlb2016.sample(3)
# Out:
# (726023, 55)
#         game_date pitch_type     Pitcher_name  pitcher_id     batter_name  \
# 380834 2016-06-29         CH   Carlos Estevez    608032.0  Josh Donaldson
# 674145 2016-04-17         KN    Steven Wright    453214.0      Ryan Goins
# 2224   2016-10-22         FF  Clayton Kershaw    477132.0     Kris Bryant
#
#         batter_id  release_speed  release_pos_x  release_pos_z stand p_throws  \
# 380834   518626.0           91.7          -2.68           6.08     R        R
# 674145   572365.0           73.7          -0.67           5.64     L        R
# 2224     592178.0           94.2           1.28           6.14     R        L
#
#         balls  strikes  pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  \
# 380834    2.0      2.0   -0.8    0.8    -0.33     2.51    NaN    NaN
# 674145    1.0      2.0    0.8   -0.2    -0.92     3.02    NaN    NaN
# 2224      2.0      2.0    0.3    2.1    -0.03     3.23    NaN    NaN
#
#            on_1b  inning inning_topbot  effective_speed  release_spin_rate  \
# 380834       NaN     9.0           Top             91.2             1671.0
# 674145  607680.0     2.0           Top             71.9                NaN
# 2224         NaN     5.0           Bot             93.8             2496.0
#
#         release_extension   Catcher  FirstBasemen  SecondBasemen  \
# 380834                5.7  547172.0      448602.0       518614.0
# 674145                5.8  452672.0      434670.0       593523.0
# 2224                  6.3  518735.0      408236.0       400284.0
#
#         ThirdBasemen  ShortStop  LeftField  CenterField  RightField  \
# 380834      571448.0   542436.0   488681.0     453568.0    471865.0
# 674145      543768.0   593428.0   455759.0     598265.0    605141.0
# 2224        457759.0   608369.0   592808.0     592626.0    502210.0
#
#         at_bat_number  pitch_number       pitch_name  bat_score  fld_score  \
# 380834           69.0           6.0         Changeup        4.0        1.0
# 674145           13.0           4.0      Knuckleball        2.0        0.0
# 2224             36.0           7.0  4-Seam Fastball        4.0        0.0
#
#         post_bat_score  post_fld_score if_fielding_alignment  \
# 380834             4.0             1.0              Standard
# 674145             2.0             0.0              Standard
# 2224               4.0             0.0              Standard
#
#        of_fielding_alignment count strike_attempt     events    description  \
# 380834              Standard   2-2            out  field_out  hit_into_play
# 674145             Strategic   1-2           ball        NaN           ball
# 2224                Standard   2-2         strike        NaN           foul
#
#        type     bb_type    vx0      vy0    vz0     ax      ay      az  \
# 380834    X  line_drive  6.373 -133.391 -4.425 -8.114  26.596 -25.033
# 674145    B         NaN -2.039 -107.299  2.431  7.163  24.341 -35.240
# 2224      S         NaN -4.817 -136.839 -6.475  6.320  32.634  -7.658
#
#         outs_when_up
# 380834           0.0
# 674145           0.0
# 2224             1.0

# %% [markdown]
# ---
# ### Check for nulls in the new dataframes

# %%
mlb2019.shape[0]*.95
# Out:
# 706393.4

# %%
pd.DataFrame(mlb2019.isnull().sum()).T
# mlb2019.dropna(thresh=49).shape
# Out:
#    game_date  pitch_type  Pitcher_name  pitcher_id  batter_name  batter_id  \
# 0          0           0             0           0            0          0
#
#    release_speed  release_pos_x  release_pos_z  stand  p_throws  balls  \
# 0           5738           5757           5757      0         0      0
#
#    strikes  pfx_x  pfx_z  plate_x  plate_z   on_3b   on_2b   on_1b  inning  \
# 0        0   5757   5757     5757     5757  675504  607993  518755       0
#
#    inning_topbot  effective_speed  release_spin_rate  release_extension  \
# 0              0             5332              18564               5759
#
#    Catcher  FirstBasemen  SecondBasemen  ThirdBasemen  ShortStop  LeftField  \
# 0       57            57             57            57         57         57
#
#    CenterField  RightField  at_bat_number  pitch_number  pitch_name  \
# 0           57          57              0             0           0
#
#    bat_score  fld_score  post_bat_score  post_fld_score  \
# 0          0          0               0               0
#
#    if_fielding_alignment  of_fielding_alignment  count  strike_attempt  \
# 0                      0                      0      0               0
#
#    events  description  type  bb_type   vx0   vy0   vz0    ax    ay    az  \
# 0  554707            0     0   616038  5757  5757  5757  5757  5757  5757
#
#    outs_when_up
# 0             0

# %%
mlb2018.shape[0]*.95
# Out:
# 694646.65

# %%
pd.DataFrame(mlb2018.isnull().sum()).T
# mlb2018.dropna(thresh=49).shape
# Out:
#    game_date  pitch_type  Pitcher_name  pitcher_id  batter_name  batter_id  \
# 0          0           0             0           0            0          0
#
#    release_speed  release_pos_x  release_pos_z  stand  p_throws  balls  \
# 0           3163           3039           3039      0         0      0
#
#    strikes  pfx_x  pfx_z  plate_x  plate_z   on_3b   on_2b   on_1b  inning  \
# 0        0   3039   3039     3039     3039  663247  598019  508052       0
#
#    inning_topbot  effective_speed  release_spin_rate  release_extension  \
# 0              0             3059              14280               3192
#
#    Catcher  FirstBasemen  SecondBasemen  ThirdBasemen  ShortStop  LeftField  \
# 0      335           335            335           335        335        335
#
#    CenterField  RightField  at_bat_number  pitch_number  pitch_name  \
# 0          335         335              0             0           0
#
#    bat_score  fld_score  post_bat_score  post_fld_score  \
# 0          0          0               0               0
#
#    if_fielding_alignment  of_fielding_alignment  count  strike_attempt  \
# 0                      0                      0      0               2
#
#    events  description  type  bb_type   vx0   vy0   vz0    ax    ay    az  \
# 0  544045            0     0   603274  3039  3039  3039  3039  3039  3039
#
#    outs_when_up
# 0             0

# %%
mlb2017.shape[0]*.95
# Out:
# 695852.2

# %%
pd.DataFrame(mlb2017.isnull().sum()).T
# mlb2017.dropna(thresh=49).shape
# Out:
#    game_date  pitch_type  Pitcher_name  pitcher_id  batter_name  batter_id  \
# 0          0           0             0           0            0          0
#
#    release_speed  release_pos_x  release_pos_z  stand  p_throws  balls  \
# 0           5725           3198           3198      0         0      0
#
#    strikes  pfx_x  pfx_z  plate_x  plate_z   on_3b   on_2b   on_1b  inning  \
# 0        0   3198   3198     3198     3198  664432  597917  508844       0
#
#    inning_topbot  effective_speed  release_spin_rate  release_extension  \
# 0              0             5545              17799               5746
#
#    Catcher  FirstBasemen  SecondBasemen  ThirdBasemen  ShortStop  LeftField  \
# 0     1766          1766           1766          1766       1766       1766
#
#    CenterField  RightField  at_bat_number  pitch_number  pitch_name  \
# 0         1766        1766              0             0           0
#
#    bat_score  fld_score  post_bat_score  post_fld_score  \
# 0          0          0               0               0
#
#    if_fielding_alignment  of_fielding_alignment  count  strike_attempt  \
# 0                      0                      0      0               0
#
#    events  description  type  bb_type   vx0   vy0   vz0    ax    ay    az  \
# 0  544982            0     0   603092  3198  3198  3198  3198  3198  3198
#
#    outs_when_up
# 0             0

# %%
mlb2016.shape[0]*.95
# Out:
# 689721.85

# %%
pd.DataFrame(mlb2016.isnull().sum()).T
# mlb2016.dropna(thresh=49).shape
# Out:
#    game_date  pitch_type  Pitcher_name  pitcher_id  batter_name  batter_id  \
# 0          0           0             0           0            0          0
#
#    release_speed  release_pos_x  release_pos_z  stand  p_throws  balls  \
# 0            106          11179          11179      0         0      0
#
#    strikes  pfx_x  pfx_z  plate_x  plate_z   on_3b   on_2b   on_1b  inning  \
# 0        0    107    107      107      107  655516  590537  507004       0
#
#    inning_topbot  effective_speed  release_spin_rate  release_extension  \
# 0              0            10650              57417              10929
#
#    Catcher  FirstBasemen  SecondBasemen  ThirdBasemen  ShortStop  LeftField  \
# 0     6710          6710           6710          6710       6710       6710
#
#    CenterField  RightField  at_bat_number  pitch_number  pitch_name  \
# 0         6710        6710              0             0           0
#
#    bat_score  fld_score  post_bat_score  post_fld_score  \
# 0          0          0               0               0
#
#    if_fielding_alignment  of_fielding_alignment  count  strike_attempt  \
# 0                      0                      0      0            3329
#
#    events  description  type  bb_type  vx0  vy0  vz0   ax   ay   az  \
# 0  538452            0     0   595480  107  107  107  107  107  107
#
#    outs_when_up
# 0             0

# %% [markdown]
# ---
# ### Examine nulls in certain parts of the data

# %%
mlb2019[mlb2019['release_pos_x'].isnull()] # make a model to determine the perfect strike zone segment
# Out:
#         game_date pitch_type      Pitcher_name  pitcher_id        batter_name  \
# 514    2019-10-29          U  Justin Verlander    434378.0     Anthony Rendon
# 2130   2019-10-22          U      Max Scherzer    453286.0       Alex Bregman
# 12669  2019-09-29          U        Sam Selman    572125.0  Enrique Hernandez
# 12698  2019-09-29          U  Dereck Rodriguez    605446.0       A.J. Pollock
# 12980  2019-09-29          U      Tanner Roark    543699.0        Austin Nola
# ...           ...        ...               ...         ...                ...
# 743567 2019-03-20          U        Mike Fiers    571666.0      Mitch Haniger
# 743568 2019-03-20          U        Mike Fiers    571666.0      Mitch Haniger
# 743569 2019-03-20          U        Mike Fiers    571666.0      Mitch Haniger
# 743570 2019-03-20          U        Mike Fiers    571666.0         Dee Gordon
# 743571 2019-03-20          U        Mike Fiers    571666.0         Dee Gordon
#
#         batter_id  release_speed  release_pos_x  release_pos_z stand p_throws  \
# 514      543685.0            NaN            NaN            NaN     R        R
# 2130     608324.0            NaN            NaN            NaN     R        R
# 12669    571771.0            NaN            NaN            NaN     R        L
# 12698    572041.0            NaN            NaN            NaN     R        R
# 12980    543592.0            NaN            NaN            NaN     R        R
# ...           ...            ...            ...            ...   ...      ...
# 743567   571745.0            NaN            NaN            NaN     R        R
# 743568   571745.0            NaN            NaN            NaN     R        R
# 743569   571745.0            NaN            NaN            NaN     R        R
# 743570   543829.0            NaN            NaN            NaN     L        R
# 743571   543829.0            NaN            NaN            NaN     L        R
#
#         balls  strikes  pfx_x  pfx_z  plate_x  plate_z  on_3b     on_2b  \
# 514       0.0      0.0    NaN    NaN      NaN      NaN    NaN       NaN
# 2130      0.0      2.0    NaN    NaN      NaN      NaN    NaN  543807.0
# 12669     0.0      2.0    NaN    NaN      NaN      NaN    NaN       NaN
# 12698     1.0      2.0    NaN    NaN      NaN      NaN    NaN  621035.0
# 12980     0.0      0.0    NaN    NaN      NaN      NaN    NaN       NaN
# ...       ...      ...    ...    ...      ...      ...    ...       ...
# 743567    0.0      2.0    NaN    NaN      NaN      NaN    NaN       NaN
# 743568    0.0      1.0    NaN    NaN      NaN      NaN    NaN       NaN
# 743569    0.0      0.0    NaN    NaN      NaN      NaN    NaN       NaN
# 743570    1.0      0.0    NaN    NaN      NaN      NaN    NaN       NaN
# 743571    0.0      0.0    NaN    NaN      NaN      NaN    NaN       NaN
#
#            on_1b  inning inning_topbot  effective_speed  release_spin_rate  \
# 514     594809.0     3.0           Top              NaN                NaN
# 2130    514888.0     1.0           Bot              NaN                NaN
# 12669   666158.0     3.0           Top              NaN                NaN
# 12698   571970.0     2.0           Top              NaN                NaN
# 12980        NaN     3.0           Bot              NaN                NaN
# ...          ...     ...           ...              ...                ...
# 743567       NaN     1.0           Top              NaN                NaN
# 743568       NaN     1.0           Top              NaN                NaN
# 743569       NaN     1.0           Top              NaN                NaN
# 743570       NaN     1.0           Top              NaN                NaN
# 743571       NaN     1.0           Top              NaN                NaN
#
#         release_extension   Catcher  FirstBasemen  SecondBasemen  \
# 514                   NaN  455139.0      493329.0       514888.0
# 2130                  NaN  435559.0      475582.0       452678.0
# 12669                 NaN  457763.0      474832.0       643289.0
# 12698                 NaN  457763.0      474832.0       643289.0
# 12980                 NaN  572033.0      664913.0       595777.0
# ...                   ...       ...           ...            ...
# 743567                NaN  460026.0      621566.0       595777.0
# 743568                NaN  460026.0      621566.0       595777.0
# 743569                NaN  460026.0      621566.0       595777.0
# 743570                NaN  460026.0      621566.0       595777.0
# 743571                NaN  460026.0      621566.0       595777.0
#
#         ThirdBasemen  ShortStop  LeftField  CenterField  RightField  \
# 514         608324.0   621043.0   488726.0     543807.0    502210.0
# 2130        543685.0   607208.0   665742.0     645302.0    594809.0
# 12669       446334.0   543063.0   596103.0     573262.0    664041.0
# 12698       446334.0   543063.0   596103.0     573262.0    664041.0
# 12980       641914.0   620439.0   543257.0     621450.0    572039.0
# ...              ...        ...        ...          ...         ...
# 743567      656305.0   543760.0   640461.0     657656.0    572039.0
# 743568      656305.0   543760.0   640461.0     657656.0    572039.0
# 743569      656305.0   543760.0   640461.0     657656.0    572039.0
# 743570      656305.0   543760.0   640461.0     657656.0    572039.0
# 743571      656305.0   543760.0   640461.0     657656.0    572039.0
#
#         at_bat_number  pitch_number pitch_name  bat_score  fld_score  \
# 514              20.0           1.0    Unknown        1.0        2.0
# 2130              8.0           3.0    Unknown        0.0        0.0
# 12669            25.0           3.0    Unknown        5.0        0.0
# 12698            17.0           5.0    Unknown        5.0        0.0
# 12980            24.0           1.0    Unknown        2.0        0.0
# ...               ...           ...        ...        ...        ...
# 743567            2.0           3.0    Unknown        0.0        0.0
# 743568            2.0           2.0    Unknown        0.0        0.0
# 743569            2.0           1.0    Unknown        0.0        0.0
# 743570            1.0           2.0    Unknown        0.0        0.0
# 743571            1.0           1.0    Unknown        0.0        0.0
#
#         post_bat_score  post_fld_score if_fielding_alignment  \
# 514                1.0             2.0             Strategic
# 2130               0.0             0.0              Standard
# 12669              5.0             0.0              Standard
# 12698              5.0             0.0              Standard
# 12980              2.0             0.0              Standard
# ...                ...             ...                   ...
# 743567             0.0             0.0               Unknown
# 743568             0.0             0.0               Unknown
# 743569             0.0             0.0               Unknown
# 743570             0.0             0.0               Unknown
# 743571             0.0             0.0               Unknown
#
#        of_fielding_alignment count strike_attempt     events    description  \
# 514                 Standard   0-0           ball        NaN           ball
# 2130                Standard   0-2           ball        NaN           ball
# 12669               Standard   0-2           ball        NaN   blocked_ball
# 12698               Standard   1-2           ball        NaN   blocked_ball
# 12980               Standard   0-0         strike        NaN  called_strike
# ...                      ...   ...            ...        ...            ...
# 743567               Unknown   0-2         strike        NaN           foul
# 743568               Unknown   0-1         strike        NaN  called_strike
# 743569               Unknown   0-0         strike        NaN  called_strike
# 743570               Unknown   1-0            out  field_out  hit_into_play
# 743571               Unknown   0-0           ball        NaN           ball
#
#        type     bb_type  vx0  vy0  vz0  ax  ay  az  outs_when_up
# 514       B         NaN  NaN  NaN  NaN NaN NaN NaN           2.0
# 2130      B         NaN  NaN  NaN  NaN NaN NaN NaN           1.0
# 12669     B         NaN  NaN  NaN  NaN NaN NaN NaN           1.0
# 12698     B         NaN  NaN  NaN  NaN NaN NaN NaN           1.0
# 12980     S         NaN  NaN  NaN  NaN NaN NaN NaN           0.0
# ...     ...         ...  ...  ...  ...  ..  ..  ..           ...
# 743567    S         NaN  NaN  NaN  NaN NaN NaN NaN           1.0
# 743568    S         NaN  NaN  NaN  NaN NaN NaN NaN           1.0
# 743569    S         NaN  NaN  NaN  NaN NaN NaN NaN           1.0
# 743570    X  line_drive  NaN  NaN  NaN NaN NaN NaN           0.0
# 743571    B         NaN  NaN  NaN  NaN NaN NaN NaN           0.0
#
# [5757 rows x 55 columns]

# %%
mlb2016[(mlb2016['Catcher'].isnull()) & (mlb2016['Pitcher_name']=='Rich Hill')] # practically missing an innings worth of data in 2016
# Missing who were his defensive peeps
# Out:
#         game_date pitch_type Pitcher_name  pitcher_id     batter_name  \
# 21632  2016-09-30         FF    Rich Hill    448179.0     Angel Pagan
# 82303  2016-09-15         FF    Rich Hill    448179.0     Kyle Jensen
# 550412 2016-05-18         CU    Rich Hill    448179.0  Mitch Moreland
# 684304 2016-04-15         FF    Rich Hill    448179.0     Alex Gordon
# 725139 2016-04-04         CU    Rich Hill    448179.0   Melky Cabrera
# 725156 2016-04-04          U    Rich Hill    448179.0    Todd Frazier
# 725157 2016-04-04         CU    Rich Hill    448179.0    Todd Frazier
# 725158 2016-04-04          U    Rich Hill    448179.0    Todd Frazier
# 725159 2016-04-04         CU    Rich Hill    448179.0    Todd Frazier
# 725160 2016-04-04         CU    Rich Hill    448179.0      Jose Abreu
# 725161 2016-04-04         CU    Rich Hill    448179.0      Jose Abreu
# 725162 2016-04-04         FF    Rich Hill    448179.0      Jose Abreu
# 725163 2016-04-04         SL    Rich Hill    448179.0      Jose Abreu
# 725164 2016-04-04         CU    Rich Hill    448179.0      Jose Abreu
# 725165 2016-04-04         CU    Rich Hill    448179.0      Jose Abreu
# 725166 2016-04-04          U    Rich Hill    448179.0   Jimmy Rollins
# 725167 2016-04-04         FF    Rich Hill    448179.0   Jimmy Rollins
# 725168 2016-04-04         SL    Rich Hill    448179.0   Jimmy Rollins
# 725169 2016-04-04          U    Rich Hill    448179.0   Jimmy Rollins
# 725170 2016-04-04          U    Rich Hill    448179.0      Adam Eaton
#
#         batter_id  release_speed  release_pos_x  release_pos_z stand p_throws  \
# 21632    434636.0           90.7            NaN            NaN     R        L
# 82303    571812.0           91.7            NaN            NaN     R        L
# 550412   519048.0           74.6            NaN            NaN     L        L
# 684304   460086.0           90.1            NaN            NaN     L        L
# 725139   466320.0           75.4            NaN            NaN     R        L
# 725156   453943.0           91.2            NaN            NaN     R        L
# 725157   453943.0           75.3            NaN            NaN     R        L
# 725158   453943.0           90.2            NaN            NaN     R        L
# 725159   453943.0           75.4            NaN            NaN     R        L
# 725160   547989.0           75.6            NaN            NaN     R        L
# 725161   547989.0           75.2            NaN            NaN     R        L
# 725162   547989.0           91.5            NaN            NaN     R        L
# 725163   547989.0           81.5            NaN            NaN     R        L
# 725164   547989.0           75.7            NaN            NaN     R        L
# 725165   547989.0           75.2            NaN            NaN     R        L
# 725166   276519.0           90.5            NaN            NaN     R        L
# 725167   276519.0           89.8            NaN            NaN     R        L
# 725168   276519.0           78.8            NaN            NaN     R        L
# 725169   276519.0           89.6            NaN            NaN     R        L
# 725170   594809.0           90.8            NaN            NaN     L        L
#
#         balls  strikes  pfx_x  pfx_z  plate_x  plate_z  on_3b     on_2b  \
# 21632     2.0      2.0    0.9    1.5    -0.62     2.45    NaN  474832.0
# 82303     1.0      1.0    1.3    1.0    -0.19     3.36    NaN       NaN
# 550412    2.0      2.0   -1.1   -1.3     0.16     2.08    NaN       NaN
# 684304    0.0      0.0    1.1    1.4     1.15     3.89    NaN       NaN
# 725139    0.0      0.0   -1.3   -0.8     1.52     3.28    NaN       NaN
# 725156    1.0      2.0    1.8    1.0     1.02     1.89    NaN       NaN
# 725157    1.0      1.0   -1.2   -0.7    -0.12     2.92    NaN       NaN
# 725158    0.0      1.0    1.6    0.9    -1.09     2.47    NaN       NaN
# 725159    0.0      0.0   -1.2   -1.0     0.24     1.87    NaN       NaN
# 725160    3.0      2.0   -1.1   -1.0    -2.44     1.79    NaN       NaN
# 725161    2.0      2.0   -1.3   -0.7     0.72     3.78    NaN       NaN
# 725162    1.0      2.0    1.4    1.6    -0.98     2.68    NaN       NaN
# 725163    1.0      1.0    0.0    0.1    -0.13     2.29    NaN       NaN
# 725164    0.0      1.0   -1.2   -0.9     3.97     3.53    NaN       NaN
# 725165    0.0      0.0   -0.9   -1.0    -0.70     2.24    NaN       NaN
# 725166    2.0      1.0    1.5    0.6     0.86     2.68    NaN       NaN
# 725167    1.0      1.0    1.3    1.3     0.77     1.53    NaN       NaN
# 725168    1.0      0.0    0.0    0.0    -0.32     2.50    NaN       NaN
# 725169    0.0      0.0    1.6    1.2    -0.90     3.81    NaN       NaN
# 725170    0.0      0.0    1.9    1.0     1.50     2.92    NaN       NaN
#
#            on_1b  inning inning_topbot  effective_speed  release_spin_rate  \
# 21632        NaN     3.0           Bot              NaN                NaN
# 82303        NaN     2.0           Bot              NaN                NaN
# 550412  607387.0     2.0           Top              NaN                NaN
# 684304  434778.0     3.0           Top              NaN                NaN
# 725139       NaN     2.0           Top              NaN                NaN
# 725156  547989.0     1.0           Top              NaN                NaN
# 725157  547989.0     1.0           Top              NaN                NaN
# 725158  547989.0     1.0           Top              NaN                NaN
# 725159  547989.0     1.0           Top              NaN                NaN
# 725160       NaN     1.0           Top              NaN                NaN
# 725161       NaN     1.0           Top              NaN                NaN
# 725162       NaN     1.0           Top              NaN                NaN
# 725163       NaN     1.0           Top              NaN                NaN
# 725164       NaN     1.0           Top              NaN                NaN
# 725165  594809.0     1.0           Top              NaN                NaN
# 725166  594809.0     1.0           Top              NaN                NaN
# 725167  594809.0     1.0           Top              NaN                NaN
# 725168  594809.0     1.0           Top              NaN                NaN
# 725169  594809.0     1.0           Top              NaN                NaN
# 725170       NaN     1.0           Top              NaN                NaN
#
#         release_extension  Catcher  FirstBasemen  SecondBasemen  ThirdBasemen  \
# 21632                 NaN      NaN           NaN            NaN           NaN
# 82303                 NaN      NaN           NaN            NaN           NaN
# 550412                NaN      NaN           NaN            NaN           NaN
# 684304                NaN      NaN           NaN            NaN           NaN
# 725139                NaN      NaN           NaN            NaN           NaN
# 725156                NaN      NaN           NaN            NaN           NaN
# 725157                NaN      NaN           NaN            NaN           NaN
# 725158                NaN      NaN           NaN            NaN           NaN
# 725159                NaN      NaN           NaN            NaN           NaN
# 725160                NaN      NaN           NaN            NaN           NaN
# 725161                NaN      NaN           NaN            NaN           NaN
# 725162                NaN      NaN           NaN            NaN           NaN
# 725163                NaN      NaN           NaN            NaN           NaN
# 725164                NaN      NaN           NaN            NaN           NaN
# 725165                NaN      NaN           NaN            NaN           NaN
# 725166                NaN      NaN           NaN            NaN           NaN
# 725167                NaN      NaN           NaN            NaN           NaN
# 725168                NaN      NaN           NaN            NaN           NaN
# 725169                NaN      NaN           NaN            NaN           NaN
# 725170                NaN      NaN           NaN            NaN           NaN
#
#         ShortStop  LeftField  CenterField  RightField  at_bat_number  \
# 21632         NaN        NaN          NaN         NaN           28.0
# 82303         NaN        NaN          NaN         NaN           15.0
# 550412        NaN        NaN          NaN         NaN           14.0
# 684304        NaN        NaN          NaN         NaN           25.0
# 725139        NaN        NaN          NaN         NaN            8.0
# 725156        NaN        NaN          NaN         NaN            4.0
# 725157        NaN        NaN          NaN         NaN            4.0
# 725158        NaN        NaN          NaN         NaN            4.0
# 725159        NaN        NaN          NaN         NaN            4.0
# 725160        NaN        NaN          NaN         NaN            3.0
# 725161        NaN        NaN          NaN         NaN            3.0
# 725162        NaN        NaN          NaN         NaN            3.0
# 725163        NaN        NaN          NaN         NaN            3.0
# 725164        NaN        NaN          NaN         NaN            3.0
# 725165        NaN        NaN          NaN         NaN            3.0
# 725166        NaN        NaN          NaN         NaN            2.0
# 725167        NaN        NaN          NaN         NaN            2.0
# 725168        NaN        NaN          NaN         NaN            2.0
# 725169        NaN        NaN          NaN         NaN            2.0
# 725170        NaN        NaN          NaN         NaN            1.0
#
#         pitch_number       pitch_name  bat_score  fld_score  post_bat_score  \
# 21632            5.0  4-Seam Fastball        2.0        2.0             2.0
# 82303            3.0  4-Seam Fastball        0.0        0.0             0.0
# 550412           5.0        Curveball        0.0        3.0             0.0
# 684304           1.0  4-Seam Fastball        3.0        1.0             3.0
# 725139           1.0        Curveball        0.0        0.0             0.0
# 725156           4.0  2-Seam Fastball        0.0        0.0             0.0
# 725157           3.0        Curveball        0.0        0.0             0.0
# 725158           2.0  2-Seam Fastball        0.0        0.0             0.0
# 725159           1.0        Curveball        0.0        0.0             0.0
# 725160           6.0        Curveball        0.0        0.0             0.0
# 725161           5.0        Curveball        0.0        0.0             0.0
# 725162           4.0  4-Seam Fastball        0.0        0.0             0.0
# 725163           3.0           Slider        0.0        0.0             0.0
# 725164           2.0        Curveball        0.0        0.0             0.0
# 725165           1.0        Curveball        0.0        0.0             0.0
# 725166           4.0  2-Seam Fastball        0.0        0.0             0.0
# 725167           3.0  4-Seam Fastball        0.0        0.0             0.0
# 725168           2.0           Slider        0.0        0.0             0.0
# 725169           1.0  2-Seam Fastball        0.0        0.0             0.0
# 725170           1.0  2-Seam Fastball        0.0        0.0             0.0
#
#         post_fld_score if_fielding_alignment of_fielding_alignment count  \
# 21632              2.0               Unknown               Unknown   2-2
# 82303              0.0               Unknown               Unknown   1-1
# 550412             3.0               Unknown               Unknown   2-2
# 684304             1.0               Unknown               Unknown   0-0
# 725139             0.0               Unknown               Unknown   0-0
# 725156             0.0               Unknown               Unknown   1-2
# 725157             0.0               Unknown               Unknown   1-1
# 725158             0.0               Unknown               Unknown   0-1
# 725159             0.0               Unknown               Unknown   0-0
# 725160             0.0               Unknown               Unknown   3-2
# 725161             0.0               Unknown               Unknown   2-2
# 725162             0.0               Unknown               Unknown   1-2
# 725163             0.0               Unknown               Unknown   1-1
# 725164             0.0               Unknown               Unknown   0-1
# 725165             0.0               Unknown               Unknown   0-0
# 725166             0.0               Unknown               Unknown   2-1
# 725167             0.0               Unknown               Unknown   1-1
# 725168             0.0               Unknown               Unknown   1-0
# 725169             0.0               Unknown               Unknown   0-0
# 725170             0.0               Unknown               Unknown   0-0
#
#        strike_attempt        events      description type     bb_type     vx0  \
# 21632             out     field_out    hit_into_play    X  line_drive  -7.891
# 82303          strike           NaN    called_strike    S         NaN  -9.246
# 550412         strike     strikeout  swinging_strike    S         NaN  -2.129
# 684304           ball           NaN             ball    B         NaN  -4.728
# 725139           ball           NaN             ball    B         NaN   0.230
# 725156         strike     strikeout  swinging_strike    S         NaN  -7.930
# 725157         strike           NaN             foul    S         NaN  -2.630
# 725158           ball           NaN             ball    B         NaN -11.370
# 725159         strike           NaN    called_strike    S         NaN  -2.070
# 725160             ob  hit_by_pitch     hit_by_pitch    B         NaN  -7.080
# 725161           ball           NaN             ball    B         NaN  -0.940
# 725162           ball           NaN             ball    B         NaN -10.370
# 725163         strike           NaN             foul    S         NaN  -5.610
# 725164           ball           NaN             ball    B         NaN   4.760
# 725165         strike           NaN    called_strike    S         NaN  -4.500
# 725166            out     field_out    hit_into_play    X  line_drive  -7.420
# 725167           ball           NaN             ball    B         NaN  -7.180
# 725168         strike           NaN    called_strike    S         NaN  -5.610
# 725169           ball           NaN             ball    B         NaN -11.600
# 725170             ob  hit_by_pitch     hit_by_pitch    B         NaN  -7.270
#
#             vy0    vz0      ax      ay      az  outs_when_up
# 21632  -131.796 -6.373  13.298  29.163 -16.821           2.0
# 82303  -133.267 -2.493  18.616  28.747 -21.567           2.0
# 550412 -108.633  2.154  -8.098  21.596 -44.134           1.0
# 684304 -131.230 -1.873  15.257  29.437 -17.319           1.0
# 725139 -109.750  4.380  -9.680  23.760 -40.740           0.0
# 725156 -132.650 -3.660  24.830  32.020 -22.590           2.0
# 725157 -109.550  3.310  -9.450  21.900 -39.720           2.0
# 725158 -130.920 -3.320  21.550  25.970 -23.980           2.0
# 725159 -109.880  1.930  -9.450  23.700 -42.320           2.0
# 725160 -109.890  1.380  -7.950  26.090 -41.990           2.0
# 725161 -109.400  4.950  -9.740  25.590 -39.430           2.0
# 725162 -132.830 -4.860  19.490  32.210 -14.770           2.0
# 725163 -118.480 -0.120   0.880  22.330 -33.070           2.0
# 725164 -110.120  4.960  -8.840  22.870 -41.070           2.0
# 725165 -109.500  2.580  -6.980  22.400 -41.910           1.0
# 725166 -131.630 -0.790  20.830  27.650 -27.260           0.0
# 725167 -130.470 -5.480  18.220  27.610 -18.280           0.0
# 725168 -114.670  0.750   1.430  19.670 -34.140           0.0
# 725169 -130.070  0.430  20.790  28.190 -19.850           0.0
# 725170 -132.140 -1.290  26.020  28.750 -21.890           0.0

# %%
# save the cleaned data
mlb2019.to_csv('data/2019cleaned.csv', index=False)
mlb2018.to_csv('data/2018cleaned.csv', index=False)
mlb2017.to_csv('data/2017cleaned.csv', index=False)
mlb2016.to_csv('data/2016cleaned.csv', index=False)

# %%
# quick check
mlb2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743572 entries, 0 to 743571
# Data columns (total 55 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   game_date              743572 non-null  datetime64[ns]
#  1   pitch_type             743572 non-null  object
#  2   Pitcher_name           743572 non-null  object
#  3   pitcher_id             743572 non-null  float64
#  4   batter_name            743572 non-null  object
#  5   batter_id              743572 non-null  float64
#  6   release_speed          737834 non-null  float64
#  7   release_pos_x          737815 non-null  float64
#  8   release_pos_z          737815 non-null  float64
#  9   stand                  743572 non-null  object
#  10  p_throws               743572 non-null  object
#  11  balls                  743572 non-null  float64
#  12  strikes                743572 non-null  float64
#  13  pfx_x                  737815 non-null  float64
#  14  pfx_z                  737815 non-null  float64
#  15  plate_x                737815 non-null  float64
#  16  plate_z                737815 non-null  float64
#  17  on_3b                  68068 non-null   float64
#  18  on_2b                  135579 non-null  float64
#  19  on_1b                  224817 non-null  float64
#  20  inning                 743572 non-null  float64
#  21  inning_topbot          743572 non-null  object
#  22  effective_speed        738240 non-null  float64
#  23  release_spin_rate      725008 non-null  float64
#  24  release_extension      737813 non-null  float64
#  25  Catcher                743515 non-null  float64
#  26  FirstBasemen           743515 non-null  float64
#  27  SecondBasemen          743515 non-null  float64
#  28  ThirdBasemen           743515 non-null  float64
#  29  ShortStop              743515 non-null  float64
#  30  LeftField              743515 non-null  float64
#  31  CenterField            743515 non-null  float64
#  32  RightField             743515 non-null  float64
#  33  at_bat_number          743572 non-null  float64
#  34  pitch_number           743572 non-null  float64
#  35  pitch_name             743572 non-null  object
#  36  bat_score              743572 non-null  float64
#  37  fld_score              743572 non-null  float64
#  38  post_bat_score         743572 non-null  float64
#  39  post_fld_score         743572 non-null  float64
#  40  if_fielding_alignment  743572 non-null  object
#  41  of_fielding_alignment  743572 non-null  object
#  42  count                  743572 non-null  object
#  43  strike_attempt         743572 non-null  object
#  44  events                 188865 non-null  object
#  45  description            743572 non-null  object
#  46  type                   743572 non-null  object
#  47  bb_type                127534 non-null  object
#  48  vx0                    737815 non-null  float64
#  49  vy0                    737815 non-null  float64
#  50  vz0                    737815 non-null  float64
#  51  ax                     737815 non-null  float64
#  52  ay                     737815 non-null  float64
#  53  az                     737815 non-null  float64
#  54  outs_when_up           743572 non-null  float64
# dtypes: datetime64[ns](1), float64(39), object(15)
# memory usage: 312.0+ MB

# %% [markdown]
# ### Import the dataframe created from EDA notebook.
#
# This came from a concatenation created in another notebook. The code was similar to what was done. (Sorry, I accidently deleted the actual code)
#
# ```python
# df = pd.concat(<list of mlb df>, something )
# df.reset_index(drop=True, inplace=True)
# ```

# %%
df = pd.read_csv('data/big_daddy_baseball.csv')

# %%
df.head()
# Out:
#     game_date pitch_type Pitcher_name  pitcher_id    batter_name  batter_id  \
# 0  2020-10-27         FF  Julio Urias    628711.0   Willy Adames   642715.0
# 1  2020-10-27         FF  Julio Urias    628711.0   Willy Adames   642715.0
# 2  2020-10-27         FF  Julio Urias    628711.0   Willy Adames   642715.0
# 3  2020-10-27         FF  Julio Urias    628711.0  Mike Brosseau   670712.0
# 4  2020-10-27         CU  Julio Urias    628711.0  Mike Brosseau   670712.0
#
#    release_speed  release_pos_x  release_pos_z stand p_throws  balls  strikes  \
# 0           96.7           1.58           5.99     R        L    0.0      2.0
# 1           94.1           2.91           5.45     R        L    0.0      1.0
# 2           94.9           1.77           6.02     R        L    0.0      0.0
# 3           94.4           1.66           5.93     R        L    3.0      2.0
# 4           81.4           1.46           6.06     R        L    2.0      2.0
#
#    pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  inning inning_topbot  \
# 0    0.2    1.6    -0.53     2.29    NaN    NaN    NaN     9.0           Top
# 1    0.8    1.3    -0.55     3.03    NaN    NaN    NaN     9.0           Top
# 2    0.2    1.5    -0.04     3.32    NaN    NaN    NaN     9.0           Top
# 3    0.3    1.5    -0.37     2.15    NaN    NaN    NaN     9.0           Top
# 4   -1.7   -0.2    -0.14     0.96    NaN    NaN    NaN     9.0           Top
#
#    effective_speed  release_spin_rate  release_extension   Catcher  \
# 0             95.4             2615.0                5.7  605131.0
# 1             93.4             2470.0                5.9  605131.0
# 2             94.0             2397.0                5.7  605131.0
# 3             93.7             2508.0                5.9  605131.0
# 4             80.2             3031.0                5.7  605131.0
#
#    FirstBasemen  SecondBasemen  ThirdBasemen  ShortStop  LeftField  \
# 0      571970.0       571771.0      621458.0   608369.0   621035.0
# 1      571970.0       571771.0      621458.0   608369.0   621035.0
# 2      571970.0       571771.0      621458.0   608369.0   621035.0
# 3      571970.0       571771.0      621458.0   608369.0   621035.0
# 4      571970.0       571771.0      621458.0   608369.0   621035.0
#
#    CenterField  RightField  at_bat_number  pitch_number       pitch_name  \
# 0     641355.0    605141.0           65.0           3.0  4-Seam Fastball
# 1     641355.0    605141.0           65.0           2.0  4-Seam Fastball
# 2     641355.0    605141.0           65.0           1.0  4-Seam Fastball
# 3     641355.0    605141.0           64.0           6.0  4-Seam Fastball
# 4     641355.0    605141.0           64.0           5.0        Curveball
#
#    bat_score  fld_score  post_bat_score  post_fld_score if_fielding_alignment  \
# 0        1.0        3.0             1.0             3.0              Standard
# 1        1.0        3.0             1.0             3.0              Standard
# 2        1.0        3.0             1.0             3.0              Standard
# 3        1.0        3.0             1.0             3.0              Standard
# 4        1.0        3.0             1.0             3.0              Standard
#
#   of_fielding_alignment count strike_attempt     events      description type  \
# 0              Standard   0-2         strike  strikeout    called_strike    S
# 1              Standard   0-1         strike        NaN    called_strike    S
# 2              Standard   0-0         strike        NaN  swinging_strike    S
# 3              Standard   3-2         strike  strikeout    called_strike    S
# 4              Standard   2-2           ball        NaN             ball    B
#
#   bb_type        vx0         vy0       vz0         ax         ay         az  \
# 0     NaN  -5.950264 -140.490456 -7.897391   3.772000  32.321911  -8.981441
# 1     NaN -10.560246 -136.599519 -3.429867  11.723598  29.183810 -15.237217
# 2     NaN  -5.199252 -138.098234 -4.637970   4.158758  30.838499 -12.535677
# 3     NaN  -5.843595 -137.294295 -7.414897   4.754147  30.016237 -11.778755
# 4     NaN  -0.383207 -118.447810 -4.454166 -15.553576  24.451936 -32.892744
#
#    outs_when_up
# 0           2.0
# 1           2.0
# 2           2.0
# 3           1.0
# 4           1.0

# %% [markdown]
# # More Feature Engineering
#
# ---
# The reason why I am doing this here is because now I have the large dataframe in which to build on. Basically, I concatenated on the EDA notebook so I can save it and reimport it there.
#
# The `subset` dataframe where I test out all my engineering.

# %%
subset = df[:300].copy()
subset.shape
# Out:
# (300, 55)

# %%
subset['out_type'] = np.where(subset['bb_type'].isnull(), subset['strike_attempt'], subset['bb_type'])

# %%
# re-ran many times
subset.sample(5)
# Out:
#       game_date pitch_type      Pitcher_name  pitcher_id    batter_name  \
# 70   2020-10-27         SI  Brusdar Graterol    660813.0   Willy Adames
# 107  2020-10-27         FF   Victor Gonzalez    624647.0   Brandon Lowe
# 129  2020-10-27         CH        Pedro Baez    520980.0    Mike Zunino
# 147  2020-10-27         FF       Blake Snell    605483.0   Corey Seager
# 294  2020-10-25         SL   Victor Gonzalez    624647.0  Mike Brosseau
#
#      batter_id  release_speed  release_pos_x  release_pos_z stand p_throws  \
# 70    642715.0          101.5          -1.34           6.64     R        R
# 107   664040.0           93.7           2.49           4.97     L        L
# 129   572287.0           88.1          -0.44           6.55     R        R
# 147   608369.0           95.9           1.71           6.62     L        L
# 294   670712.0           85.6           2.51           4.93     R        L
#
#      balls  strikes  pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b   on_1b  \
# 70     0.0      0.0   -1.3    0.7    -0.50     4.06    NaN    NaN       0
# 107    0.0      0.0    1.5    0.9     0.20     2.46    NaN    NaN       0
# 129    1.0      2.0   -1.1    1.1    -0.28     1.51    NaN    NaN       0
# 147    0.0      1.0    0.2    1.7    -0.94     3.50    NaN    NaN       0
# 294    1.0      2.0   -0.1    0.2     0.32     0.66    NaN    NaN  595281
#
#      inning inning_topbot  effective_speed  release_spin_rate  \
# 70      7.0           Top            100.6             1952.0
# 107     6.0           Top             93.4             2226.0
# 129     5.0           Top             87.6             1979.0
# 147     4.0           Bot             96.8             2504.0
# 294     8.0           Bot             85.7             2447.0
#
#      release_extension   Catcher  FirstBasemen  SecondBasemen  ThirdBasemen  \
# 70                 5.7  605131.0      571970.0       621035.0      457759.0
# 107                6.2  605131.0      571970.0       621035.0      457759.0
# 129                6.0  605131.0      571970.0       621035.0      457759.0
# 147                7.0  572287.0      596847.0       664040.0      621563.0
# 294                6.0  605131.0      571970.0       571771.0      457759.0
#
#      ShortStop  LeftField  CenterField  RightField  at_bat_number  \
# 70    608369.0   572041.0     641355.0    605141.0           47.0
# 107   608369.0   572041.0     641355.0    605141.0           38.0
# 129   608369.0   572041.0     641355.0    605141.0           31.0
# 147   642715.0   668227.0     595281.0    622534.0           28.0
# 294   608369.0   621035.0     641355.0    605141.0           62.0
#
#      pitch_number       pitch_name  bat_score  fld_score  post_bat_score  \
# 70            1.0           Sinker        1.0        2.0             1.0
# 107           1.0  4-Seam Fastball        1.0        0.0             1.0
# 129           4.0         Changeup        1.0        0.0             1.0
# 147           2.0  4-Seam Fastball        0.0        1.0             0.0
# 294           4.0           Slider        2.0        4.0             2.0
#
#      post_fld_score if_fielding_alignment of_fielding_alignment count  \
# 70              2.0              Standard              Standard   0-0
# 107             0.0         Infield shift              Standard   0-0
# 129             0.0         Infield shift              Standard   1-2
# 147             1.0             Strategic              Standard   0-1
# 294             4.0         Infield shift              Standard   1-2
#
#     strike_attempt     events      description type bb_type       vx0  \
# 70            ball        NaN             ball    B     NaN  5.286563
# 107         strike        NaN             foul    S     NaN -9.146629
# 129         strike  strikeout  swinging_strike    S     NaN  2.608465
# 147           ball        NaN             ball    B     NaN -7.474445
# 294           ball        NaN             ball    B     NaN -4.996849
#
#             vy0       vz0         ax         ay         az  outs_when_up  \
# 70  -147.795150 -3.657855 -19.660019  33.958463 -20.873227           0.0
# 107 -136.173221 -2.755801  20.541189  30.220566 -20.300179           0.0
# 129 -128.101120 -8.443739 -12.387265  26.896402 -18.064926           0.0
# 147 -139.312841 -6.533739   4.019059  33.083993  -8.760552           0.0
# 294 -124.737900 -4.253432   0.028998  22.128032 -29.662832           1.0
#
#     out_type
# 70      ball
# 107   strike
# 129   strike
# 147     ball
# 294     ball

# %%
# Fill the subsets with 0s
subset['on_1b'].fillna(0, inplace=True)

# %%
subset['on_1b']=subset['on_1b'].map(int)

# %% [markdown]
# ---
# ---
# Execute what is done on the subset into `df`

# %%
# save df
df.to_csv('data/big_daddy_baseball_cleaned.csv')
