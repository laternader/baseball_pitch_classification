# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# Import Data
mlb2020 = pd.read_csv('data/2020mlb.csv')
mlb2020.shape
# Out:
# (279660, 90)

# %%
mlb2020['strike_attempt']=mlb2020['description'].map(
{'called_strike':'strike',
 'swinging_strike':'strike',
 'ball':'ball',
 'foul':'strike', # False in out_via_description
 'hit_into_play':'out',
 'blocked_ball':'ball',
 'hit_into_play_score':'ob',
 'swinging_strike_blocked':'strike',
 'hit_into_play_no_out':'ob',
 'foul_bunt':'strike',
 'foul_tip':'strike',
 'hit_by_pitch':'ob',
 'missed_bunt':'strike',
 'pitchout':'out',
 'bunt_foul_tip':'strike'})

# %%
# Rename 'player_name' to 'pitcher_name'

# Make sure all dataframes go through this.
mlb2020.rename(columns={'player_name':'pitcher_name'}, inplace=True)

# %%
# Create Batter Name
def batter_name(des):
    try:
        name = ' '.join(des.split(' ',2)[:2])
        return name
    except:
        return np.nan
mlb2020['batter_name'] = mlb2020['des'].map(batter_name)
mlb2020['batter_name'].ffill(axis=0, inplace=True)
mlb2020.head()
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         FF  2020-10-27           96.7           1.58           5.99
# 1      1         FF  2020-10-27           94.1           2.91           5.45
# 2      2         FF  2020-10-27           94.9           1.77           6.02
# 3      3         FF  2020-10-27           94.4           1.66           5.93
# 4      4         CU  2020-10-27           81.4           1.46           6.06
#
#   pitcher_name    batter   pitcher     events      description  spin_dir  \
# 0  Julio Urias  642715.0  628711.0  strikeout    called_strike       NaN
# 1  Julio Urias  642715.0  628711.0        NaN    called_strike       NaN
# 2  Julio Urias  642715.0  628711.0        NaN  swinging_strike       NaN
# 3  Julio Urias  670712.0  628711.0  strikeout    called_strike       NaN
# 4  Julio Urias  670712.0  628711.0        NaN             ball       NaN
#
#    spin_rate_deprecated  break_angle_deprecated  break_length_deprecated  \
# 0                   NaN                     NaN                      NaN
# 1                   NaN                     NaN                      NaN
# 2                   NaN                     NaN                      NaN
# 3                   NaN                     NaN                      NaN
# 4                   NaN                     NaN                      NaN
#
#    zone                                     des game_type stand p_throws  \
# 0   4.0   Willy Adames called out on strikes.           W     R        L
# 1   1.0                                     NaN         W     R        L
# 2   2.0                                     NaN         W     R        L
# 3   4.0  Mike Brosseau called out on strikes.           W     R        L
# 4  13.0                                     NaN         W     R        L
#
#   home_team away_team type  hit_location bb_type  balls  strikes  game_year  \
# 0       LAD        TB    S           2.0     NaN    0.0      2.0     2020.0
# 1       LAD        TB    S           NaN     NaN    0.0      1.0     2020.0
# 2       LAD        TB    S           NaN     NaN    0.0      0.0     2020.0
# 3       LAD        TB    S           2.0     NaN    3.0      2.0     2020.0
# 4       LAD        TB    B           NaN     NaN    2.0      2.0     2020.0
#
#    pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  outs_when_up  inning  \
# 0    0.2    1.6    -0.53     2.29    NaN    NaN    NaN           2.0     9.0
# 1    0.8    1.3    -0.55     3.03    NaN    NaN    NaN           2.0     9.0
# 2    0.2    1.5    -0.04     3.32    NaN    NaN    NaN           2.0     9.0
# 3    0.3    1.5    -0.37     2.15    NaN    NaN    NaN           1.0     9.0
# 4   -1.7   -0.2    -0.14     0.96    NaN    NaN    NaN           1.0     9.0
#
#   inning_topbot  hc_x  hc_y  tfs_deprecated  tfs_zulu_deprecated  fielder_2  \
# 0           Top   NaN   NaN             NaN                  NaN   605131.0
# 1           Top   NaN   NaN             NaN                  NaN   605131.0
# 2           Top   NaN   NaN             NaN                  NaN   605131.0
# 3           Top   NaN   NaN             NaN                  NaN   605131.0
# 4           Top   NaN   NaN             NaN                  NaN   605131.0
#
#    umpire  sv_id        vx0         vy0       vz0         ax         ay  \
# 0     NaN    NaN  -5.950264 -140.490456 -7.897391   3.772000  32.321911
# 1     NaN    NaN -10.560246 -136.599519 -3.429867  11.723598  29.183810
# 2     NaN    NaN  -5.199252 -138.098234 -4.637970   4.158758  30.838499
# 3     NaN    NaN  -5.843595 -137.294295 -7.414897   4.754147  30.016237
# 4     NaN    NaN  -0.383207 -118.447810 -4.454166 -15.553576  24.451936
#
#           az  sz_top  sz_bot  hit_distance_sc  launch_speed  launch_angle  \
# 0  -8.981441    3.50    1.69              NaN           NaN           NaN
# 1 -15.237217    3.50    1.69              NaN           NaN           NaN
# 2 -12.535677    3.50    1.69              NaN           NaN           NaN
# 3 -11.778755    3.34    1.53              NaN           NaN           NaN
# 4 -32.892744    3.34    1.53              NaN           NaN           NaN
#
#    effective_speed  release_spin_rate  release_extension   game_pk  pitcher.1  \
# 0             95.4             2615.0                5.7  635886.0   628711.0
# 1             93.4             2470.0                5.9  635886.0   628711.0
# 2             94.0             2397.0                5.7  635886.0   628711.0
# 3             93.7             2508.0                5.9  635886.0   628711.0
# 4             80.2             3031.0                5.7  635886.0   628711.0
#
#    fielder_2.1  fielder_3  fielder_4  fielder_5  fielder_6  fielder_7  \
# 0     605131.0   571970.0   571771.0   621458.0   608369.0   621035.0
# 1     605131.0   571970.0   571771.0   621458.0   608369.0   621035.0
# 2     605131.0   571970.0   571771.0   621458.0   608369.0   621035.0
# 3     605131.0   571970.0   571771.0   621458.0   608369.0   621035.0
# 4     605131.0   571970.0   571771.0   621458.0   608369.0   621035.0
#
#    fielder_8  fielder_9  release_pos_y  estimated_ba_using_speedangle  \
# 0   641355.0   605141.0          54.82                            NaN
# 1   641355.0   605141.0          54.59                            NaN
# 2   641355.0   605141.0          54.76                            NaN
# 3   641355.0   605141.0          54.60                            NaN
# 4   641355.0   605141.0          54.84                            NaN
#
#    estimated_woba_using_speedangle  woba_value  woba_denom  babip_value  \
# 0                              NaN         0.0         1.0          0.0
# 1                              NaN         NaN         NaN          NaN
# 2                              NaN         NaN         NaN          NaN
# 3                              NaN         0.0         1.0          0.0
# 4                              NaN         NaN         NaN          NaN
#
#    iso_value  launch_speed_angle  at_bat_number  pitch_number  \
# 0        0.0                 NaN           65.0           3.0
# 1        NaN                 NaN           65.0           2.0
# 2        NaN                 NaN           65.0           1.0
# 3        0.0                 NaN           64.0           6.0
# 4        NaN                 NaN           64.0           5.0
#
#         pitch_name  home_score  away_score  bat_score  fld_score  \
# 0  4-Seam Fastball         3.0         1.0        1.0        3.0
# 1  4-Seam Fastball         3.0         1.0        1.0        3.0
# 2  4-Seam Fastball         3.0         1.0        1.0        3.0
# 3  4-Seam Fastball         3.0         1.0        1.0        3.0
# 4        Curveball         3.0         1.0        1.0        3.0
#
#    post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0              1.0              3.0             1.0             3.0
# 1              1.0              3.0             1.0             3.0
# 2              1.0              3.0             1.0             3.0
# 3              1.0              3.0             1.0             3.0
# 4              1.0              3.0             1.0             3.0
#
#   if_fielding_alignment of_fielding_alignment strike_attempt    batter_name
# 0              Standard              Standard         strike   Willy Adames
# 1              Standard              Standard         strike   Willy Adames
# 2              Standard              Standard         strike   Willy Adames
# 3              Standard              Standard         strike  Mike Brosseau
# 4              Standard              Standard           ball  Mike Brosseau

# %%
# Get Pitcher Name Stats
def pitcher_stats(name ,df):
    '''
    name: name of pitcher as a string
    df: dataframe of the season you want to check
    '''
    try:
        return df[df['pitcher_name']==name]
    except:
        return 'Did not play this season or you misspelled his name.'

# Get Batter Stats
def batter_stats(name ,df):
    '''
    name: name of batter as a string
    df: dataframe of the season you want to check
    '''
    try:
        return df[df['batter_name']==name]
    except:
        return 'Did not play this season or you misspelled his name.'

# %%
# Example of grabbing pitcher stats
julio_urias = pitcher_stats('Julio Urias', mlb2020)

yu_darvish = pitcher_stats('Yu Darvish', mlb2020)

# Example of grabbing batter stats
justin_turner = batter_stats('Justin Turner', mlb2020)

joey_gallo = batter_stats('Joey Gallo', mlb2020)

freddy = batter_stats('Freddie Freeman', mlb2020)

# %%
julio_urias.head(10)
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         FF  2020-10-27           96.7           1.58           5.99
# 1      1         FF  2020-10-27           94.1           2.91           5.45
# 2      2         FF  2020-10-27           94.9           1.77           6.02
# 3      3         FF  2020-10-27           94.4           1.66           5.93
# 4      4         CU  2020-10-27           81.4           1.46           6.06
# 5      5         FF  2020-10-27           95.6           1.81           5.95
# 6      6         CU  2020-10-27           80.6           1.50           6.11
# 7      7         FF  2020-10-27           94.7           1.82           5.95
# 8      8         FF  2020-10-27           94.3           1.67           6.11
# 9      9         FF  2020-10-27           95.2           1.72           6.09
#
#   pitcher_name    batter   pitcher     events      description  spin_dir  \
# 0  Julio Urias  642715.0  628711.0  strikeout    called_strike       NaN
# 1  Julio Urias  642715.0  628711.0        NaN    called_strike       NaN
# 2  Julio Urias  642715.0  628711.0        NaN  swinging_strike       NaN
# 3  Julio Urias  670712.0  628711.0  strikeout    called_strike       NaN
# 4  Julio Urias  670712.0  628711.0        NaN             ball       NaN
# 5  Julio Urias  670712.0  628711.0        NaN             ball       NaN
# 6  Julio Urias  670712.0  628711.0        NaN             foul       NaN
# 7  Julio Urias  670712.0  628711.0        NaN             foul       NaN
# 8  Julio Urias  670712.0  628711.0        NaN             ball       NaN
# 9  Julio Urias  622534.0  628711.0  field_out    hit_into_play       NaN
#
#    spin_rate_deprecated  break_angle_deprecated  break_length_deprecated  \
# 0                   NaN                     NaN                      NaN
# 1                   NaN                     NaN                      NaN
# 2                   NaN                     NaN                      NaN
# 3                   NaN                     NaN                      NaN
# 4                   NaN                     NaN                      NaN
# 5                   NaN                     NaN                      NaN
# 6                   NaN                     NaN                      NaN
# 7                   NaN                     NaN                      NaN
# 8                   NaN                     NaN                      NaN
# 9                   NaN                     NaN                      NaN
#
#    zone                                                des game_type stand  \
# 0   4.0              Willy Adames called out on strikes.           W     R
# 1   1.0                                                NaN         W     R
# 2   2.0                                                NaN         W     R
# 3   4.0             Mike Brosseau called out on strikes.           W     R
# 4  13.0                                                NaN         W     R
# 5  11.0                                                NaN         W     R
# 6  13.0                                                NaN         W     R
# 7   5.0                                                NaN         W     R
# 8  12.0                                                NaN         W     R
# 9   6.0  Manuel Margot flies out to right fielder Mooki...         W     R
#
#   p_throws home_team away_team type  hit_location   bb_type  balls  strikes  \
# 0        L       LAD        TB    S           2.0       NaN    0.0      2.0
# 1        L       LAD        TB    S           NaN       NaN    0.0      1.0
# 2        L       LAD        TB    S           NaN       NaN    0.0      0.0
# 3        L       LAD        TB    S           2.0       NaN    3.0      2.0
# 4        L       LAD        TB    B           NaN       NaN    2.0      2.0
# 5        L       LAD        TB    B           NaN       NaN    1.0      2.0
# 6        L       LAD        TB    S           NaN       NaN    1.0      1.0
# 7        L       LAD        TB    S           NaN       NaN    1.0      0.0
# 8        L       LAD        TB    B           NaN       NaN    0.0      0.0
# 9        L       LAD        TB    X           9.0  fly_ball    1.0      2.0
#
#    game_year  pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  \
# 0     2020.0    0.2    1.6    -0.53     2.29    NaN    NaN    NaN
# 1     2020.0    0.8    1.3    -0.55     3.03    NaN    NaN    NaN
# 2     2020.0    0.2    1.5    -0.04     3.32    NaN    NaN    NaN
# 3     2020.0    0.3    1.5    -0.37     2.15    NaN    NaN    NaN
# 4     2020.0   -1.7   -0.2    -0.14     0.96    NaN    NaN    NaN
# 5     2020.0    0.3    1.4    -0.47     3.94    NaN    NaN    NaN
# 6     2020.0   -1.6   -0.1    -0.97     2.06    NaN    NaN    NaN
# 7     2020.0    0.5    1.4     0.08     2.59    NaN    NaN    NaN
# 8     2020.0    0.5    1.4     1.18     3.52    NaN    NaN    NaN
# 9     2020.0    0.4    1.5     0.40     2.56    NaN    NaN    NaN
#
#    outs_when_up  inning inning_topbot    hc_x   hc_y  tfs_deprecated  \
# 0           2.0     9.0           Top     NaN    NaN             NaN
# 1           2.0     9.0           Top     NaN    NaN             NaN
# 2           2.0     9.0           Top     NaN    NaN             NaN
# 3           1.0     9.0           Top     NaN    NaN             NaN
# 4           1.0     9.0           Top     NaN    NaN             NaN
# 5           1.0     9.0           Top     NaN    NaN             NaN
# 6           1.0     9.0           Top     NaN    NaN             NaN
# 7           1.0     9.0           Top     NaN    NaN             NaN
# 8           1.0     9.0           Top     NaN    NaN             NaN
# 9           0.0     9.0           Top  191.34  99.03             NaN
#
#    tfs_zulu_deprecated  fielder_2  umpire  sv_id        vx0         vy0  \
# 0                  NaN   605131.0     NaN    NaN  -5.950264 -140.490456
# 1                  NaN   605131.0     NaN    NaN -10.560246 -136.599519
# 2                  NaN   605131.0     NaN    NaN  -5.199252 -138.098234
# 3                  NaN   605131.0     NaN    NaN  -5.843595 -137.294295
# 4                  NaN   605131.0     NaN    NaN  -0.383207 -118.447810
# 5                  NaN   605131.0     NaN    NaN  -6.600812 -139.135295
# 6                  NaN   605131.0     NaN    NaN  -2.476312 -117.286244
# 7                  NaN   605131.0     NaN    NaN  -5.607907 -137.809921
# 8                  NaN   605131.0     NaN    NaN  -2.392348 -137.363478
# 9                  NaN   605131.0     NaN    NaN  -4.306764 -138.539023
#
#         vz0         ax         ay         az  sz_top  sz_bot  hit_distance_sc  \
# 0 -7.897391   3.772000  32.321911  -8.981441    3.50    1.69              NaN
# 1 -3.429867  11.723598  29.183810 -15.237217    3.50    1.69              NaN
# 2 -4.637970   4.158758  30.838499 -12.535677    3.50    1.69              NaN
# 3 -7.414897   4.754147  30.016237 -11.778755    3.34    1.53              NaN
# 4 -4.454166 -15.553576  24.451936 -32.892744    3.34    1.53              NaN
# 5 -2.905682   5.335650  30.811825 -12.976271    3.34    1.53              NaN
# 6 -2.102737 -13.916321  24.086999 -32.781095    3.34    1.53              9.0
# 7 -6.197171   7.630847  29.808875 -13.053227    3.34    1.53            239.0
# 8 -4.225068   7.109486  29.169727 -13.246297    3.34    1.53              NaN
# 9 -6.867868   6.166594  30.824839 -11.731952    3.25    1.53            284.0
#
#    launch_speed  launch_angle  effective_speed  release_spin_rate  \
# 0           NaN           NaN             95.4             2615.0
# 1           NaN           NaN             93.4             2470.0
# 2           NaN           NaN             94.0             2397.0
# 3           NaN           NaN             93.7             2508.0
# 4           NaN           NaN             80.2             3031.0
# 5           NaN           NaN             94.9             2437.0
# 6          92.8         -16.0             79.3             2971.0
# 7          77.3          29.0             93.9             2478.0
# 8           NaN           NaN             93.6             2581.0
# 9          83.4          44.0             94.0             2450.0
#
#    release_extension   game_pk  pitcher.1  fielder_2.1  fielder_3  fielder_4  \
# 0                5.7  635886.0   628711.0     605131.0   571970.0   571771.0
# 1                5.9  635886.0   628711.0     605131.0   571970.0   571771.0
# 2                5.7  635886.0   628711.0     605131.0   571970.0   571771.0
# 3                5.9  635886.0   628711.0     605131.0   571970.0   571771.0
# 4                5.7  635886.0   628711.0     605131.0   571970.0   571771.0
# 5                5.8  635886.0   628711.0     605131.0   571970.0   571771.0
# 6                5.6  635886.0   628711.0     605131.0   571970.0   571771.0
# 7                5.8  635886.0   628711.0     605131.0   571970.0   571771.0
# 8                5.7  635886.0   628711.0     605131.0   571970.0   571771.0
# 9                5.6  635886.0   628711.0     605131.0   571970.0   571771.0
#
#    fielder_5  fielder_6  fielder_7  fielder_8  fielder_9  release_pos_y  \
# 0   621458.0   608369.0   621035.0   641355.0   605141.0          54.82
# 1   621458.0   608369.0   621035.0   641355.0   605141.0          54.59
# 2   621458.0   608369.0   621035.0   641355.0   605141.0          54.76
# 3   621458.0   608369.0   621035.0   641355.0   605141.0          54.60
# 4   621458.0   608369.0   621035.0   641355.0   605141.0          54.84
# 5   621458.0   608369.0   621035.0   641355.0   605141.0          54.66
# 6   621458.0   608369.0   621035.0   641355.0   605141.0          54.94
# 7   621458.0   608369.0   621035.0   641355.0   605141.0          54.72
# 8   621458.0   608369.0   621035.0   641355.0   605141.0          54.79
# 9   621458.0   608369.0   621035.0   641355.0   605141.0          54.92
#
#    estimated_ba_using_speedangle  estimated_woba_using_speedangle  woba_value  \
# 0                            NaN                              NaN         0.0
# 1                            NaN                              NaN         NaN
# 2                            NaN                              NaN         NaN
# 3                            NaN                              NaN         0.0
# 4                            NaN                              NaN         NaN
# 5                            NaN                              NaN         NaN
# 6                            NaN                              NaN         NaN
# 7                            NaN                              NaN         NaN
# 8                            NaN                              NaN         NaN
# 9                          0.029                             0.04         0.0
#
#    woba_denom  babip_value  iso_value  launch_speed_angle  at_bat_number  \
# 0         1.0          0.0        0.0                 NaN           65.0
# 1         NaN          NaN        NaN                 NaN           65.0
# 2         NaN          NaN        NaN                 NaN           65.0
# 3         1.0          0.0        0.0                 NaN           64.0
# 4         NaN          NaN        NaN                 NaN           64.0
# 5         NaN          NaN        NaN                 NaN           64.0
# 6         NaN          NaN        NaN                 NaN           64.0
# 7         NaN          NaN        NaN                 NaN           64.0
# 8         NaN          NaN        NaN                 NaN           64.0
# 9         1.0          0.0        0.0                 3.0           63.0
#
#    pitch_number       pitch_name  home_score  away_score  bat_score  \
# 0           3.0  4-Seam Fastball         3.0         1.0        1.0
# 1           2.0  4-Seam Fastball         3.0         1.0        1.0
# 2           1.0  4-Seam Fastball         3.0         1.0        1.0
# 3           6.0  4-Seam Fastball         3.0         1.0        1.0
# 4           5.0        Curveball         3.0         1.0        1.0
# 5           4.0  4-Seam Fastball         3.0         1.0        1.0
# 6           3.0        Curveball         3.0         1.0        1.0
# 7           2.0  4-Seam Fastball         3.0         1.0        1.0
# 8           1.0  4-Seam Fastball         3.0         1.0        1.0
# 9           4.0  4-Seam Fastball         3.0         1.0        1.0
#
#    fld_score  post_away_score  post_home_score  post_bat_score  \
# 0        3.0              1.0              3.0             1.0
# 1        3.0              1.0              3.0             1.0
# 2        3.0              1.0              3.0             1.0
# 3        3.0              1.0              3.0             1.0
# 4        3.0              1.0              3.0             1.0
# 5        3.0              1.0              3.0             1.0
# 6        3.0              1.0              3.0             1.0
# 7        3.0              1.0              3.0             1.0
# 8        3.0              1.0              3.0             1.0
# 9        3.0              1.0              3.0             1.0
#
#    post_fld_score if_fielding_alignment of_fielding_alignment strike_attempt  \
# 0             3.0              Standard              Standard         strike
# 1             3.0              Standard              Standard         strike
# 2             3.0              Standard              Standard         strike
# 3             3.0              Standard              Standard         strike
# 4             3.0              Standard              Standard           ball
# 5             3.0              Standard              Standard           ball
# 6             3.0         Infield shift              Standard         strike
# 7             3.0         Infield shift              Standard         strike
# 8             3.0         Infield shift              Standard           ball
# 9             3.0              Standard              Standard            out
#
#      batter_name
# 0   Willy Adames
# 1   Willy Adames
# 2   Willy Adames
# 3  Mike Brosseau
# 4  Mike Brosseau
# 5  Mike Brosseau
# 6  Mike Brosseau
# 7  Mike Brosseau
# 8  Mike Brosseau
# 9  Manuel Margot

# %%
julio_urias['strike_attempt'].value_counts(normalize=True)
# Out:
# strike    0.496779
# ball      0.332528
# out       0.122383
# ob        0.048309
# Name: strike_attempt, dtype: float64

# %%
julio_urias['description'].value_counts(normalize=True)
# Out:
# ball                       0.318841
# foul                       0.194847
# called_strike              0.159420
# swinging_strike            0.123994
# hit_into_play              0.122383
# hit_into_play_no_out       0.033011
# hit_into_play_score        0.015298
# blocked_ball               0.013688
# foul_tip                   0.012882
# swinging_strike_blocked    0.005636
# Name: description, dtype: float64

# %%
joey_gallo['strike_attempt'].value_counts(normalize=True)
# Out:
# strike    0.474737
# ball      0.401053
# out       0.080000
# ob        0.044211
# Name: strike_attempt, dtype: float64

# %%
freddy['strike_attempt'].value_counts(normalize=True)
# Out:
# strike    0.414018
# ball      0.408313
# out       0.103504
# ob        0.074165
# Name: strike_attempt, dtype: float64

# %%
justin_turner['strike_attempt'].value_counts(normalize=True)
# Out:
# strike    0.429150
# ball      0.384615
# out       0.110324
# ob        0.075911
# Name: strike_attempt, dtype: float64
