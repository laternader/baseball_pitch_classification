# %% [markdown]
# # Data Dictionary
#
# ---
# | column name 	| dtype 	| description 	|
# |-	|-	|-	|
# | game_date 	| datetime64[ns] 	| Date of the game 	|
# | pitch_type 	| object 	| The type of pitch derived from Statcast 	|
# | Pitcher_name 	| object 	| Name of the pitcher 	|
# | pitcher_id 	| int 	| ID of the pitcher 	|
# | batter_name 	| object 	| Name of the batter 	|
# | batter_id 	| int 	| ID of the batter 	|
# | release_speed 	| float64 	| Pitch velocities from 2008-16 are via Pitch F/X, and adjusted to roughly out-of-hand release point. All velocities from 2017 and beyond are Statcast, which are reported out-of-hand. 	|
# | release_pos_x 	| float64 	| Horizontal Release Position of the ball measured in feet from the catcher's perspective 	|
# | release_pos_z 	| float64 	| Vertical Release Position of the ball measured in feet from the catcher's perspective 	|
# | stand 	| uint8 	| Side of the plate batter is standing. (R = 1, L = 0) 	|
# | p_throws 	| uint8 	| Hand pitcher throws with. (R = 1, L = 0) 	|
# | balls 	| float64 	| Pre-pitch number of balls in count. 	|
# | strikes 	| float64 	| Pre-pitch number of strikes in count. 	|
# | pfx_x 	| float64 	| Horizontal movement in feet from the catcher's perspective. 	|
# | pfx_z 	| float64 	| Vertical movement in feet from the catcher's perpsective. 	|
# | plate_x 	| float64 	| Horizontal position of the ball when it crosses home plate from the catcher's perspective. 	|
# | plate_z 	| float64 	| Vertical position of the ball when it crosses home plate from the catcher's perspective. 	|
# | on_3b 	| int 	| Pre-pitch MLB Player Id of Runner on 3B. 	|
# | on_2b 	| int 	| Pre-pitch MLB Player Id of Runner on 2B. 	|
# | on_1b 	| int 	| Pre-pitch MLB Player Id of Runner on 1B. 	|
# | inning 	| int 	| Pre-pitch inning number.  	|
# | inning_topbot 	| uint8 	| Pre-pitch top or bottom of inning. (Bottom = 0, Top = 1) 	|
# | effective_speed 	| float64 	| Derived speed based on the the extension of the pitcher's release. 	|
# | release_spin_rate 	| float64 	| Spin rate of pitch tracked by Statcast. 	|
# | release_extension 	| float64 	| Release extension of pitch in feet as tracked by Statcast. 	|
# | Catcher 	| int 	| MLB Player Id for catcher. 	|
# | FirstBasemen 	| int 	| MLB Player Id for 1B. 	|
# | SecondBasemen 	| int 	| MLB Player Id for 2B. 	|
# | ThirdBasemen 	| int 	| MLB Player Id for 3B. 	|
# | ShortStop 	| int 	| MLB Player Id for SS. 	|
# | LeftField 	| int 	| MLB Player Id for LF. 	|
# | CenterField 	| int 	| MLB Player Id for CF. 	|
# | RightField 	| int 	| MLB Player Id for RF. 	|
# | at_bat_number 	| int 	| Plate appearance number of the game. 	|
# | pitch_number 	| int 	| Total pitch number of the plate appearance. 	|
# | pitch_name 	| object 	| The name of the pitch derived from the Statcast Data. 	|
# | bat_score 	| int 	| Pre-pitch bat team score 	|
# | fld_score 	| int 	| Pre-pitch field team score 	|
# | post_bat_score 	| int 	| Post-pitch bat team score 	|
# | post_fld_score 	| int 	| Post-pitch field team score 	|
# | if_fielding_alignment 	| object 	| Infield fielding alignment at the time of the pitch. 	|
# | of_fielding_alignment 	| object 	| Outfield fielding alignment at the time of the pitch. 	|
# | count 	| object 	| Shows the pre-pitch count in a nicer format. 	|
# | strike_attempt 	| object 	| (Y) The result of what happened to the pitch: strike, out, ball, or on-base(ob). 	|
# | events 	| object 	| Event of the resulting Plate Appearance. 	|
# | description 	| object 	| Description of the resulting pitch. 	|
# | type 	| object 	| Short hand of pitch result. B = ball, S = strike, X = in play. 	|
# | bb_type 	| object 	| Batted ball type, ground_ball, line_drive, fly_ball, popup. 	|
# | vx0 	| float64 	| The velocity of the pitch, in feet per second, in x-dimension, determined at y=50 feet. 	|
# | vy0 	| float64 	| The velocity of the pitch, in feet per second, in y-dimension, determined at y=50 feet. 	|
# | vz0 	| float64 	| The velocity of the pitch, in feet per second, in z-dimension, determined at y=50 feet. 	|
# | ax 	| float64 	| The acceleration of the pitch, in feet per second per second, in x-dimension, determined at y=50 feet. 	|
# | ay 	| float64 	| The acceleration of the pitch, in feet per second per second, in y-dimension, determined at y=50 feet. 	|
# | az 	| float64 	| The acceleration of the pitch, in feet per second per second, in z-dimension, determined at y=50 feet. 	|
# | outs_when_up 	| int 	| Pre-pitch number of outs. 	|
#
# ```python
# ids = ['pitcher_id','batter_id','on_1b','on_2b','on_3b','Catcher','FirstBasemen',
#       'SecondBasemen', 'ThirdBasemen', 'ShortStop', 'LeftField','CenterField', 'RightField']
# ```
# These columns are IDs.

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pybaseball as pb
import project_baseball as project

pd.set_option('display.max_columns', None)

# %%
# Import cleaned data
mlb20 = pd.read_csv('data/2020cleaned.csv')
mlb19 = pd.read_csv('data/2019cleaned.csv')
mlb18 = pd.read_csv('data/2018cleaned.csv')
mlb17 = pd.read_csv('data/2017cleaned.csv')
mlb16 = pd.read_csv('data/2016cleaned.csv')
df = pd.read_csv('data/big_daddy_baseball.csv')
df_cleaned = pd.read_csv('data/big_daddy_baseball_cleaned.csv')

# %%
mlb16.head()
# Out:
#     game_date pitch_type      Pitcher_name  pitcher_id       batter_name  \
# 0  2016-11-02         CU   Mike Montgomery    543557.0  Michael Martinez
# 1  2016-11-02         CU   Mike Montgomery    543557.0  Michael Martinez
# 2  2016-11-02         FF  Carl Edwards Jr.    605218.0       Rajai Davis
# 3  2016-11-02         FF  Carl Edwards Jr.    605218.0       Rajai Davis
# 4  2016-11-02         FF  Carl Edwards Jr.    605218.0     Brandon Guyer
#
#    batter_id  release_speed  release_pos_x  release_pos_z stand p_throws  \
# 0   492841.0           76.6           2.72           6.39     R        L
# 1   492841.0           74.3           2.82           6.28     R        L
# 2   434658.0           94.9          -1.50           6.08     R        R
# 3   434658.0           95.6          -1.46           6.09     R        R
# 4   446386.0           94.8          -1.40           5.95     R        R
#
#    balls  strikes  pfx_x  pfx_z  plate_x  plate_z  on_3b     on_2b     on_1b  \
# 0    0.0      1.0   -0.8   -1.1     0.75     2.85    NaN       NaN  434658.0
# 1    0.0      0.0   -0.7   -1.1     0.43     2.64    NaN       NaN  434658.0
# 2    1.0      0.0   -0.1    1.7     0.05     1.56    NaN  446386.0       NaN
# 3    0.0      0.0   -0.4    1.7     0.40     1.04    NaN       NaN  446386.0
# 4    3.0      1.0    0.0    1.4     0.16     0.78    NaN       NaN       NaN
#
#    inning inning_topbot  effective_speed  release_spin_rate  \
# 0    10.0           Bot             76.9             2324.0
# 1    10.0           Bot             74.3             2478.0
# 2    10.0           Bot             96.3             2636.0
# 3    10.0           Bot             97.2             2672.0
# 4    10.0           Bot             96.8             2712.0
#
#    release_extension   Catcher  FirstBasemen  SecondBasemen  ThirdBasemen  \
# 0                6.2  471083.0      519203.0       595879.0      592178.0
# 1                6.0  471083.0      519203.0       595879.0      592178.0
# 2                6.8  471083.0      519203.0       595879.0      592178.0
# 3                6.8  471083.0      519203.0       595879.0      592178.0
# 4                6.7  471083.0      519203.0       595879.0      592178.0
#
#    ShortStop  LeftField  CenterField  RightField  at_bat_number  pitch_number  \
# 0   608365.0   450314.0     451594.0    518792.0           89.0           2.0
# 1   608365.0   450314.0     451594.0    518792.0           89.0           1.0
# 2   608365.0   450314.0     451594.0    518792.0           88.0           2.0
# 3   608365.0   450314.0     451594.0    518792.0           88.0           1.0
# 4   608365.0   450314.0     451594.0    518792.0           87.0           5.0
#
#         pitch_name  bat_score  fld_score  post_bat_score  post_fld_score  \
# 0        Curveball        7.0        8.0             7.0             8.0
# 1        Curveball        7.0        8.0             7.0             8.0
# 2  4-Seam Fastball        6.0        8.0             6.0             8.0
# 3  4-Seam Fastball        6.0        8.0             6.0             8.0
# 4  4-Seam Fastball        6.0        8.0             6.0             8.0
#
#   if_fielding_alignment of_fielding_alignment count strike_attempt     events  \
# 0              Standard              Standard   0-1            out  field_out
# 1              Standard              Standard   0-0         strike        NaN
# 2              Standard              Standard   1-0             ob     single
# 3              Standard              Standard   0-0           ball        NaN
# 4              Standard              Standard   3-1           ball       walk
#
#            description type      bb_type    vx0      vy0     vz0     ax  \
# 0        hit_into_play    X  ground_ball -3.206 -111.550   1.462 -5.837
# 1        called_strike    S          NaN -4.155 -108.216   1.520 -4.543
# 2  hit_into_play_score    X   line_drive  3.378 -137.703 -10.286 -0.221
# 3                 ball    B          NaN  4.780 -138.573 -12.000 -3.197
# 4                 ball    B          NaN  2.838 -137.534 -11.396  2.476
#
#        ay      az  outs_when_up
# 0  20.536 -43.549           2.0
# 1  19.370 -42.641           2.0
# 2  29.317 -11.776           2.0
# 3  25.774 -11.146           2.0
# 4  23.633 -15.029           2.0

# %%
# check columns match in every way
mlb20.columns == mlb16.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %% [markdown]
# # EDA
#
# ---
# Let's look at the trends of data over the past five seasons including the playoffs.

# %%
df.columns
# Out:
# Index(['game_date', 'pitch_type', 'Pitcher_name', 'pitcher_id', 'batter_name',
#        'batter_id', 'release_speed', 'release_pos_x', 'release_pos_z', 'stand',
#        'p_throws', 'balls', 'strikes', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z',
#        'on_3b', 'on_2b', 'on_1b', 'inning', 'inning_topbot', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'Catcher', 'FirstBasemen',
#        'SecondBasemen', 'ThirdBasemen', 'ShortStop', 'LeftField',
#        'CenterField', 'RightField', 'at_bat_number', 'pitch_number',
#        'pitch_name', 'bat_score', 'fld_score', 'post_bat_score',
#        'post_fld_score', 'if_fielding_alignment', 'of_fielding_alignment',
#        'count', 'strike_attempt', 'events', 'description', 'type', 'bb_type',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'outs_when_up'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3212938 entries, 0 to 3212937
# Data columns (total 55 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   game_date              object
#  1   pitch_type             object
#  2   Pitcher_name           object
#  3   pitcher_id             int64
#  4   batter_name            object
#  5   batter_id              int64
#  6   release_speed          float64
#  7   release_pos_x          float64
#  8   release_pos_z          float64
#  9   stand                  int64
#  10  p_throws               int64
#  11  balls                  int64
#  12  strikes                int64
#  13  pfx_x                  float64
#  14  pfx_z                  float64
#  15  plate_x                float64
#  16  plate_z                float64
#  17  on_3b                  int64
#  18  on_2b                  int64
#  19  on_1b                  int64
#  20  inning                 int64
#  21  inning_topbot          int64
#  22  effective_speed        float64
#  23  release_spin_rate      float64
#  24  release_extension      float64
#  25  Catcher                int64
#  26  FirstBasemen           int64
#  27  SecondBasemen          int64
#  28  ThirdBasemen           int64
#  29  ShortStop              int64
#  30  LeftField              int64
#  31  CenterField            int64
#  32  RightField             int64
#  33  at_bat_number          int64
#  34  pitch_number           int64
#  35  pitch_name             object
#  36  bat_score              int64
#  37  fld_score              int64
#  38  post_bat_score         int64
#  39  post_fld_score         int64
#  40  if_fielding_alignment  object
#  41  of_fielding_alignment  object
#  42  count                  object
#  43  strike_attempt         object
#  44  events                 object
#  45  description            object
#  46  type                   object
#  47  bb_type                object
#  48  vx0                    float64
#  49  vy0                    float64
#  50  vz0                    float64
#  51  ax                     float64
#  52  ay                     float64
#  53  az                     float64
#  54  outs_when_up           int64
# dtypes: float64(16), int64(26), object(13)
# memory usage: 1.3+ GB

# %%
df.describe(include='all')
# Out:
#          game_date pitch_type      Pitcher_name    pitcher_id batter_name  \
# count      3212938    3212938           3212938  3.212938e+06     3212938
# unique         913         11              1517           NaN        2291
# top     2020-09-04         FF  Justin Verlander           NaN         J.
# freq          5640    1135708             15568           NaN       18923
# mean           NaN        NaN               NaN  5.494827e+05         NaN
# std            NaN        NaN               NaN  7.534544e+04         NaN
# min            NaN        NaN               NaN  1.125260e+05         NaN
# 25%            NaN        NaN               NaN  5.016970e+05         NaN
# 50%            NaN        NaN               NaN  5.702400e+05         NaN
# 75%            NaN        NaN               NaN  6.055400e+05         NaN
# max            NaN        NaN               NaN  6.854930e+05         NaN
#
#            batter_id  release_speed  release_pos_x  release_pos_z    stand  \
# count   3.212938e+06   3.198198e+06   3.189757e+06   3.189757e+06  3212938
# unique           NaN            NaN            NaN            NaN        2
# top              NaN            NaN            NaN            NaN        R
# freq             NaN            NaN            NaN            NaN  1876519
# mean    5.442058e+05   8.866974e+01  -8.019256e-01   5.931463e+00      NaN
# std     7.745715e+04   6.017740e+00   2.227390e+01   3.726005e+01      NaN
# min     1.125260e+05   3.810000e+01  -2.521450e+04  -3.000000e-02      NaN
# 25%     4.767040e+05   8.450000e+01  -2.190000e+00   5.630000e+00      NaN
# 50%     5.471720e+05   9.000000e+01  -1.530000e+00   5.930000e+00      NaN
# 75%     6.051130e+05   9.330000e+01   9.800000e-01   6.210000e+00      NaN
# max     6.807770e+05   1.057000e+02   2.942509e+04   4.616850e+04      NaN
#
#        p_throws         balls       strikes         pfx_x         pfx_z  \
# count   3212938  3.212938e+06  3.212938e+06  3.200829e+06  3.200829e+06
# unique        2           NaN           NaN           NaN           NaN
# top           R           NaN           NaN           NaN           NaN
# freq    2343572           NaN           NaN           NaN           NaN
# mean        NaN  8.883377e-01  8.908557e-01 -1.808209e-01  7.403970e-01
# std         NaN  9.690400e-01  8.260539e-01  1.051005e+00  1.061793e+00
# min         NaN  0.000000e+00  0.000000e+00 -1.013900e+03 -1.600000e+01
# 25%         NaN  0.000000e+00  0.000000e+00 -9.000000e-01  3.000000e-01
# 50%         NaN  1.000000e+00  1.000000e+00 -3.000000e-01  9.000000e-01
# 75%         NaN  2.000000e+00  2.000000e+00  5.000000e-01  1.300000e+00
# max         NaN  4.000000e+00  2.000000e+00  1.752000e+02  1.281700e+03
#
#              plate_x       plate_z          on_3b          on_2b  \
# count   3.200829e+06  3.200829e+06  301461.000000  591896.000000
# unique           NaN           NaN            NaN            NaN
# top              NaN           NaN            NaN            NaN
# freq             NaN           NaN            NaN            NaN
# mean    3.087645e-02  2.284933e+00  545453.284355  545267.611857
# std     2.264207e+01  3.557962e+01   76658.825472   76548.462279
# min    -2.642677e+04 -2.848000e+01  112526.000000  112526.000000
# 25%    -5.600000e-01  1.640000e+00  488726.000000  488726.000000
# 50%     3.000000e-02  2.260000e+00  547180.000000  547180.000000
# 75%     6.200000e-01  2.870000e+00  605137.000000  605137.000000
# max     2.950113e+04  4.547908e+04  680777.000000  680777.000000
#
#                 on_1b        inning inning_topbot  effective_speed  \
# count   979029.000000  3.212938e+06       3212938     3.188344e+06
# unique            NaN           NaN             2              NaN
# top               NaN           NaN           Top              NaN
# freq              NaN           NaN       1636241              NaN
# mean    543304.122539  4.994990e+00           NaN     8.821389e+01
# std      77405.029037  2.663342e+00           NaN     6.613052e+00
# min     112526.000000  1.000000e+00           NaN     0.000000e+00
# 25%     475582.000000  3.000000e+00           NaN     8.400000e+01
# 50%     545361.000000  5.000000e+00           NaN     8.960000e+01
# 75%     600869.000000  7.000000e+00           NaN     9.310000e+01
# max     680777.000000  1.900000e+01           NaN     1.946000e+02
#
#         release_spin_rate  release_extension       Catcher  FirstBasemen  \
# count        3.104524e+06       3.186717e+06  3.204070e+06  3.204070e+06
# unique                NaN                NaN           NaN           NaN
# top                   NaN                NaN           NaN           NaN
# freq                  NaN                NaN           NaN           NaN
# mean         2.229467e+03       6.043558e+00  5.260236e+05  5.249564e+05
# std          3.220069e+02       5.094527e-01  6.862932e+04  6.945231e+04
# min          4.130000e+02      -9.000000e-01  1.502290e+05  1.200740e+05
# 25%          2.081000e+03       5.700000e+00  4.577630e+05  4.725280e+05
# 50%          2.253000e+03       6.000000e+00  5.216920e+05  5.190480e+05
# 75%          2.417000e+03       6.400000e+00  5.759290e+05  5.722330e+05
# max          3.741000e+03       1.100000e+01  6.807770e+05  6.707120e+05
#
#         SecondBasemen  ThirdBasemen     ShortStop     LeftField   CenterField  \
# count    3.204070e+06  3.204070e+06  3.204070e+06  3.204070e+06  3.204070e+06
# unique            NaN           NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN           NaN
# mean     5.538044e+05  5.515431e+05  5.704851e+05  5.480825e+05  5.587756e+05
# std      6.770486e+04  8.011837e+04  6.395592e+04  8.459324e+04  6.735890e+04
# min      4.002840e+05  1.213470e+05  2.765190e+05  1.368600e+05  4.000850e+05
# 25%      5.149170e+05  5.018960e+05  5.423400e+05  4.613140e+05  5.167820e+05
# 50%      5.705600e+05  5.718750e+05  5.934280e+05  5.715530e+05  5.717400e+05
# 75%      6.054120e+05  6.008690e+05  6.083690e+05  6.086540e+05  6.076800e+05
# max      6.712770e+05  6.707120e+05  6.764800e+05  6.734510e+05  6.734510e+05
#
#           RightField  at_bat_number  pitch_number       pitch_name  \
# count   3.204070e+06   3.212938e+06  3.212938e+06          3212938
# unique           NaN            NaN           NaN               16
# top              NaN            NaN           NaN  4-Seam Fastball
# freq             NaN            NaN           NaN          1135708
# mean    5.480923e+05   3.911947e+01  2.912104e+00              NaN
# std     7.049311e+04   2.313338e+01  1.735179e+00              NaN
# min     1.368600e+05   1.000000e+00  1.000000e+00              NaN
# 25%     5.008740e+05   1.900000e+01  1.000000e+00              NaN
# 50%     5.714370e+05   3.900000e+01  3.000000e+00              NaN
# 75%     5.961460e+05   5.800000e+01  4.000000e+00              NaN
# max     6.712500e+05   1.510000e+02  2.100000e+01              NaN
#
#            bat_score     fld_score  post_bat_score  post_fld_score  \
# count   3.212938e+06  3.212938e+06    3.212938e+06    3.212938e+06
# unique           NaN           NaN             NaN             NaN
# top              NaN           NaN             NaN             NaN
# freq             NaN           NaN             NaN             NaN
# mean    2.318636e+00  2.359239e+00    2.318715e+00    2.359239e+00
# std     2.609796e+00  2.698448e+00    2.609833e+00    2.698448e+00
# min     0.000000e+00  0.000000e+00    0.000000e+00    0.000000e+00
# 25%     0.000000e+00  0.000000e+00    0.000000e+00    0.000000e+00
# 50%     2.000000e+00  2.000000e+00    2.000000e+00    2.000000e+00
# 75%     4.000000e+00  4.000000e+00    4.000000e+00    4.000000e+00
# max     2.900000e+01  2.900000e+01    2.900000e+01    2.900000e+01
#
#        if_fielding_alignment of_fielding_alignment    count strike_attempt  \
# count                3212938               3212938  3212938        3209607
# unique                     4                     5       14              4
# top                 Standard              Standard      0-0         strike
# freq                 2303434               2948445   822227        1480962
# mean                     NaN                   NaN      NaN            NaN
# std                      NaN                   NaN      NaN            NaN
# min                      NaN                   NaN      NaN            NaN
# 25%                      NaN                   NaN      NaN            NaN
# 50%                      NaN                   NaN      NaN            NaN
# 75%                      NaN                   NaN      NaN            NaN
# max                      NaN                   NaN      NaN            NaN
#
#            events description     type      bb_type           vx0  \
# count      821529     3212938  3212938       561911  3.200829e+06
# unique         34          19        3            4           NaN
# top     field_out        ball        S  ground_ball           NaN
# freq       324911     1081635  1481027       251874           NaN
# mean          NaN         NaN      NaN          NaN  2.358151e+00
# std           NaN         NaN      NaN          NaN  5.999919e+00
# min           NaN         NaN      NaN          NaN -5.718084e+01
# 25%           NaN         NaN      NaN          NaN -2.151512e+00
# 50%           NaN         NaN      NaN          NaN  4.100155e+00
# 75%           NaN         NaN      NaN          NaN  6.712834e+00
# max           NaN         NaN      NaN          NaN  1.852271e+02
#
#                  vy0           vz0            ax            ay            az  \
# count   3.200829e+06  3.200829e+06  3.200829e+06  3.200829e+06  3.200829e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean   -1.288463e+02 -4.312600e+00 -2.476377e+00  2.614176e+01 -2.300083e+01
# std     8.723895e+00  3.078021e+00  1.060744e+01  3.975267e+00  8.900092e+00
# min    -7.721720e+02 -7.512015e+01 -1.279061e+02 -8.386989e+01 -1.843371e+02
# 25%    -1.356025e+02 -6.392600e+00 -1.136622e+01  2.319353e+01 -2.908582e+01
# 50%    -1.307080e+02 -4.486616e+00 -3.044696e+00  2.612600e+01 -2.190531e+01
# 75%    -1.228367e+02 -2.386334e+00  5.653196e+00  2.896976e+01 -1.576900e+01
# max    -5.455437e+01  4.609421e+02  1.826535e+02  8.949168e+01  1.832867e+02
#
#         outs_when_up
# count   3.212938e+06
# unique           NaN
# top              NaN
# freq             NaN
# mean    9.804814e-01
# std     8.174726e-01
# min     0.000000e+00
# 25%     0.000000e+00
# 50%     1.000000e+00
# 75%     2.000000e+00
# max     2.000000e+00

# %%
df.head()
# Out:
#     game_date pitch_type Pitcher_name  pitcher_id    batter_name  batter_id  \
# 0  2020-10-27         FF  Julio Urias    628711.0   Willy Adames   642715.0
# 1  2020-10-27         FF  Julio Urias    628711.0   Willy Adames   642715.0
# 2  2020-10-27         FF  Julio Urias    628711.0   Willy Adames   642715.0
# 3  2020-10-27         FF  Julio Urias    628711.0  Mike Brosseau   670712.0
# 4  2020-10-27         CU  Julio Urias    628711.0  Mike Brosseau   670712.0
#
#    release_speed  release_pos_x  release_pos_z stand p_throws  balls  strikes  \
# 0           96.7           1.58           5.99     R        L    0.0      2.0
# 1           94.1           2.91           5.45     R        L    0.0      1.0
# 2           94.9           1.77           6.02     R        L    0.0      0.0
# 3           94.4           1.66           5.93     R        L    3.0      2.0
# 4           81.4           1.46           6.06     R        L    2.0      2.0
#
#    pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  inning inning_topbot  \
# 0    0.2    1.6    -0.53     2.29    NaN    NaN    NaN     9.0           Top
# 1    0.8    1.3    -0.55     3.03    NaN    NaN    NaN     9.0           Top
# 2    0.2    1.5    -0.04     3.32    NaN    NaN    NaN     9.0           Top
# 3    0.3    1.5    -0.37     2.15    NaN    NaN    NaN     9.0           Top
# 4   -1.7   -0.2    -0.14     0.96    NaN    NaN    NaN     9.0           Top
#
#    effective_speed  release_spin_rate  release_extension   Catcher  \
# 0             95.4             2615.0                5.7  605131.0
# 1             93.4             2470.0                5.9  605131.0
# 2             94.0             2397.0                5.7  605131.0
# 3             93.7             2508.0                5.9  605131.0
# 4             80.2             3031.0                5.7  605131.0
#
#    FirstBasemen  SecondBasemen  ThirdBasemen  ShortStop  LeftField  \
# 0      571970.0       571771.0      621458.0   608369.0   621035.0
# 1      571970.0       571771.0      621458.0   608369.0   621035.0
# 2      571970.0       571771.0      621458.0   608369.0   621035.0
# 3      571970.0       571771.0      621458.0   608369.0   621035.0
# 4      571970.0       571771.0      621458.0   608369.0   621035.0
#
#    CenterField  RightField  at_bat_number  pitch_number       pitch_name  \
# 0     641355.0    605141.0           65.0           3.0  4-Seam Fastball
# 1     641355.0    605141.0           65.0           2.0  4-Seam Fastball
# 2     641355.0    605141.0           65.0           1.0  4-Seam Fastball
# 3     641355.0    605141.0           64.0           6.0  4-Seam Fastball
# 4     641355.0    605141.0           64.0           5.0        Curveball
#
#    bat_score  fld_score  post_bat_score  post_fld_score if_fielding_alignment  \
# 0        1.0        3.0             1.0             3.0              Standard
# 1        1.0        3.0             1.0             3.0              Standard
# 2        1.0        3.0             1.0             3.0              Standard
# 3        1.0        3.0             1.0             3.0              Standard
# 4        1.0        3.0             1.0             3.0              Standard
#
#   of_fielding_alignment count strike_attempt     events      description type  \
# 0              Standard   0-2         strike  strikeout    called_strike    S
# 1              Standard   0-1         strike        NaN    called_strike    S
# 2              Standard   0-0         strike        NaN  swinging_strike    S
# 3              Standard   3-2         strike  strikeout    called_strike    S
# 4              Standard   2-2           ball        NaN             ball    B
#
#   bb_type        vx0         vy0       vz0         ax         ay         az  \
# 0     NaN  -5.950264 -140.490456 -7.897391   3.772000  32.321911  -8.981441
# 1     NaN -10.560246 -136.599519 -3.429867  11.723598  29.183810 -15.237217
# 2     NaN  -5.199252 -138.098234 -4.637970   4.158758  30.838499 -12.535677
# 3     NaN  -5.843595 -137.294295 -7.414897   4.754147  30.016237 -11.778755
# 4     NaN  -0.383207 -118.447810 -4.454166 -15.553576  24.451936 -32.892744
#
#    outs_when_up
# 0           2.0
# 1           2.0
# 2           2.0
# 3           1.0
# 4           1.0

# %% [markdown]
# ## Unexpected Nulls
#
# ---
# The amount of nulls is surprising in some categories. Places where I expect nulls to be are in `'on_3b', 'on_2b', 'on_1b','events','bb_type'` since there are innings where people are not on base and not everyone can guarantee an out without ever striking out in their entire career.
#
# What I did not expect to see was NaNs in the fielder spots because you can't play baseball without 9 men on the field. I also did not expect to see release speeds missing or the velocities/accelerations of aputch to be missing. Someone was not doing their job when they were recording these stats.
#
# *This will get fixed in the cleaning notebook. This is something good to note prior to cleaning.*

# %%
df.isnull().sum()
# Out:
# game_date                      0
# pitch_type                     0
# Pitcher_name                   0
# pitcher_id                     0
# batter_name                    0
# batter_id                      0
# release_speed              14740
# release_pos_x              23181
# release_pos_z              23181
# stand                          0
# p_throws                       0
# balls                          0
# strikes                        0
# pfx_x                      12109
# pfx_z                      12109
# plate_x                    12109
# plate_z                    12109
# on_3b                    2911477
# on_2b                    2621042
# on_1b                    2233909
# inning                         0
# inning_topbot                  0
# effective_speed            24594
# release_spin_rate         108414
# release_extension          26221
# Catcher                     8868
# FirstBasemen                8868
# SecondBasemen               8868
# ThirdBasemen                8868
# ShortStop                   8868
# LeftField                   8868
# CenterField                 8868
# RightField                  8868
# at_bat_number                  0
# pitch_number                   0
# pitch_name                     0
# bat_score                      0
# fld_score                      0
# post_bat_score                 0
# post_fld_score                 0
# if_fielding_alignment          0
# of_fielding_alignment          0
# count                          0
# strike_attempt              3331
# events                   2391409
# description                    0
# type                           0
# bb_type                  2651027
# vx0                        12109
# vy0                        12109
# vz0                        12109
# ax                         12109
# ay                         12109
# az                         12109
# outs_when_up                   0
# dtype: int64

# %% [markdown]
# There is also way too many rows containing nulls. If I am to drop any nulls, I need to be weary of how I am dropping them since if I do, 13 million data points are missing.

# %%
df.isnull().sum().sum()
# over 13 million data points are nulls
# Out:
# 13224560

# %% [markdown]
# ## After Cleaning `df` and importing `df_cleaned`

# %%
df_cleaned.isnull().sum()
# Out:
# game_date                      0
# pitch_type                     0
# Pitcher_name                   0
# pitcher_id                     0
# batter_name                    0
# batter_id                      0
# release_speed              14740
# release_pos_x              23181
# release_pos_z              23181
# stand                          0
# p_throws                       0
# balls                          0
# strikes                        0
# pfx_x                      12109
# pfx_z                      12109
# plate_x                    12109
# plate_z                    12109
# on_3b                          0
# on_2b                          0
# on_1b                          0
# inning                         0
# inning_topbot                  0
# effective_speed            24594
# release_spin_rate         108414
# release_extension          26221
# Catcher                        0
# FirstBasemen                   0
# SecondBasemen                  0
# ThirdBasemen                   0
# ShortStop                      0
# LeftField                      0
# CenterField                    0
# RightField                     0
# at_bat_number                  0
# pitch_number                   0
# pitch_name                     0
# bat_score                      0
# fld_score                      0
# post_bat_score                 0
# post_fld_score                 0
# if_fielding_alignment          0
# of_fielding_alignment          0
# count                          0
# strike_attempt              3331
# events                   2391409
# description                    0
# type                           0
# bb_type                  2651027
# vx0                        12109
# vy0                        12109
# vz0                        12109
# ax                         12109
# ay                         12109
# az                         12109
# outs_when_up                   0
# dtype: int64

# %%
df_cleaned.isnull().sum().sum()
# now only 500k remain as nulls
# Out:
# 5387188

# %%
df_cleaned.head(200)
# Out:
#       game_date pitch_type   Pitcher_name  pitcher_id      batter_name  \
# 0    2020-10-27         FF    Julio Urias      628711     Willy Adames
# 1    2020-10-27         FF    Julio Urias      628711     Willy Adames
# 2    2020-10-27         FF    Julio Urias      628711     Willy Adames
# 3    2020-10-27         FF    Julio Urias      628711    Mike Brosseau
# 4    2020-10-27         CU    Julio Urias      628711    Mike Brosseau
# ..          ...        ...            ...         ...              ...
# 195  2020-10-27         FF    Blake Snell      605483        Max Muncy
# 196  2020-10-27         CH    Dylan Floro      571670  Randy Arozarena
# 197  2020-10-27         CH    Dylan Floro      571670  Randy Arozarena
# 198  2020-10-27         CH    Dylan Floro      571670  Randy Arozarena
# 199  2020-10-27         FS  Tony Gonsolin      664062      Ji-Man Choi
#
#      batter_id  release_speed  release_pos_x  release_pos_z  stand  p_throws  \
# 0       642715           96.7           1.58           5.99      1         0
# 1       642715           94.1           2.91           5.45      1         0
# 2       642715           94.9           1.77           6.02      1         0
# 3       670712           94.4           1.66           5.93      1         0
# 4       670712           81.4           1.46           6.06      1         0
# ..         ...            ...            ...            ...    ...       ...
# 195     571970           96.0           1.88           6.76      0         0
# 196     668227           87.2          -3.57           5.94      1         1
# 197     668227           87.2          -3.61           5.84      1         1
# 198     668227           86.7          -3.69           5.87      1         1
# 199     596847           86.1          -0.75           6.13      0         1
#
#      balls  strikes  pfx_x  pfx_z  plate_x  plate_z  on_3b   on_2b   on_1b  \
# 0        0        2    0.2    1.6    -0.53     2.29      0       0       0
# 1        0        1    0.8    1.3    -0.55     3.03      0       0       0
# 2        0        0    0.2    1.5    -0.04     3.32      0       0       0
# 3        3        2    0.3    1.5    -0.37     2.15      0       0       0
# 4        2        2   -1.7   -0.2    -0.14     0.96      0       0       0
# ..     ...      ...    ...    ...      ...      ...    ...     ...     ...
# 195      0        0    0.3    1.8    -0.31     3.99      0       0       0
# 196      0        2   -1.4    0.4    -0.53     1.47      0  595281  596847
# 197      0        1   -1.3    0.1    -0.42     1.63      0  595281  596847
# 198      0        0   -1.2   -0.1    -0.73     2.46      0  595281  596847
# 199      3        2   -1.2    0.6     1.20     1.39      0  595281       0
#
#      inning  inning_topbot  effective_speed  release_spin_rate  \
# 0         9              1             95.4             2615.0
# 1         9              1             93.4             2470.0
# 2         9              1             94.0             2397.0
# 3         9              1             93.7             2508.0
# 4         9              1             80.2             3031.0
# ..      ...            ...              ...                ...
# 195       2              0             97.0             2484.0
# 196       2              1             87.0             2048.0
# 197       2              1             87.2             2006.0
# 198       2              1             86.5             1784.0
# 199       2              1             85.4             1917.0
#
#      release_extension  Catcher  FirstBasemen  SecondBasemen  ThirdBasemen  \
# 0                  5.7   605131        571970         571771        621458
# 1                  5.9   605131        571970         571771        621458
# 2                  5.7   605131        571970         571771        621458
# 3                  5.9   605131        571970         571771        621458
# 4                  5.7   605131        571970         571771        621458
# ..                 ...      ...           ...            ...           ...
# 195                7.0   572287        596847         664040        621563
# 196                6.2   605131        571970         621035        457759
# 197                6.4   605131        571970         621035        457759
# 198                6.3   605131        571970         621035        457759
# 199                5.9   605131        571970         621035        457759
#
#      ShortStop  LeftField  CenterField  RightField  at_bat_number  \
# 0       608369     621035       641355      605141             65
# 1       608369     621035       641355      605141             65
# 2       608369     621035       641355      605141             65
# 3       608369     621035       641355      605141             64
# 4       608369     621035       641355      605141             64
# ..         ...        ...          ...         ...            ...
# 195     642715     668227       595281      622534             15
# 196     608369     572041       641355      605141             14
# 197     608369     572041       641355      605141             14
# 198     608369     572041       641355      605141             14
# 199     608369     572041       641355      605141             13
#
#      pitch_number       pitch_name  bat_score  fld_score  post_bat_score  \
# 0               3  4-Seam Fastball          1          3               1
# 1               2  4-Seam Fastball          1          3               1
# 2               1  4-Seam Fastball          1          3               1
# 3               6  4-Seam Fastball          1          3               1
# 4               5        Curveball          1          3               1
# ..            ...              ...        ...        ...             ...
# 195             1  4-Seam Fastball          0          1               0
# 196             3         Changeup          1          0               1
# 197             2         Changeup          1          0               1
# 198             1         Changeup          1          0               1
# 199             6     Split-Finger          1          0               1
#
#      post_fld_score if_fielding_alignment of_fielding_alignment count  \
# 0                 3              Standard              Standard   0-2
# 1                 3              Standard              Standard   0-1
# 2                 3              Standard              Standard   0-0
# 3                 3              Standard              Standard   3-2
# 4                 3              Standard              Standard   2-2
# ..              ...                   ...                   ...   ...
# 195               1         Infield shift              Standard   0-0
# 196               0              Standard              Standard   0-2
# 197               0              Standard              Standard   0-1
# 198               0              Standard              Standard   0-0
# 199               0             Strategic              Standard   3-2
#
#     strike_attempt     events      description type bb_type        vx0  \
# 0           strike  strikeout    called_strike    S     NaN  -5.950264
# 1           strike        NaN    called_strike    S     NaN -10.560246
# 2           strike        NaN  swinging_strike    S     NaN  -5.199252
# 3           strike  strikeout    called_strike    S     NaN  -5.843595
# 4             ball        NaN             ball    B     NaN  -0.383207
# ..             ...        ...              ...  ...     ...        ...
# 195           ball        NaN             ball    B     NaN  -6.439376
# 196         strike  strikeout         foul_tip    S     NaN  10.032531
# 197         strike        NaN    called_strike    S     NaN  10.267292
# 198         strike        NaN    called_strike    S     NaN   9.449081
# 199           ball       walk             ball    B     NaN   7.009654
#
#             vy0       vz0         ax         ay         az  outs_when_up
# 0   -140.490456 -7.897391   3.772000  32.321911  -8.981441             2
# 1   -136.599519 -3.429867  11.723598  29.183810 -15.237217             2
# 2   -138.098234 -4.637970   4.158758  30.838499 -12.535677             2
# 3   -137.294295 -7.414897   4.754147  30.016237 -11.778755             1
# 4   -118.447810 -4.454166 -15.553576  24.451936 -32.892744             1
# ..          ...       ...        ...        ...        ...           ...
# 195 -139.530594 -5.869423   4.834519  32.875510  -7.461457             0
# 196 -126.579289 -5.424505 -16.574063  24.476075 -26.829657             2
# 197 -126.637060 -4.147810 -15.650891  25.342290 -30.452200             2
# 198 -125.899337 -1.833442 -14.386981  25.133779 -32.543760             2
# 199 -125.047953 -6.131996 -14.058565  25.156928 -24.920777             2
#
# [200 rows x 55 columns]
