# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pybaseball as pb
import project_baseball as project

pd.set_option('display.max_columns', None)

# %%
# Import cleaned data
mlb20 = pd.read_csv('data/2020cleaned.csv')
mlb19 = pd.read_csv('data/2019cleaned.csv')
mlb18 = pd.read_csv('data/2018cleaned.csv')
mlb17 = pd.read_csv('data/2017cleaned.csv')
mlb16 = pd.read_csv('data/2016cleaned.csv')

# %%
mlb16.head()
# Out:
#     game_date pitch_type      Pitcher_name  pitcher_id       batter_name  \
# 0  2016-11-02         CU   Mike Montgomery    543557.0  Michael Martinez
# 1  2016-11-02         CU   Mike Montgomery    543557.0  Michael Martinez
# 2  2016-11-02         FF  Carl Edwards Jr.    605218.0       Rajai Davis
# 3  2016-11-02         FF  Carl Edwards Jr.    605218.0       Rajai Davis
# 4  2016-11-02         FF  Carl Edwards Jr.    605218.0     Brandon Guyer
#
#    batter_id  release_speed  release_pos_x  release_pos_z stand p_throws  \
# 0   492841.0           76.6           2.72           6.39     R        L
# 1   492841.0           74.3           2.82           6.28     R        L
# 2   434658.0           94.9          -1.50           6.08     R        R
# 3   434658.0           95.6          -1.46           6.09     R        R
# 4   446386.0           94.8          -1.40           5.95     R        R
#
#    balls  strikes  pfx_x  pfx_z  plate_x  plate_z  on_3b     on_2b     on_1b  \
# 0    0.0      1.0   -0.8   -1.1     0.75     2.85    NaN       NaN  434658.0
# 1    0.0      0.0   -0.7   -1.1     0.43     2.64    NaN       NaN  434658.0
# 2    1.0      0.0   -0.1    1.7     0.05     1.56    NaN  446386.0       NaN
# 3    0.0      0.0   -0.4    1.7     0.40     1.04    NaN       NaN  446386.0
# 4    3.0      1.0    0.0    1.4     0.16     0.78    NaN       NaN       NaN
#
#    inning inning_topbot  effective_speed  release_spin_rate  \
# 0    10.0           Bot             76.9             2324.0
# 1    10.0           Bot             74.3             2478.0
# 2    10.0           Bot             96.3             2636.0
# 3    10.0           Bot             97.2             2672.0
# 4    10.0           Bot             96.8             2712.0
#
#    release_extension   Catcher  FirstBasemen  SecondBasemen  ThirdBasemen  \
# 0                6.2  471083.0      519203.0       595879.0      592178.0
# 1                6.0  471083.0      519203.0       595879.0      592178.0
# 2                6.8  471083.0      519203.0       595879.0      592178.0
# 3                6.8  471083.0      519203.0       595879.0      592178.0
# 4                6.7  471083.0      519203.0       595879.0      592178.0
#
#    ShortStop  LeftField  CenterField  RightField  at_bat_number  pitch_number  \
# 0   608365.0   450314.0     451594.0    518792.0           89.0           2.0
# 1   608365.0   450314.0     451594.0    518792.0           89.0           1.0
# 2   608365.0   450314.0     451594.0    518792.0           88.0           2.0
# 3   608365.0   450314.0     451594.0    518792.0           88.0           1.0
# 4   608365.0   450314.0     451594.0    518792.0           87.0           5.0
#
#         pitch_name  bat_score  fld_score  post_bat_score  post_fld_score  \
# 0        Curveball        7.0        8.0             7.0             8.0
# 1        Curveball        7.0        8.0             7.0             8.0
# 2  4-Seam Fastball        6.0        8.0             6.0             8.0
# 3  4-Seam Fastball        6.0        8.0             6.0             8.0
# 4  4-Seam Fastball        6.0        8.0             6.0             8.0
#
#   if_fielding_alignment of_fielding_alignment count strike_attempt     events  \
# 0              Standard              Standard   0-1            out  field_out
# 1              Standard              Standard   0-0         strike        NaN
# 2              Standard              Standard   1-0             ob     single
# 3              Standard              Standard   0-0           ball        NaN
# 4              Standard              Standard   3-1           ball       walk
#
#            description type      bb_type    vx0      vy0     vz0     ax  \
# 0        hit_into_play    X  ground_ball -3.206 -111.550   1.462 -5.837
# 1        called_strike    S          NaN -4.155 -108.216   1.520 -4.543
# 2  hit_into_play_score    X   line_drive  3.378 -137.703 -10.286 -0.221
# 3                 ball    B          NaN  4.780 -138.573 -12.000 -3.197
# 4                 ball    B          NaN  2.838 -137.534 -11.396  2.476
#
#        ay      az  outs_when_up
# 0  20.536 -43.549           2.0
# 1  19.370 -42.641           2.0
# 2  29.317 -11.776           2.0
# 3  25.774 -11.146           2.0
# 4  23.633 -15.029           2.0

# %%
# check columns match in every way
mlb20.columns == mlb16.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %% [markdown]
# ## Concatenate

# %%
# Concatenate the data to make one large dataframe
mlb_szn = [mlb20, mlb19, mlb18, mlb17, mlb16]
df = pd.concat(mlb_szn, sort=False)
# reset index
df.reset_index(drop=True, inplace=True)

# %%
df.sample(10)
# Out:
#           game_date pitch_type     Pitcher_name  pitcher_id       batter_name  \
# 2912482  2016-06-18         CU        Brad Hand    543272.0      Bryce Harper
# 179295   2020-08-19         SI    Tyler Bashlor    641341.0    Carlos Santana
# 1294905  2018-07-27         FF       Mike Fiers    571666.0  Francisco Lindor
# 1090518  2018-09-16         CU       Lance Lynn    458681.0    Billy McKinney
# 2401278  2017-04-25         SL    Kenley Jansen    445276.0   Conor Gillaspie
# 1928696  2017-08-23         FF      Koji Uehara    493157.0     Stuart Turner
# 1547337  2018-05-21         FF  Hector Santiago    502327.0       Mark Trumbo
# 2641351  2016-08-28         FF     Tyler Skaggs    572140.0    Cameron Maybin
# 1435438  2018-06-18          U    Bartolo Colon    112526.0   Abraham Almonte
# 1688172  2018-04-15         SL       Jose Urena    570632.0   Corey Dickerson
#
#          batter_id  release_speed  release_pos_x  release_pos_z stand  \
# 2912482   547180.0           84.0           2.16           5.99     L
# 179295    467793.0           97.0          -1.93           5.40     L
# 1294905   596019.0           89.1          -1.07           6.41     L
# 1090518   641856.0           80.5          -2.56           5.47     L
# 2401278   543216.0           82.2          -2.00           6.28     L
# 1928696   642156.0           87.2          -1.31           6.01     R
# 1547337   444432.0           91.1           1.96           5.84     R
# 2641351   457727.0           93.3           2.12           6.83     R
# 1435438   501659.0           87.4          -1.48           5.22     L
# 1688172   572816.0           84.5          -1.84           5.98     L
#
#         p_throws  balls  strikes  pfx_x  pfx_z  plate_x  plate_z     on_3b  \
# 2912482        L    0.0      2.0   -0.4   -0.1    -2.64    -0.64       NaN
ld_score  post_bat_score  post_fld_score if_fielding_alignment  \
# 2912482        1.0             2.0             1.0         Infield shift
# 179295         0.0             3.0             0.0             Strategic
# 1294905        0.0             0.0             0.0              Standard
# 1090518        2.0             1.0             2.0              Standard
# 2401278        2.0             1.0             2.0         Infield shift
# 1928696        9.0             0.0             9.0              Standard
# 1547337        1.0             3.0             1.0              Standard
# 2641351        0.0             0.0             0.0              Standard
# 1435438        5.0             0.0             5.0              Standard
# 1688172        1.0             2.0             1.0              Standard
#
#         of_fielding_alignment count strike_attempt     events  \
# 2912482              Standard   0-2           ball        NaN
# 179295               Standard   2-2         strike  strikeout
# 1294905              Standard   3-1         strike        NaN
# 1090518              Standard   3-2            out  field_out
# 2401278              Standard   0-1         strike        NaN
# 1928696              Standard   0-2            out  field_out
# 1547337              Standard   0-0         strike        NaN
# 2641351              Standard   0-0           ball        NaN
# 1435438              Standard   2-2             ob     single
# 1688172              Standard   0-0           ball        NaN
#
#                   description type      bb_type        vx0         vy0  \
# 2912482          blocked_ball    B          NaN -10.266000 -121.617000
# 179295        swinging_strike    S          NaN   6.145734 -141.117448
# 1294905       swinging_strike    S          NaN   3.318766 -129.417646
# 1090518         hit_into_play    X        popup   5.483491 -117.083441
# 2401278       swinging_strike    S          NaN   2.118476 -119.593533
# 1928696         hit_into_play    X        popup   5.320030 -126.285118
# 1547337       swinging_strike    S          NaN  -7.244798 -132.419898
# 2641351                  ball    B          NaN  -7.419000 -135.611000
# 1435438  hit_into_play_no_out    X  ground_ball   6.325248 -126.935620
# 1688172          blocked_ball    B          NaN   5.642165 -122.600568
#
#                vz0         ax         ay         az  outs_when_up
# 2912482  -8.570000  -3.063000  22.305000 -35.351000           0.0
# 179295   -5.278232 -16.692884  31.370317 -15.313568           1.0
# 1294905  -8.050957  -7.564493  25.835332 -13.239864           0.0
# 1090518   1.081758   5.936503  21.615274 -40.372901           2.0
# 2401278  -5.950809   7.290524  22.654625 -29.042247           2.0
# 1928696  -4.760209  -9.720180  28.470802  -1.981481           0.0
# 1547337  -1.567465  12.843049  29.309446 -16.033473           2.0
# 2641351  -6.717000   8.104000  26.322000 -12.008000           1.0
# 1435438  -1.491051 -17.212048  25.594014 -25.185941           0.0
# 1688172 -10.123671   3.416683  25.538894 -22.173509           1.0

# %%
df.shape
# Out:
# (3212938, 55)

# %% [markdown]
# # EDA
#
# ---
# Let's look at the trends of data over the past five seasons including the playoffs.

# %%
df.columns
# Out:
# Index(['game_date', 'pitch_type', 'Pitcher_name', 'pitcher_id', 'batter_name',
#        'batter_id', 'release_speed', 'release_pos_x', 'release_pos_z', 'stand',
#        'p_throws', 'balls', 'strikes', 'pfx_x', 'pfx_z', 'plate_x', 'plate_z',
#        'on_3b', 'on_2b', 'on_1b', 'inning', 'inning_topbot', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'Catcher', 'FirstBasemen',
#        'SecondBasemen', 'ThirdBasemen', 'ShortStop', 'LeftField',
#        'CenterField', 'RightField', 'at_bat_number', 'pitch_number',
#        'pitch_name', 'bat_score', 'fld_score', 'post_bat_score',
#        'post_fld_score', 'if_fielding_alignment', 'of_fielding_alignment',
#        'count', 'strike_attempt', 'events', 'description', 'type', 'bb_type',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'outs_when_up'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3212938 entries, 0 to 3212937
# Data columns (total 55 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   game_date              object
#  1   pitch_type             object
#  2   Pitcher_name           object
#  3   pitcher_id             float64
#  4   batter_name            object
#  5   batter_id              float64
#  6   release_speed          float64
#  7   release_pos_x          float64
#  8   release_pos_z          float64
#  9   stand                  object
#  10  p_throws               object
#  11  balls                  float64
#  12  strikes                float64
#  13  pfx_x                  float64
#  14  pfx_z                  float64
#  15  plate_x                float64
#  16  plate_z                float64
#  17  on_3b                  float64
#  18  on_2b                  float64
#  19  on_1b                  float64
#  20  inning                 float64
#  21  inning_topbot          object
#  22  effective_speed        float64
#  23  release_spin_rate      float64
#  24  release_extension      float64
#  25  Catcher                float64
#  26  FirstBasemen           float64
#  27  SecondBasemen          float64
#  28  ThirdBasemen           float64
#  29  ShortStop              float64
#  30  LeftField              float64
#  31  CenterField            float64
#  32  RightField             float64
#  33  at_bat_number          float64
#  34  pitch_number           float64
#  35  pitch_name             object
#  36  bat_score              float64
#  37  fld_score              float64
#  38  post_bat_score         float64
#  39  post_fld_score         float64
#  40  if_fielding_alignment  object
#  41  of_fielding_alignment  object
#  42  count                  object
#  43  strike_attempt         object
#  44  events                 object
#  45  description            object
#  46  type                   object
#  47  bb_type                object
#  48  vx0                    float64
#  49  vy0                    float64
#  50  vz0                    float64
#  51  ax                     float64
#  52  ay                     float64
#  53  az                     float64
#  54  outs_when_up           float64
# dtypes: float64(39), object(16)
# memory usage: 1.3+ GB

# %%
df.describe(include='all')

# %% [markdown]
# The amount of nulls is surprising in some categories. Places where I expect nulls to be are in `'on_3b', 'on_2b', 'on_1b','events','bb_type'` since there are innings where people are not on base and not everyone can guarantee an out without ever striking out in their entire career.
#
# What I did not expect to see was NaNs in the fielder spots because you can't play baseball without 9 men on the field. I also did not expect to see release speeds missing or the velocities/accelerations of aputch to be missing. Someone was not doing their job when they were recording these stats.

# %%
df.isnull().sum()

# %% [markdown]
# There is also way too many rows containing nulls. If I am to drop any nulls, I need to be weary of how I am dropping them since if I do, 1/3 of the data will be gone.

# %%
df.isnull().sum().sum()
# About 1/3 of the data has a null in it
