# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pybaseball as pb
import project_baseball as project

pd.set_option('display.max_columns', None)

# %%
# Import cleaned data
mlb20 = pd.read_csv('data/2020cleaned.csv')
mlb19 = pd.read_csv('data/2019cleaned.csv')
mlb18 = pd.read_csv('data/2018cleaned.csv')
mlb17 = pd.read_csv('data/2017cleaned.csv')
mlb16 = pd.read_csv('data/2016cleaned.csv')

# %%
mlb16.head()
# Out:
#     game_date pitch_type      Pitcher_name  batter_id  pitcher_id  \
# 0  2016-11-02         CU   Mike Montgomery   492841.0    543557.0
# 1  2016-11-02         CU   Mike Montgomery   492841.0    543557.0
# 2  2016-11-02         FF  Carl Edwards Jr.   434658.0    605218.0
# 3  2016-11-02         FF  Carl Edwards Jr.   434658.0    605218.0
# 4  2016-11-02         FF  Carl Edwards Jr.   446386.0    605218.0
#
#    release_speed  release_pos_x  release_pos_z stand p_throws  balls  strikes  \
# 0           76.6           2.72           6.39     R        L    0.0      1.0
# 1           74.3           2.82           6.28     R        L    0.0      0.0
# 2           94.9          -1.50           6.08     R        R    1.0      0.0
# 3           95.6          -1.46           6.09     R        R    0.0      0.0
# 4           94.8          -1.40           5.95     R        R    3.0      1.0
#
#    pfx_x  pfx_z  plate_x  plate_z  on_3b     on_2b     on_1b  inning  \
# 0   -0.8   -1.1     0.75     2.85    NaN       NaN  434658.0    10.0
# 1   -0.7   -1.1     0.43     2.64    NaN       NaN  434658.0    10.0
# 2   -0.1    1.7     0.05     1.56    NaN  446386.0       NaN    10.0
# 3   -0.4    1.7     0.40     1.04    NaN       NaN  446386.0    10.0
# 4    0.0    1.4     0.16     0.78    NaN       NaN       NaN    10.0
#
#   inning_topbot  effective_speed  release_spin_rate  release_extension  \
# 0           Bot             76.9             2324.0                6.2
# 1           Bot             74.3             2478.0                6.0
# 2           Bot             96.3             2636.0                6.8
# 3           Bot             97.2             2672.0                6.8
# 4           Bot             96.8             2712.0                6.7
#
#     Catcher  FirstBasemen  SecondBasemen  ThirdBasemen  ShortStop  LeftField  \
# 0  471083.0      519203.0       595879.0      592178.0   608365.0   450314.0
# 1  471083.0      519203.0       595879.0      592178.0   608365.0   450314.0
# 2  471083.0      519203.0       595879.0      592178.0   608365.0   450314.0
# 3  471083.0      519203.0       595879.0      592178.0   608365.0   450314.0
# 4  471083.0      519203.0       595879.0      592178.0   608365.0   450314.0
#
#    CenterField  RightField  at_bat_number  pitch_number       pitch_name  \
# 0     451594.0    518792.0           89.0           2.0        Curveball
# 1     451594.0    518792.0           89.0           1.0        Curveball
# 2     451594.0    518792.0           88.0           2.0  4-Seam Fastball
# 3     451594.0    518792.0           88.0           1.0  4-Seam Fastball
# 4     451594.0    518792.0           87.0           5.0  4-Seam Fastball
#
#    bat_score  fld_score  post_bat_score  post_fld_score if_fielding_alignment  \
# 0        7.0        8.0             7.0             8.0              Standard
# 1        7.0        8.0             7.0             8.0              Standard
# 2        6.0        8.0             6.0             8.0              Standard
# 3        6.0        8.0             6.0             8.0              Standard
# 4        6.0        8.0             6.0             8.0              Standard
#
#   of_fielding_alignment count strike_attempt     events          description  \
# 0              Standard   0-1            out  field_out        hit_into_play
# 1              Standard   0-0         strike        NaN        called_strike
# 2              Standard   1-0             ob     single  hit_into_play_score
# 3              Standard   0-0           ball        NaN                 ball
# 4              Standard   3-1           ball       walk                 ball
#
#   type      bb_type    vx0      vy0     vz0     ax      ay      az  \
# 0    X  ground_ball -3.206 -111.550   1.462 -5.837  20.536 -43.549
# 1    S          NaN -4.155 -108.216   1.520 -4.543  19.370 -42.641
# 2    X   line_drive  3.378 -137.703 -10.286 -0.221  29.317 -11.776
# 3    B          NaN  4.780 -138.573 -12.000 -3.197  25.774 -11.146
# 4    B          NaN  2.838 -137.534 -11.396  2.476  23.633 -15.029
#
#    outs_when_up
# 0           2.0
# 1           2.0
# 2           2.0
# 3           2.0
# 4           2.0

# %%
# check columns match in every way
mlb20.columns == mlb16.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# ## Concatenate

# %%
# Concatenate the data to make one large dataframe
mlb_szn = [mlb20, mlb19, mlb18, mlb17, mlb16]
df = pd.concat(mlb_szn, sort=False)
# reset index
df.reset_index(drop=True, inplace=True)

# %%
df.sample(10)
# Out:
#           game_date pitch_type     Pitcher_name  batter_id  pitcher_id  \
# 1221004  2018-08-14         SI     Ryan Borucki   594011.0    621366.0
# 2129272  2017-07-01          U  Carlos Carrasco   435079.0    471911.0
# 383702   2019-09-07         SI    Chris Bassitt   408234.0    605135.0
# 990223   2019-04-05         CU    Yusei Kikuchi   456078.0    579328.0
# 2601269  2016-09-07         KC    Jarred Cosart   506702.0    543054.0
# 721503   2019-06-12         SL     Anthony Bass   593934.0    542914.0
# 863638   2019-05-08         CH   Kyle Hendricks   500743.0    543294.0
# 1654389  2018-04-24         SI      CC Sabathia   572821.0    282332.0
# 137313   2020-08-30         SI    Hector Rondon   643289.0    444468.0
# 2956574  2016-06-07          U       Matt Purke   543685.0    545357.0
#
#          release_speed  release_pos_x  release_pos_z stand p_throws  balls  \
# 1221004           92.3           3.05           5.70     R        L    2.0
# 2129272           91.6          -1.98           5.33     R        R    1.0
# 383702            91.5          -1.07           5.88     R        R    1.0
# 990223            74.3           2.17           5.94     R        L    0.0
# 2601269           79.4          -1.94           5.85     L        R    0.0
# 721503            86.9          -0.84           5.92     R        R    0.0
# 863638            80.0          -2.13           6.14     R        R    0.0
# 1654389           88.5           2.18           6.27     R        L    0.0
# 137313            95.0          -1.40           5.78     R        R    0.0
# 2956574           92.6           3.38           6.54     R        L    0.0
#
#          strikes  pfx_x  pfx_z  plate_x  plate_z  on_3b     on_2b     on_1b  \
# 1221004      1.0    1.5    0.5    -1.15     1.30    NaN       NaN  593528.0
# 2129272      1.0   -1.0    0.6    -0.25     1.63    NaN       NaN       NaN
# 383702       1.0   -1.2    1.0    -0.93     1.99    NaN       NaN  605612.0
# 990223       0.0   -0.8   -1.2     0.60     2.74    NaN       NaN       NaN
# 2601269      2.0    0.8   -0.8    -0.22    -0.07    NaN       NaN       NaN
# 721503       0.0    0.6    0.1     0.59     3.29    NaN       NaN       NaN
# 863638       2.0   -1.0    0.9    -0.18     1.56    NaN  595751.0  516770.0
# 1654389      0.0    1.4    0.9     1.31     2.98    NaN       NaN       NaN
# 137313       1.0   -1.2    1.0    -0.54     3.02    NaN       NaN  467055.0
# 2956574      1.0    1.5    1.0    -0.47     1.04    NaN       NaN       NaN
#
#          inning inning_topbot  effective_speed  release_spin_rate  \
# 1221004     2.0           Bot             92.0             2238.0
# 2129272     3.0           Bot             91.4             2118.0
# 383702      1.0           Top             91.9             2117.0
# 990223      5.0           Bot             75.0             2552.0
# 2601269     2.0           Top             79.7             2655.0
# 721503      9.0           Bot             86.8                NaN
# 863638      1.0           Top             79.5             2227.0
# 1654389     1.0           Top             88.7             1914.0
# 137313      9.0           Top             94.7             2006.0
# 2956574     7.0           Top             90.5             2196.0
#
#          release_extension   Catcher  FirstBasemen  SecondBasemen  \
# 1221004                6.1  643376.0      475253.0       581527.0
# 2129272                6.0  547379.0      467793.0       543401.0
# 383702                 6.0  669221.0      621566.0       595777.0
# 990223                 6.7  553882.0      457803.0       664238.0
# 2601269                6.7  519083.0      571976.0       572114.0
# 721503                 6.0  553882.0      596129.0       543829.0
# 863638                 5.9  575929.0      519203.0       608365.0
# 1654389                6.4  596142.0      435522.0       650402.0
# 137313                 6.4  608348.0      572233.0       606466.0
# 2956574                5.9  425900.0      547989.0       543434.0
#
#          ThirdBasemen  ShortStop  LeftField  CenterField  RightField  \
# 1221004      431145.0   649557.0   606192.0     607680.0    434158.0
# 2129272      608070.0   596019.0   488726.0     605548.0    502082.0
# 383702       656305.0   543760.0   664913.0     657656.0    543257.0
# 990223       592387.0   542921.0   570267.0     605480.0    571745.0
# 2601269      500208.0   596143.0   543105.0     608671.0    445055.0
# 721503       572122.0   664238.0   643418.0     605480.0    570267.0
# 863638       623520.0   595879.0   656941.0     518792.0    592178.0
# 1654389      609280.0   544369.0   458731.0     543305.0    592450.0
# 137313       500871.0   605113.0   444482.0     516782.0    594777.0
# 2956574      453943.0   573135.0   466320.0     457706.0    594809.0
#
#          at_bat_number  pitch_number       pitch_name  bat_score  fld_score  \
# 1221004           14.0           4.0           Sinker        0.0        2.0
# 2129272           20.0           3.0  2-Seam Fastball        1.0        0.0
# 383702             3.0           3.0           Sinker        0.0        0.0
# 990223            45.0           1.0        Curveball        6.0        4.0
# 2601269           10.0           3.0    Knuckle Curve        0.0        1.0
# 721503            78.0           1.0           Slider        4.0        6.0
# 863638             6.0           3.0         Changeup        1.0        0.0
# 1654389            1.0           1.0           Sinker        0.0        0.0
# 137313            65.0           2.0           Sinker        4.0        1.0
# 2956574           63.0           2.0  2-Seam Fastball       10.0        5.0
#
#          post_bat_score  post_fld_score if_fielding_alignment  \
# 1221004             0.0             2.0              Standard
# 2129272             1.0             0.0              Standard
# 383702              0.0             0.0             Strategic
# 990223              6.0             4.0              Standard
# 2601269             0.0             1.0         Infield shift
# 721503              4.0             6.0              Standard
# 863638              1.0             0.0              Standard
# 1654389             0.0             0.0             Strategic
# 137313              4.0             1.0              Standard
# 2956574            10.0             5.0              Standard
#
#         of_fielding_alignment count strike_attempt     events  \
# 1221004              Standard   2-1           ball        NaN
# 2129272              Standard   1-1            out  field_out
# 383702               Standard   1-1             ob     single
# 990223               Standard   0-0         strike        NaN
# 2601269              Standard   0-2         strike  strikeout
# 721503               Standard   0-0         strike        NaN
# 863638               Standard   0-2            out  field_out
# 1654389             Strategic   0-0            out  field_out
# 137313               Standard   0-1             ob     single
# 2956574              Standard   0-1            out  field_out
#
#                      description type      bb_type        vx0         vy0  \
# 1221004                     ball    B          NaN -13.874036 -133.662819
# 2129272            hit_into_play    X  ground_ball   6.437406 -133.064459
# 383702      hit_into_play_no_out    X   line_drive   2.950428 -133.215967
# 990223             called_strike    S          NaN  -1.763284 -108.274864
# 2601269  swinging_strike_blocked    S          NaN   1.435000 -115.526000
# 721503           swinging_strike    S          NaN   2.141285 -126.586402
# 863638             hit_into_play    X  ground_ball   6.012078 -116.247442
# 1654389            hit_into_play    X  ground_ball  -5.012633 -128.852607
# 137313      hit_into_play_no_out    X   line_drive   4.899593 -138.168495
# 2956574            hit_into_play    X  ground_ball -12.313000 -134.010000
#
#               vz0         ax         ay         az  outs_when_up
# 1221004 -6.438270  20.963340  24.823520 -25.076336           0.0
# 2129272 -4.732206 -13.026836  25.686305 -24.553774           0.0
# 383702  -6.077644 -15.063187  22.654096 -19.820079           1.0
# 990223   2.815224  -6.310313  18.467665 -42.435501           0.0
# 2601269 -4.586000   8.980000  22.760000 -41.884000           0.0
# 721503  -0.418600   6.314715  24.020834 -30.944563           0.0
# 863638  -5.045002  -9.616428  20.511556 -23.270947           2.0
# 1654389 -3.801681  16.394591  26.929926 -21.840971           0.0
# 137313  -3.769536 -16.078608  33.791407 -18.668660           2.0
# 2956574 -9.181000  21.187000  33.672000 -21.756000           0.0

# %%
df.shape
# Out:
# (3212938, 54)

# %% [markdown]
# # EDA
#
# ---
# Let's look at the trends of data over the past five seasons including the playoffs.
