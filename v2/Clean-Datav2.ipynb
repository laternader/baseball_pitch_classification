# %% [markdown]
# # Clean Data
#
# ---
# Now that we have saved such a large data set, we need to clean it. 4 million rows with 93 columns is way too much to handle, so we need to at least clean it to understand every aspect and apply it to all applicable data entries.

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Import personally made cleaning library, a copy was made from original location
import project_baseball as pb

# %%
df = pd.read_csv('mlbpitches15-20.csv')
df.shape
df.info()
df.head()
# Out:
# C:\Users\ncesm\anaconda3\envs\capstone\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (44) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3925776 entries, 0 to 3925775
# Data columns (total 93 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   index                            int64
#  1   pitch_type                       object
#  2   game_date                        object
#  3   release_speed                    float64
#  4   release_pos_x                    float64
#  5   release_pos_z                    float64
#  6   player_name                      object
#  7   batter                           float64
#  8   pitcher                          float64
#  9   events                           object
#  10  description                      object
# ...

# %% [markdown]
# First, renaming the fielder names and pitcher name columns.

# %%
pb.renaming_fielders(df)
# Out:
#          index pitch_type   game_date  release_speed  release_pos_x  \
# 0           77         FF  2020-10-27           96.7           1.58
# 1           79         FF  2020-10-27           94.1           2.91
# 2           83         FF  2020-10-27           94.9           1.77
# 3           89         FF  2020-10-27           94.4           1.66
# 4           93         CU  2020-10-27           81.4           1.46
# ...        ...        ...         ...            ...            ...
# 3925771  17532         CU  2015-04-05            NaN            NaN
# 3925772  17546         FF  2015-04-05            NaN            NaN
# 3925773  17554         FF  2015-04-05            NaN            NaN
# 3925774  17564         FF  2015-04-05            NaN            NaN
# 3925775  17570         FF  2015-04-05            NaN            NaN
#
#          release_pos_z  Pitcher_name  batter_id  pitcher_id     events  \
# 0                 5.99  Urías, Julio   642715.0    628711.0  strikeout
# ...

# %%
df.head()
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0     77         FF  2020-10-27           96.7           1.58           5.99
# 1     79         FF  2020-10-27           94.1           2.91           5.45
# 2     83         FF  2020-10-27           94.9           1.77           6.02
# 3     89         FF  2020-10-27           94.4           1.66           5.93
# 4     93         CU  2020-10-27           81.4           1.46           6.06
#
#    Pitcher_name  batter_id  pitcher_id     events      description  spin_dir  \
# 0  Urías, Julio   642715.0    628711.0  strikeout    called_strike       NaN
# 1  Urías, Julio   642715.0    628711.0        NaN    called_strike       NaN
# 2  Urías, Julio   642715.0    628711.0        NaN  swinging_strike       NaN
# 3  Urías, Julio   670712.0    628711.0  strikeout    called_strike       NaN
# 4  Urías, Julio   670712.0    628711.0        NaN             ball       NaN
#
# ...

# %%
# In case we want to drop some columns, we will check for nulls.
df.isnull().sum()
# Out:
# index                                    0
# pitch_type                           14553
# game_date                                0
# release_speed                        38052
# release_pos_x                        38720
# release_pos_z                        38720
# Pitcher_name                             0
# batter_id                                0
# pitcher_id                               0
# events                             2918070
# description                              0
# spin_dir                           3925776
# spin_rate_deprecated               3925776
# break_angle_deprecated             3925776
# break_length_deprecated            3925776
# zone                                 38720
# des                                     13
# game_type                                0
# stand                                    0
# p_throws                                 0
# home_team                                0
# away_team                                0
# ...
