# %%
import pybaseball as pb
import pandas as pd

# %%
from pybaseball import cache

# %%
cache.enable()

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Gathering the Data per season
#
# ---
# We selected the 20125-2020 seasons to get enough data to run this model. This is a re-run of the previous project.
#
# The dates include the opening days until the very last pitch of the World Series of the respective years.

# %%
mlb2020 = pb.statcast(start_dt='2020-07-23', end_dt='2020-10-27')
mlb2019 = pb.statcast(start_dt='2019-03-20', end_dt='2019-10-30')
mlb2018 = pb.statcast(start_dt='2018-03-29', end_dt='2018-10-28')
mlb2017 = pb.statcast(start_dt='2017-04-02', end_dt='2017-11-01')
mlb2016 = pb.statcast(start_dt='2016-04-03', end_dt='2016-11-02')
mlb2015 = pb.statcast(start_dt='2015-04-05', end_dt='2015-11-01')

print('Finished Acquiring Data')
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2020-07-23 to 2020-07-28
# Completed sub-query from 2020-07-29 to 2020-08-03
# Completed sub-query from 2020-08-04 to 2020-08-09
# Completed sub-query from 2020-08-10 to 2020-08-15
# Completed sub-query from 2020-08-16 to 2020-08-21
# Completed sub-query from 2020-08-22 to 2020-08-27
# Completed sub-query from 2020-08-28 to 2020-09-02
# Completed sub-query from 2020-09-03 to 2020-09-08
# Completed sub-query from 2020-09-09 to 2020-09-14
# Completed sub-query from 2020-09-15 to 2020-09-20
# Completed sub-query from 2020-09-21 to 2020-09-26
# Completed sub-query from 2020-09-27 to 2020-10-02
# Completed sub-query from 2020-10-03 to 2020-10-08
# Completed sub-query from 2020-10-09 to 2020-10-14
# Completed sub-query from 2020-10-15 to 2020-10-20
# Completed sub-query from 2020-10-21 to 2020-10-26
# Completed sub-query from 2020-10-27 to 2020-10-27
# This is a large query, it may take a moment to complete
# Completed sub-query from 2019-03-20 to 2019-03-25
# Completed sub-query from 2019-03-26 to 2019-03-31
# Completed sub-query from 2019-04-01 to 2019-04-06
# Completed sub-query from 2019-04-07 to 2019-04-12
# Completed sub-query from 2019-04-13 to 2019-04-18
# Completed sub-query from 2019-04-19 to 2019-04-24
# Completed sub-query from 2019-04-25 to 2019-04-30
# Completed sub-query from 2019-05-01 to 2019-05-06
# Completed sub-query from 2019-05-07 to 2019-05-12
# Completed sub-query from 2019-05-13 to 2019-05-18
# Completed sub-query from 2019-05-19 to 2019-05-24
# Completed sub-query from 2019-05-25 to 2019-05-30
# Completed sub-query from 2019-05-31 to 2019-06-05
# Completed sub-query from 2019-06-06 to 2019-06-11
# Completed sub-query from 2019-06-12 to 2019-06-17
# Completed sub-query from 2019-06-18 to 2019-06-23
# Completed sub-query from 2019-06-24 to 2019-06-29
# Completed sub-query from 2019-06-30 to 2019-07-05
# Completed sub-query from 2019-07-06 to 2019-07-11
# Completed sub-query from 2019-07-12 to 2019-07-17
# Completed sub-query from 2019-07-18 to 2019-07-23
# Completed sub-query from 2019-07-24 to 2019-07-29
# Completed sub-query from 2019-07-30 to 2019-08-04
# Completed sub-query from 2019-08-05 to 2019-08-10
# Completed sub-query from 2019-08-11 to 2019-08-16
# Completed sub-query from 2019-08-17 to 2019-08-22
# Completed sub-query from 2019-08-23 to 2019-08-28
# Completed sub-query from 2019-08-29 to 2019-09-03
# Completed sub-query from 2019-09-04 to 2019-09-09
# Completed sub-query from 2019-09-10 to 2019-09-15
# Completed sub-query from 2019-09-16 to 2019-09-21
# Completed sub-query from 2019-09-22 to 2019-09-27
# Completed sub-query from 2019-09-28 to 2019-10-03
# Completed sub-query from 2019-10-04 to 2019-10-09
# Completed sub-query from 2019-10-10 to 2019-10-15
# Completed sub-query from 2019-10-16 to 2019-10-21
# Completed sub-query from 2019-10-22 to 2019-10-27
# Completed sub-query from 2019-10-28 to 2019-10-30
# This is a large query, it may take a moment to complete
# Completed sub-query from 2018-03-29 to 2018-04-03
# Completed sub-query from 2018-04-04 to 2018-04-09
# Completed sub-query from 2018-04-10 to 2018-04-15
# Completed sub-query from 2018-04-16 to 2018-04-21
# Completed sub-query from 2018-04-22 to 2018-04-27
# Completed sub-query from 2018-04-28 to 2018-05-03
# Completed sub-query from 2018-05-04 to 2018-05-09
# Completed sub-query from 2018-05-10 to 2018-05-15
# Completed sub-query from 2018-05-16 to 2018-05-21
# Completed sub-query from 2018-05-22 to 2018-05-27
# Completed sub-query from 2018-05-28 to 2018-06-02
# Completed sub-query from 2018-06-03 to 2018-06-08
# Completed sub-query from 2018-06-09 to 2018-06-14
# Completed sub-query from 2018-06-15 to 2018-06-20
# Completed sub-query from 2018-06-21 to 2018-06-26
# Completed sub-query from 2018-06-27 to 2018-07-02
# Completed sub-query from 2018-07-03 to 2018-07-08
# Completed sub-query from 2018-07-09 to 2018-07-14
# Completed sub-query from 2018-07-15 to 2018-07-20
# Completed sub-query from 2018-07-21 to 2018-07-26
# Completed sub-query from 2018-07-27 to 2018-08-01
# Completed sub-query from 2018-08-02 to 2018-08-07
# Completed sub-query from 2018-08-08 to 2018-08-13
# Completed sub-query from 2018-08-14 to 2018-08-19
# Completed sub-query from 2018-08-20 to 2018-08-25
# Completed sub-query from 2018-08-26 to 2018-08-31
# Completed sub-query from 2018-09-01 to 2018-09-06
# Completed sub-query from 2018-09-07 to 2018-09-12
# Completed sub-query from 2018-09-13 to 2018-09-18
# Completed sub-query from 2018-09-19 to 2018-09-24
# Completed sub-query from 2018-09-25 to 2018-09-30
# Completed sub-query from 2018-10-01 to 2018-10-06
# Completed sub-query from 2018-10-07 to 2018-10-12
# Completed sub-query from 2018-10-13 to 2018-10-18
# Completed sub-query from 2018-10-19 to 2018-10-24
# Completed sub-query from 2018-10-25 to 2018-10-28
# This is a large query, it may take a moment to complete
# Completed sub-query from 2017-04-02 to 2017-04-07
# Completed sub-query from 2017-04-08 to 2017-04-13
# Completed sub-query from 2017-04-14 to 2017-04-19
# Completed sub-query from 2017-04-20 to 2017-04-25
# Completed sub-query from 2017-04-26 to 2017-05-01
# Completed sub-query from 2017-05-02 to 2017-05-07
# Completed sub-query from 2017-05-08 to 2017-05-13
# Completed sub-query from 2017-05-14 to 2017-05-19
# Completed sub-query from 2017-05-20 to 2017-05-25
# Completed sub-query from 2017-05-26 to 2017-05-31
# Completed sub-query from 2017-06-01 to 2017-06-06
# Completed sub-query from 2017-06-07 to 2017-06-12
# Completed sub-query from 2017-06-13 to 2017-06-18
# Completed sub-query from 2017-06-19 to 2017-06-24
# Completed sub-query from 2017-06-25 to 2017-06-30
# Completed sub-query from 2017-07-01 to 2017-07-06
# Completed sub-query from 2017-07-07 to 2017-07-12
# Completed sub-query from 2017-07-13 to 2017-07-18
# Completed sub-query from 2017-07-19 to 2017-07-24
# Completed sub-query from 2017-07-25 to 2017-07-30
# Completed sub-query from 2017-07-31 to 2017-08-05
# Completed sub-query from 2017-08-06 to 2017-08-11
# Completed sub-query from 2017-08-12 to 2017-08-17
# Completed sub-query from 2017-08-18 to 2017-08-23
# Completed sub-query from 2017-08-24 to 2017-08-29
# Completed sub-query from 2017-08-30 to 2017-09-04
# Completed sub-query from 2017-09-05 to 2017-09-10
# Completed sub-query from 2017-09-11 to 2017-09-16
# Completed sub-query from 2017-09-17 to 2017-09-22
# Completed sub-query from 2017-09-23 to 2017-09-28
# Completed sub-query from 2017-09-29 to 2017-10-04
# Completed sub-query from 2017-10-05 to 2017-10-10
# Completed sub-query from 2017-10-11 to 2017-10-16
# Completed sub-query from 2017-10-17 to 2017-10-22
# Completed sub-query from 2017-10-23 to 2017-10-28
# Completed sub-query from 2017-10-29 to 2017-11-01
# This is a large query, it may take a moment to complete
# Completed sub-query from 2016-04-03 to 2016-04-08
# Completed sub-query from 2016-04-09 to 2016-04-14
# Completed sub-query from 2016-04-15 to 2016-04-20
# Completed sub-query from 2016-04-21 to 2016-04-26
# Completed sub-query from 2016-04-27 to 2016-05-02
# Completed sub-query from 2016-05-03 to 2016-05-08
# Completed sub-query from 2016-05-09 to 2016-05-14
# Completed sub-query from 2016-05-15 to 2016-05-20
# Completed sub-query from 2016-05-21 to 2016-05-26
# Completed sub-query from 2016-05-27 to 2016-06-01
# Completed sub-query from 2016-06-02 to 2016-06-07
# Completed sub-query from 2016-06-08 to 2016-06-13
# Completed sub-query from 2016-06-14 to 2016-06-19
# Completed sub-query from 2016-06-20 to 2016-06-25
# Completed sub-query from 2016-06-26 to 2016-07-01
# Completed sub-query from 2016-07-02 to 2016-07-07
# Completed sub-query from 2016-07-08 to 2016-07-13
# Completed sub-query from 2016-07-14 to 2016-07-19
# Completed sub-query from 2016-07-20 to 2016-07-25
# Completed sub-query from 2016-07-26 to 2016-07-31
# Completed sub-query from 2016-08-01 to 2016-08-06
# Completed sub-query from 2016-08-07 to 2016-08-12
# Completed sub-query from 2016-08-13 to 2016-08-18
# Completed sub-query from 2016-08-19 to 2016-08-24
# Completed sub-query from 2016-08-25 to 2016-08-30
# Completed sub-query from 2016-08-31 to 2016-09-05
# Completed sub-query from 2016-09-06 to 2016-09-11
# Completed sub-query from 2016-09-12 to 2016-09-17
# Completed sub-query from 2016-09-18 to 2016-09-23
# Completed sub-query from 2016-09-24 to 2016-09-29
# Completed sub-query from 2016-09-30 to 2016-10-05
# Completed sub-query from 2016-10-06 to 2016-10-11
# Completed sub-query from 2016-10-12 to 2016-10-17
# Completed sub-query from 2016-10-18 to 2016-10-23
# Completed sub-query from 2016-10-24 to 2016-10-29
# Completed sub-query from 2016-10-30 to 2016-11-02
# This is a large query, it may take a moment to complete
# Completed sub-query from 2015-04-05 to 2015-04-10
# Completed sub-query from 2015-04-11 to 2015-04-16
# Completed sub-query from 2015-04-17 to 2015-04-22
# Completed sub-query from 2015-04-23 to 2015-04-28
# Completed sub-query from 2015-04-29 to 2015-05-04
# Completed sub-query from 2015-05-05 to 2015-05-10
# Completed sub-query from 2015-05-11 to 2015-05-16
# Completed sub-query from 2015-05-17 to 2015-05-22
# Completed sub-query from 2015-05-23 to 2015-05-28
# Completed sub-query from 2015-05-29 to 2015-06-03
# Completed sub-query from 2015-06-04 to 2015-06-09
# Completed sub-query from 2015-06-10 to 2015-06-15
# Completed sub-query from 2015-06-16 to 2015-06-21
# Completed sub-query from 2015-06-22 to 2015-06-27
# Completed sub-query from 2015-06-28 to 2015-07-03
# Completed sub-query from 2015-07-04 to 2015-07-09
# Completed sub-query from 2015-07-10 to 2015-07-15
# Completed sub-query from 2015-07-16 to 2015-07-21
# Completed sub-query from 2015-07-22 to 2015-07-27
# Completed sub-query from 2015-07-28 to 2015-08-02
# Completed sub-query from 2015-08-03 to 2015-08-08
# Completed sub-query from 2015-08-09 to 2015-08-14
# Completed sub-query from 2015-08-15 to 2015-08-20
# Completed sub-query from 2015-08-21 to 2015-08-26
# Completed sub-query from 2015-08-27 to 2015-09-01
# Completed sub-query from 2015-09-02 to 2015-09-07
# Completed sub-query from 2015-09-08 to 2015-09-13
# Completed sub-query from 2015-09-14 to 2015-09-19
# Completed sub-query from 2015-09-20 to 2015-09-25
# Completed sub-query from 2015-09-26 to 2015-10-01
# Completed sub-query from 2015-10-02 to 2015-10-07
# Completed sub-query from 2015-10-08 to 2015-10-13
# Completed sub-query from 2015-10-14 to 2015-10-19
# Completed sub-query from 2015-10-20 to 2015-10-25
# Completed sub-query from 2015-10-26 to 2015-10-31
# Completed sub-query from 2015-11-01 to 2015-11-01
# Finished Acquiring Data

# %%
# We will check to see if the data was scraped properly

mlb2020.head()
# Out:
#    index pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0     77         FF 2020-10-27           96.7           1.58           5.99
# 1     79         FF 2020-10-27           94.1           2.91           5.45
# 2     83         FF 2020-10-27           94.9           1.77           6.02
# 3     89         FF 2020-10-27           94.4           1.66           5.93
# 4     93         CU 2020-10-27           81.4           1.46           6.06
#
#     player_name    batter   pitcher     events  ... fld_score  \
# 0  Urías, Julio  642715.0  628711.0  strikeout  ...       3.0
# 1  Urías, Julio  642715.0  628711.0        NaN  ...       3.0
# 2  Urías, Julio  642715.0  628711.0        NaN  ...       3.0
# 3  Urías, Julio  670712.0  628711.0  strikeout  ...       3.0
# 4  Urías, Julio  670712.0  628711.0        NaN  ...       3.0
#
#    post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0              1.0              3.0             1.0             3.0
# 1              1.0              3.0             1.0             3.0
# 2              1.0              3.0             1.0             3.0
# 3              1.0              3.0             1.0             3.0
# 4              1.0              3.0             1.0             3.0
#
#    if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 0               Standard              Standard     149.0              0.011
# 1               Standard              Standard     127.0              0.000
# 2               Standard              Standard     147.0              0.000
# 3               Standard              Standard     153.0              0.023
# 4               Standard              Standard     308.0              0.000
#
#   delta_run_exp
# 0        -0.067
# 1        -0.027
# 2        -0.017
# 3        -0.208
# 4         0.060
#
# [5 rows x 93 columns]

# %%
# If you choose to save the data as separate CSVs based on year, you can execute

# mlbYEAR.to_csv('mlbYEAR.csv', index=False)

# %% [markdown]
# Since we are after one big concatenated file, we will save it as one gigantic file.

# %%
mlbseasons = [mlb2020, mlb2019, mlb2018, mlb2017, mlb2016, mlb2015]
df = pd.concat(mlbseasons)

df.head(10)
# Out:
#    index pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0     77         FF 2020-10-27           96.7           1.58           5.99
# 1     79         FF 2020-10-27           94.1           2.91           5.45
# 2     83         FF 2020-10-27           94.9           1.77           6.02
# 3     89         FF 2020-10-27           94.4           1.66           5.93
# 4     93         CU 2020-10-27           81.4           1.46           6.06
# 5     95         FF 2020-10-27           95.6           1.81           5.95
# 6     98         CU 2020-10-27           80.6           1.50           6.11
# 7    102         FF 2020-10-27           94.7           1.82           5.95
# 8    108         FF 2020-10-27           94.3           1.67           6.11
# 9    114         FF 2020-10-27           95.2           1.72           6.09
#
#     player_name    batter   pitcher     events      description  spin_dir  \
# 0  Urías, Julio  642715.0  628711.0  strikeout    called_strike       NaN
# 1  Urías, Julio  642715.0  628711.0        NaN    called_strike       NaN
# 2  Urías, Julio  642715.0  628711.0        NaN  swinging_strike       NaN
# 3  Urías, Julio  670712.0  628711.0  strikeout    called_strike       NaN
# 4  Urías, Julio  670712.0  628711.0        NaN             ball       NaN
# 5  Urías, Julio  670712.0  628711.0        NaN             ball       NaN
# 6  Urías, Julio  670712.0  628711.0        NaN             foul       NaN
# 7  Urías, Julio  670712.0  628711.0        NaN             foul       NaN
# 8  Urías, Julio  670712.0  628711.0        NaN             ball       NaN
# 9  Urías, Julio  622534.0  628711.0  field_out    hit_into_play       NaN
#
#    spin_rate_deprecated  break_angle_deprecated  break_length_deprecated  \
# 0                   NaN                     NaN                      NaN
# 1                   NaN                     NaN                      NaN
# 2                   NaN                     NaN                      NaN
# 3                   NaN                     NaN                      NaN
# 4                   NaN                     NaN                      NaN
# 5                   NaN                     NaN                      NaN
# 6                   NaN                     NaN                      NaN
# 7                   NaN                     NaN                      NaN
# 8                   NaN                     NaN                      NaN
# 9                   NaN                     NaN                      NaN
#
#    zone                                                des game_type stand  \
# 0   4.0                Willy Adames called out on strikes.         W     R
# 1   1.0                Willy Adames called out on strikes.         W     R
# 2   2.0                Willy Adames called out on strikes.         W     R
# 3   4.0               Mike Brosseau called out on strikes.         W     R
# 4  13.0               Mike Brosseau called out on strikes.         W     R
# 5  11.0               Mike Brosseau called out on strikes.         W     R
# 6  13.0               Mike Brosseau called out on strikes.         W     R
# 7   5.0               Mike Brosseau called out on strikes.         W     R
# 8  12.0               Mike Brosseau called out on strikes.         W     R
# 9   6.0  Manuel Margot flies out to right fielder Mooki...         W     R
#
#   p_throws home_team away_team type  hit_location   bb_type  balls  strikes  \
# 0        L       LAD        TB    S           2.0       NaN    0.0      2.0
# 1        L       LAD        TB    S           NaN       NaN    0.0      1.0
# 2        L       LAD        TB    S           NaN       NaN    0.0      0.0
# 3        L       LAD        TB    S           2.0       NaN    3.0      2.0
# 4        L       LAD        TB    B           NaN       NaN    2.0      2.0
# 5        L       LAD        TB    B           NaN       NaN    1.0      2.0
# 6        L       LAD        TB    S           NaN       NaN    1.0      1.0
# 7        L       LAD        TB    S           NaN       NaN    1.0      0.0
# 8        L       LAD        TB    B           NaN       NaN    0.0      0.0
# 9        L       LAD        TB    X           9.0  fly_ball    1.0      2.0
#
#    game_year  pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  \
# 0     2020.0   0.18   1.63    -0.53     2.29    NaN    NaN    NaN
# 1     2020.0   0.75   1.30    -0.55     3.03    NaN    NaN    NaN
# 2     2020.0   0.23   1.47    -0.04     3.32    NaN    NaN    NaN
# 3     2020.0   0.27   1.50    -0.37     2.15    NaN    NaN    NaN
# 4     2020.0  -1.67  -0.15    -0.14     0.96    NaN    NaN    NaN
# 5     2020.0   0.30   1.44    -0.47     3.94    NaN    NaN    NaN
# 6     2020.0  -1.57  -0.09    -0.97     2.06    NaN    NaN    NaN
# 7     2020.0   0.50   1.41     0.08     2.59    NaN    NaN    NaN
# 8     2020.0   0.52   1.44     1.18     3.52    NaN    NaN    NaN
# 9     2020.0   0.40   1.48     0.40     2.56    NaN    NaN    NaN
#
#    outs_when_up  inning inning_topbot    hc_x   hc_y  tfs_deprecated  \
# 0           2.0     9.0           Top     NaN    NaN             NaN
# 1           2.0     9.0           Top     NaN    NaN             NaN
# 2           2.0     9.0           Top     NaN    NaN             NaN
# 3           1.0     9.0           Top     NaN    NaN             NaN
# 4           1.0     9.0           Top     NaN    NaN             NaN
# 5           1.0     9.0           Top     NaN    NaN             NaN
# 6           1.0     9.0           Top     NaN    NaN             NaN
# 7           1.0     9.0           Top     NaN    NaN             NaN
# 8           1.0     9.0           Top     NaN    NaN             NaN
# 9           0.0     9.0           Top  191.34  99.03             NaN
#
#    tfs_zulu_deprecated  fielder_2  umpire sv_id        vx0         vy0  \
# 0                  NaN   605131.0     NaN   NaN  -5.950264 -140.490456
# 1                  NaN   605131.0     NaN   NaN -10.560246 -136.599519
# 2                  NaN   605131.0     NaN   NaN  -5.199252 -138.098234
# 3                  NaN   605131.0     NaN   NaN  -5.843595 -137.294295
# 4                  NaN   605131.0     NaN   NaN  -0.383207 -118.447810
# 5                  NaN   605131.0     NaN   NaN  -6.600812 -139.135295
# 6                  NaN   605131.0     NaN   NaN  -2.476312 -117.286244
# 7                  NaN   605131.0     NaN   NaN  -5.607907 -137.809921
# 8                  NaN   605131.0     NaN   NaN  -2.392348 -137.363478
# 9                  NaN   605131.0     NaN   NaN  -4.306764 -138.539023
#
#         vz0         ax         ay         az  sz_top  sz_bot  hit_distance_sc  \
# 0 -7.897391   3.772000  32.321911  -8.981441    3.50    1.69              NaN
# 1 -3.429867  11.723598  29.183810 -15.237217    3.49    1.69              NaN
# 2 -4.637970   4.158758  30.838499 -12.535677    3.50    1.69              NaN
# 3 -7.414897   4.754147  30.016237 -11.778755    3.24    1.53              NaN
# 4 -4.454166 -15.553576  24.451936 -32.892744    3.20    1.53              NaN
# 5 -2.905682   5.335650  30.811825 -12.976271    3.22    1.53              NaN
# 6 -2.102737 -13.916321  24.086999 -32.781095    3.34    1.53              8.0
# 7 -6.197171   7.630847  29.808875 -13.053227    3.34    1.53            240.0
# 8 -4.225068   7.109486  29.169727 -13.246297    3.24    1.53              NaN
# 9 -6.867868   6.166594  30.824839 -11.731952    3.25    1.53            283.0
#
#    launch_speed  launch_angle  effective_speed  release_spin_rate  \
# 0           NaN           NaN             95.4             2615.0
# 1           NaN           NaN             93.4             2470.0
# 2           NaN           NaN             94.0             2397.0
# 3           NaN           NaN             93.7             2508.0
# 4           NaN           NaN             80.2             3031.0
# 5           NaN           NaN             94.9             2437.0
# 6          92.8         -16.0             79.3             2971.0
# 7          77.3          29.0             93.9             2478.0
# 8           NaN           NaN             93.6             2581.0
# 9          83.4          44.0             94.0             2450.0
#
#    release_extension   game_pk  pitcher.1  fielder_2.1  fielder_3  fielder_4  \
# 0                5.7  635886.0   628711.0     605131.0   571970.0   571771.0
# 1                5.9  635886.0   628711.0     605131.0   571970.0   571771.0
# 2                5.7  635886.0   628711.0     605131.0   571970.0   571771.0
# 3                5.9  635886.0   628711.0     605131.0   571970.0   571771.0
# 4                5.7  635886.0   628711.0     605131.0   571970.0   571771.0
# 5                5.8  635886.0   628711.0     605131.0   571970.0   571771.0
# 6                5.6  635886.0   628711.0     605131.0   571970.0   571771.0
# 7                5.8  635886.0   628711.0     605131.0   571970.0   571771.0
# 8                5.7  635886.0   628711.0     605131.0   571970.0   571771.0
# 9                5.6  635886.0   628711.0     605131.0   571970.0   571771.0
#
#    fielder_5  fielder_6  fielder_7  fielder_8  fielder_9  release_pos_y  \
# 0   621458.0   608369.0   621035.0   641355.0   605141.0          54.82
# 1   621458.0   608369.0   621035.0   641355.0   605141.0          54.59
# 2   621458.0   608369.0   621035.0   641355.0   605141.0          54.76
# 3   621458.0   608369.0   621035.0   641355.0   605141.0          54.60
# 4   621458.0   608369.0   621035.0   641355.0   605141.0          54.84
# 5   621458.0   608369.0   621035.0   641355.0   605141.0          54.66
# 6   621458.0   608369.0   621035.0   641355.0   605141.0          54.94
# 7   621458.0   608369.0   621035.0   641355.0   605141.0          54.72
# 8   621458.0   608369.0   621035.0   641355.0   605141.0          54.79
# 9   621458.0   608369.0   621035.0   641355.0   605141.0          54.92
#
#    estimated_ba_using_speedangle  estimated_woba_using_speedangle  woba_value  \
# 0                            NaN                              NaN         0.0
# 1                            NaN                              NaN         NaN
# 2                            NaN                              NaN         NaN
# 3                            NaN                              NaN         0.0
# 4                            NaN                              NaN         NaN
# 5                            NaN                              NaN         NaN
# 6                            NaN                              NaN         NaN
# 7                            NaN                              NaN         NaN
# 8                            NaN                              NaN         NaN
# 9                          0.027                            0.041         0.0
#
#    woba_denom  babip_value  iso_value  launch_speed_angle  at_bat_number  \
# 0         1.0          0.0        0.0                 NaN           65.0
# 1         NaN          NaN        NaN                 NaN           65.0
# 2         NaN          NaN        NaN                 NaN           65.0
# 3         1.0          0.0        0.0                 NaN           64.0
# 4         NaN          NaN        NaN                 NaN           64.0
# 5         NaN          NaN        NaN                 NaN           64.0
# 6         NaN          NaN        NaN                 NaN           64.0
# 7         NaN          NaN        NaN                 NaN           64.0
# 8         NaN          NaN        NaN                 NaN           64.0
# 9         1.0          0.0        0.0                 3.0           63.0
#
#    pitch_number       pitch_name  home_score  away_score  bat_score  \
# 0           3.0  4-Seam Fastball         3.0         1.0        1.0
# 1           2.0  4-Seam Fastball         3.0         1.0        1.0
# 2           1.0  4-Seam Fastball         3.0         1.0        1.0
# 3           6.0  4-Seam Fastball         3.0         1.0        1.0
# 4           5.0        Curveball         3.0         1.0        1.0
# 5           4.0  4-Seam Fastball         3.0         1.0        1.0
# 6           3.0        Curveball         3.0         1.0        1.0
# 7           2.0  4-Seam Fastball         3.0         1.0        1.0
# 8           1.0  4-Seam Fastball         3.0         1.0        1.0
# 9           4.0  4-Seam Fastball         3.0         1.0        1.0
#
#    fld_score  post_away_score  post_home_score  post_bat_score  \
# 0        3.0              1.0              3.0             1.0
# 1        3.0              1.0              3.0             1.0
# 2        3.0              1.0              3.0             1.0
# 3        3.0              1.0              3.0             1.0
# 4        3.0              1.0              3.0             1.0
# 5        3.0              1.0              3.0             1.0
# 6        3.0              1.0              3.0             1.0
# 7        3.0              1.0              3.0             1.0
# 8        3.0              1.0              3.0             1.0
# 9        3.0              1.0              3.0             1.0
#
#    post_fld_score if_fielding_alignment of_fielding_alignment  spin_axis  \
# 0             3.0              Standard              Standard      149.0
# 1             3.0              Standard              Standard      127.0
# 2             3.0              Standard              Standard      147.0
# 3             3.0              Standard              Standard      153.0
# 4             3.0              Standard              Standard      308.0
# 5             3.0              Standard              Standard      148.0
# 6             3.0         Infield shift              Standard      128.0
# 7             3.0         Infield shift              Standard      140.0
# 8             3.0         Infield shift              Standard      146.0
# 9             3.0              Standard              Standard      148.0
#
#    delta_home_win_exp  delta_run_exp
# 0               0.011         -0.067
# 1               0.000         -0.027
# 2               0.000         -0.017
# 3               0.023         -0.208
# 4               0.000          0.060
# 5               0.000          0.030
# 6               0.000         -0.044
# 7               0.000         -0.033
# 8               0.000          0.027
# 9               0.037         -0.180

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3925776 entries, 0 to 712838
# Data columns (total 93 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   index                            int64
#  1   pitch_type                       object
#  2   game_date                        datetime64[ns]
#  3   release_speed                    float64
#  4   release_pos_x                    float64
#  5   release_pos_z                    float64
#  6   player_name                      object
#  7   batter                           float64
#  8   pitcher                          float64
#  9   events                           object
#  10  description                      object
#  11  spin_dir                         float64
#  12  spin_rate_deprecated             float64
#  13  break_angle_deprecated           float64
#  14  break_length_deprecated          float64
#  15  zone                             float64
#  16  des                              object
#  17  game_type                        object
#  18  stand                            object
#  19  p_throws                         object
#  20  home_team                        object
#  21  away_team                        object
#  22  type                             object
#  23  hit_location                     float64
#  24  bb_type                          object
#  25  balls                            float64
#  26  strikes                          float64
#  27  game_year                        float64
#  28  pfx_x                            float64
#  29  pfx_z                            float64
#  30  plate_x                          float64
#  31  plate_z                          float64
#  32  on_3b                            float64
#  33  on_2b                            float64
#  34  on_1b                            float64
#  35  outs_when_up                     float64
#  36  inning                           float64
#  37  inning_topbot                    object
#  38  hc_x                             float64
#  39  hc_y                             float64
#  40  tfs_deprecated                   float64
#  41  tfs_zulu_deprecated              float64
#  42  fielder_2                        float64
#  43  umpire                           float64
#  44  sv_id                            object
#  45  vx0                              float64
#  46  vy0                              float64
#  47  vz0                              float64
#  48  ax                               float64
#  49  ay                               float64
#  50  az                               float64
#  51  sz_top                           float64
#  52  sz_bot                           float64
#  53  hit_distance_sc                  float64
#  54  launch_speed                     float64
#  55  launch_angle                     float64
#  56  effective_speed                  float64
#  57  release_spin_rate                float64
#  58  release_extension                float64
#  59  game_pk                          float64
#  60  pitcher.1                        float64
#  61  fielder_2.1                      float64
#  62  fielder_3                        float64
#  63  fielder_4                        float64
#  64  fielder_5                        float64
#  65  fielder_6                        float64
#  66  fielder_7                        float64
#  67  fielder_8                        float64
#  68  fielder_9                        float64
#  69  release_pos_y                    float64
#  70  estimated_ba_using_speedangle    float64
#  71  estimated_woba_using_speedangle  float64
#  72  woba_value                       float64
#  73  woba_denom                       float64
#  74  babip_value                      float64
#  75  iso_value                        float64
#  76  launch_speed_angle               float64
#  77  at_bat_number                    float64
#  78  pitch_number                     float64
#  79  pitch_name                       object
#  80  home_score                       float64
#  81  away_score                       float64
#  82  bat_score                        float64
#  83  fld_score                        float64
#  84  post_away_score                  float64
#  85  post_home_score                  float64
#  86  post_bat_score                   float64
#  87  post_fld_score                   float64
#  88  if_fielding_alignment            object
#  89  of_fielding_alignment            object
#  90  spin_axis                        float64
#  91  delta_home_win_exp               float64
#  92  delta_run_exp                    float64
# dtypes: datetime64[ns](1), float64(74), int64(1), object(17)
# memory usage: 2.8+ GB
